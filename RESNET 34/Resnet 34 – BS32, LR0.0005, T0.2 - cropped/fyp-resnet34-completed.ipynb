# %%
# !git clone https://github.com/salesforce/PCL.git
# %cd PCL
# Out:
# Cloning into 'PCL'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 160 (delta 18), reused 12 (delta 12), pack-reused 134 (from 2)
# Receiving objects: 100% (160/160), 196.36 KiB | 5.95 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/PCL

# %%
# !pip install torch torchvision
# !pip install numpy tqdm pyyaml
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.2)

# %%
import torch
print(torch.cuda.is_available())  # True
print(torch.cuda.get_device_name(0))  #GPU name
# Out:
# True
# Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = "/content/drive/My Drive/dataset"

# %%
# %cd /content/PCL
# Out:
# /content/PCL

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 72.1 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
import torch
import torch.nn as nn

# %%
import importlib
import sys
import pcl.builder as builder

# Print where the module is loaded from
print("Reloaded from:", builder.__file__)

# Force reload and confirm
builder = importlib.reload(builder)
print("After reload:", builder.__file__)

# Check if MoCo exists
print("MoCo available?", hasattr(builder, "MoCo"))

# Print id to confirm new module object
print("Module id:", id(builder))
# Out:
# Reloaded from: /content/PCL/pcl/builder.py
# After reload: /content/PCL/pcl/builder.py
# MoCo available? True
# Module id: 136997869833728

# %%
import sys
sys.path.insert(0, "/content/PCL")  # force project path

from pcl import builder
print("Builder path:", builder.__file__)
print("Has MoCo:", hasattr(builder, "MoCo"))
# Out:
# Builder path: /content/PCL/pcl/builder.py
# Has MoCo: True

# %%
import os, sys
sys.path.append('/content/PCL')

from pcl import builder
print("✅ Import worked!")

import sys
sys.path.insert(0, "/content/PCL")
# Out:
# ✅ Import worked!

# %%
# %reset -f

# %%
builder_path = "/content/PCL/pcl/builder.py"

# Read the existing builder.py
with open(builder_path, "r") as f:
    original_code = f.read()

# Only add MoCo if it's not already defined
if "class MoCo" not in original_code:
    moco_code = """
class MoCo(nn.Module):
    \"\"\"Build a MoCo model with: a query encoder, a key encoder, and a queue.\"\"\"
    def __init__(self, base_encoder, dim=128, r=16384, m=0.999, T=0.1, mlp=False):
        super(MoCo, self).__init__()
        self.r = r
        self.m = m
        self.T = T
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.encoder_q = base_encoder(num_classes=dim).to(self.device)
        self.encoder_k = base_encoder(num_classes=dim).to(self.device)

        if mlp:
            dim_mlp = self.encoder_q.fc.weight.shape[1]
            self.encoder_q.fc = nn.Sequential(nn.Linear(dim_mlp, dim_mlp), nn.ReLU(), self.encoder_q.fc)
            self.encoder_k.fc = nn.Sequential(nn.Linear(dim_mlp, dim_mlp), nn.ReLU(), self.encoder_k.fc)

        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data.copy_(param_q.data)
            param_k.requires_grad = False

        self.register_buffer("queue", torch.randn(dim, r))
        self.queue = nn.functional.normalize(self.queue, dim=0)
        self.register_buffer("queue_ptr", torch.zeros(1, dtype=torch.long))

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1. - self.m)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys):
        keys = concat_all_gather(keys)
        batch_size = keys.shape[0]
        ptr = int(self.queue_ptr)
        assert self.r % batch_size == 0
        self.queue[:, ptr:ptr + batch_size] = keys.T
        ptr = (ptr + batch_size) % self.r
        self.queue_ptr[0] = ptr

    @torch.no_grad()
    def _batch_shuffle_ddp(self, x):
        idx_unshuffle = None
        return x, idx_unshuffle

    @torch.no_grad()
    def _batch_unshuffle_ddp(self, x, idx_unshuffle):
        return x

    def forward(self, im_q, im_k=None, is_eval=False, cluster_result=None, index=None):
        im_q = im_q.to(self.device)
        if im_k is not None:
            im_k = im_k.to(self.device)
        if index is not None:
            index = index.to(self.device)

        if is_eval:
            self.encoder_k.eval()
            k = self.encoder_k(im_q)
            k = nn.functional.normalize(k, dim=1)
            return k

        with torch.no_grad():
            self._momentum_update_key_encoder()
            im_k, idx_unshuffle = self._batch_shuffle_ddp(im_k)
            k = self.encoder_k(im_k)
            k = nn.functional.normalize(k, dim=1)
            k = self._batch_unshuffle_ddp(k, idx_unshuffle)

        q = self.encoder_q(im_q)
        q = nn.functional.normalize(q, dim=1)

        l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
        l_neg = torch.einsum('nc,ck->nk', [q, self.queue.clone().detach().to(self.device)])
        logits = torch.cat([l_pos, l_neg], dim=1)
        logits /= self.T
        labels = torch.zeros(logits.shape[0], dtype=torch.long).to(self.device)
        self._dequeue_and_enqueue(k)
        return logits, labels, None, None

@torch.no_grad()
def concat_all_gather(tensor):
    return tensor
"""
    # Append the MoCo definition
    with open(builder_path, "a") as f:
        f.write("\n" + moco_code)

print("MoCo class appended to builder.py")
# Out:
# MoCo class appended to builder.py

# %%
import sys
sys.path.insert(0, "/content/PCL")

from pcl import builder
print("MoCo available?", hasattr(builder, "MoCo"))
# Out:
# MoCo available? True

# %%
# !python3 /content/PCL/main_pcl.py \
  "/content/drive/My Drive/dataset_cropped" \
  --arch resnet34 \
  --epochs 300 \
  --batch-size 32 \
  --lr 0.0005 \
  --temperature 0.2 \
  --num-cluster 3
# Out:
# Streaming output truncated to the last 5000 lines.
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.4539 imbalance=1.012 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.45372 imbalance=1.034 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.53555 imbalance=1.040 nsplit=0
# Epoch: [40][0/8]	Time  6.610 ( 6.610)	Data  6.220 ( 6.220)	Loss 9.0900e+00 (9.0900e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 41 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.20s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.48304 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.47918 imbalance=1.053 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.46726 imbalance=1.020 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.46768 imbalance=1.023 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.5161 imbalance=1.029 nsplit=0
# Epoch: [41][0/8]	Time  5.892 ( 5.892)	Data  5.147 ( 5.147)	Loss 9.2292e+00 (9.2292e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 42 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.76s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.4598 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.45585 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.45582 imbalance=1.018 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.45632 imbalance=1.032 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.53847 imbalance=1.034 nsplit=0
# Epoch: [42][0/8]	Time  4.649 ( 4.649)	Data  4.321 ( 4.321)	Loss 9.0573e+00 (9.0573e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 43 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.99s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.46651 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.45948 imbalance=1.132 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.45693 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.45596 imbalance=1.046 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.57037 imbalance=1.040 nsplit=0
# Epoch: [43][0/8]	Time  4.524 ( 4.524)	Data  4.123 ( 4.123)	Loss 9.1536e+00 (9.1536e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 44 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.57s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.5219 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.52614 imbalance=1.111 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.52067 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.51976 imbalance=1.062 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.63943 imbalance=1.052 nsplit=0
# Epoch: [44][0/8]	Time  4.623 ( 4.623)	Data  4.226 ( 4.226)	Loss 9.2412e+00 (9.2412e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 45 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.33s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.57207 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.57158 imbalance=1.115 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.56688 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.56688 imbalance=1.052 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.59435 imbalance=1.100 nsplit=0
# Epoch: [45][0/8]	Time  4.676 ( 4.676)	Data  3.967 ( 3.967)	Loss 9.0943e+00 (9.0943e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 46 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.80s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.57103 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.55807 imbalance=1.073 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.56268 imbalance=1.064 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.55837 imbalance=1.053 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.59587 imbalance=1.145 nsplit=0
# Epoch: [46][0/8]	Time  4.727 ( 4.727)	Data  4.288 ( 4.288)	Loss 9.0878e+00 (9.0878e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 47 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.80s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.65007 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.64169 imbalance=1.115 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.64926 imbalance=1.070 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.64818 imbalance=1.065 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.67116 imbalance=1.118 nsplit=0
# Epoch: [47][0/8]	Time  6.067 ( 6.067)	Data  5.590 ( 5.590)	Loss 9.1169e+00 (9.1169e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 48 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.79s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.72005 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.69469 imbalance=1.141 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.69264 imbalance=1.082 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.69165 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.69458 imbalance=1.083 nsplit=0
# Epoch: [48][0/8]	Time  6.602 ( 6.602)	Data  6.043 ( 6.043)	Loss 9.0535e+00 (9.0535e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 49 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.80s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.75 imbalance=1.118 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.74392 imbalance=1.231 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.72002 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.71609 imbalance=1.073 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.73806 imbalance=1.088 nsplit=0
# Epoch: [49][0/8]	Time  4.930 ( 4.930)	Data  4.446 ( 4.446)	Loss 9.1774e+00 (9.1774e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 50 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.08s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.77661 imbalance=1.117 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.75487 imbalance=1.078 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.76137 imbalance=1.081 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.75411 imbalance=1.076 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.77938 imbalance=1.057 nsplit=0
# Epoch: [50][0/8]	Time  4.832 ( 4.832)	Data  4.450 ( 4.450)	Loss 9.1110e+00 (9.1110e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 51 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.11s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.74981 imbalance=1.135 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.74209 imbalance=1.043 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.74195 imbalance=1.076 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.73647 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.74106 imbalance=1.035 nsplit=0
# Epoch: [51][0/8]	Time  5.580 ( 5.580)	Data  5.260 ( 5.260)	Loss 9.0375e+00 (9.0375e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 52 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.28s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.76267 imbalance=1.089 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.78239 imbalance=1.135 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.76267 imbalance=1.089 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.76208 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.78298 imbalance=1.027 nsplit=0
# Epoch: [52][0/8]	Time  4.614 ( 4.614)	Data  4.213 ( 4.213)	Loss 9.1577e+00 (9.1577e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 53 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.65s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.83274 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.83218 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.832 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.82965 imbalance=1.038 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.84568 imbalance=1.019 nsplit=0
# Epoch: [53][0/8]	Time  4.942 ( 4.942)	Data  4.624 ( 4.624)	Loss 9.1445e+00 (9.1445e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 54 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.35s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.90321 imbalance=1.050 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.89875 imbalance=1.036 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.90314 imbalance=1.046 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.8992 imbalance=1.052 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.91142 imbalance=1.026 nsplit=0
# Epoch: [54][0/8]	Time  5.544 ( 5.544)	Data  5.234 ( 5.234)	Loss 9.0807e+00 (9.0807e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 55 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.96913 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.03021 imbalance=1.028 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.9716 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.0321 imbalance=1.006 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.9672 imbalance=1.012 nsplit=0
# Objective improved: keep new clusters
# Epoch: [55][0/8]	Time  4.730 ( 4.730)	Data  4.406 ( 4.406)	Loss 9.1393e+00 (9.1393e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 56 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:06<00:00,  3.12s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.96161 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.02761 imbalance=1.018 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.9594 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.96881 imbalance=1.024 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.96041 imbalance=1.039 nsplit=0
# Epoch: [56][0/8]	Time  5.353 ( 5.353)	Data  5.033 ( 5.033)	Loss 9.1463e+00 (9.1463e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 57 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.79s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.00774 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.0457 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.00967 imbalance=1.023 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.08482 imbalance=1.006 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.00697 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Epoch: [57][0/8]	Time  6.015 ( 6.015)	Data  5.669 ( 5.669)	Loss 9.0037e+00 (9.0037e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 58 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.77s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.16773 imbalance=1.016 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.21046 imbalance=1.053 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.18538 imbalance=1.029 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.26552 imbalance=1.052 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.16829 imbalance=1.044 nsplit=0
# Epoch: [58][0/8]	Time  6.516 ( 6.516)	Data  5.831 ( 5.831)	Loss 9.0562e+00 (9.0562e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 59 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.80s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.2413 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.26966 imbalance=1.019 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.27062 imbalance=1.023 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.29594 imbalance=1.021 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.24459 imbalance=1.086 nsplit=0
# Epoch: [59][0/8]	Time  4.911 ( 4.911)	Data  4.261 ( 4.261)	Loss 9.0989e+00 (9.0989e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 60 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.90s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.2333 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.24119 imbalance=1.007 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.2865 imbalance=1.007 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.28741 imbalance=1.013 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.23575 imbalance=1.058 nsplit=0
# Epoch: [60][0/8]	Time  4.724 ( 4.724)	Data  4.059 ( 4.059)	Loss 9.2533e+00 (9.2533e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 61 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.06s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.16384 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.18209 imbalance=1.015 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.16286 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.19148 imbalance=1.005 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.16272 imbalance=1.066 nsplit=0
# Objective improved: keep new clusters
# Epoch: [61][0/8]	Time  5.458 ( 5.458)	Data  4.952 ( 4.952)	Loss 8.9802e+00 (8.9802e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 62 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.39s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.25001 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.24264 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.24437 imbalance=1.039 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.34286 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.24437 imbalance=1.039 nsplit=0
# Epoch: [62][0/8]	Time  4.653 ( 4.653)	Data  3.985 ( 3.985)	Loss 9.1702e+00 (9.1702e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 63 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.52s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.25471 imbalance=1.014 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.25247 imbalance=1.041 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.24865 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.24996 imbalance=1.036 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.24914 imbalance=1.042 nsplit=0
# Epoch: [63][0/8]	Time  4.846 ( 4.846)	Data  4.522 ( 4.522)	Loss 9.0050e+00 (9.0050e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 64 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.22s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.27011 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.27011 imbalance=1.045 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.27011 imbalance=1.045 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.27011 imbalance=1.045 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.27011 imbalance=1.045 nsplit=0
# Epoch: [64][0/8]	Time  5.717 ( 5.717)	Data  5.332 ( 5.332)	Loss 9.1791e+00 (9.1791e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 65 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.87s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.191 imbalance=1.053 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.19133 imbalance=1.056 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.191 imbalance=1.053 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.19133 imbalance=1.056 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.19133 imbalance=1.056 nsplit=0
# Epoch: [65][0/8]	Time  4.752 ( 4.752)	Data  4.360 ( 4.360)	Loss 8.9195e+00 (8.9195e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 66 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.31s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.20025 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.20025 imbalance=1.031 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.20025 imbalance=1.031 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.20025 imbalance=1.031 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.20025 imbalance=1.031 nsplit=0
# Epoch: [66][0/8]	Time  4.700 ( 4.700)	Data  4.366 ( 4.366)	Loss 9.0118e+00 (9.0118e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 67 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.56s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.4743 imbalance=1.213 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.28375 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.28145 imbalance=1.022 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.28375 imbalance=1.023 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.28375 imbalance=1.023 nsplit=0
# Epoch: [67][0/8]	Time  4.627 ( 4.627)	Data  4.243 ( 4.243)	Loss 9.0879e+00 (9.0879e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 68 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.23s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.40487 imbalance=1.188 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.24773 imbalance=1.014 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.24244 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.24835 imbalance=1.018 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.24249 imbalance=1.046 nsplit=0
# Epoch: [68][0/8]	Time  5.000 ( 5.000)	Data  4.667 ( 4.667)	Loss 8.8977e+00 (8.8977e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 69 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.78s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.2955 imbalance=1.108 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.15103 imbalance=1.021 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.15126 imbalance=1.019 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.15103 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.15351 imbalance=1.058 nsplit=0
# Epoch: [69][0/8]	Time  6.554 ( 6.554)	Data  6.216 ( 6.216)	Loss 8.9323e+00 (8.9323e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 70 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.14s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.19558 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.19588 imbalance=1.036 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.31999 imbalance=1.031 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.19599 imbalance=1.031 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.32331 imbalance=1.038 nsplit=0
# Epoch: [70][0/8]	Time  4.657 ( 4.657)	Data  4.185 ( 4.185)	Loss 8.8332e+00 (8.8332e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 71 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.54s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.14351 imbalance=1.171 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.12108 imbalance=1.131 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.13565 imbalance=1.067 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.07222 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.06994 imbalance=1.041 nsplit=0
# Objective improved: keep new clusters
# Epoch: [71][0/8]	Time  6.305 ( 6.305)	Data  5.899 ( 5.899)	Loss 8.7888e+00 (8.7888e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 72 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.51s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.18884 imbalance=1.094 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.19578 imbalance=1.087 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.19189 imbalance=1.072 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.18561 imbalance=1.120 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.20855 imbalance=1.049 nsplit=0
# Epoch: [72][0/8]	Time  4.604 ( 4.604)	Data  4.154 ( 4.154)	Loss 8.7942e+00 (8.7942e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 73 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.01s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.25266 imbalance=1.111 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.25681 imbalance=1.111 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.25859 imbalance=1.085 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.24691 imbalance=1.117 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.32068 imbalance=1.033 nsplit=0
# Epoch: [73][0/8]	Time  5.600 ( 5.600)	Data  5.168 ( 5.168)	Loss 8.7320e+00 (8.7320e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 74 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.78s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.1943 imbalance=1.182 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.23561 imbalance=1.058 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.21936 imbalance=1.052 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.19642 imbalance=1.143 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.3033 imbalance=1.006 nsplit=0
# Epoch: [74][0/8]	Time  6.739 ( 6.739)	Data  6.361 ( 6.361)	Loss 8.8296e+00 (8.8296e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 75 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.63s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.19596 imbalance=1.217 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.20686 imbalance=1.085 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.19576 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.20458 imbalance=1.088 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.20686 imbalance=1.085 nsplit=0
# Epoch: [75][0/8]	Time  4.670 ( 4.670)	Data  4.346 ( 4.346)	Loss 8.7308e+00 (8.7308e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 76 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.01s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.3273 imbalance=1.124 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.32586 imbalance=1.065 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.32512 imbalance=1.077 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.32543 imbalance=1.134 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.32904 imbalance=1.073 nsplit=0
# Epoch: [76][0/8]	Time  5.241 ( 5.241)	Data  4.683 ( 4.683)	Loss 8.6721e+00 (8.6721e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 77 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.76s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.32666 imbalance=1.151 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.32852 imbalance=1.076 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.32785 imbalance=1.086 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.32465 imbalance=1.128 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.32129 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Epoch: [77][0/8]	Time  6.478 ( 6.478)	Data  6.079 ( 6.079)	Loss 8.8003e+00 (8.8003e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 78 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.77s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.33939 imbalance=1.151 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.34083 imbalance=1.088 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.3323 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.33735 imbalance=1.113 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.33543 imbalance=1.032 nsplit=0
# Epoch: [78][0/8]	Time  5.434 ( 5.434)	Data  4.733 ( 4.733)	Loss 8.7193e+00 (8.7193e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 79 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.90s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.39339 imbalance=1.129 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.38898 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.38413 imbalance=1.081 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.3901 imbalance=1.107 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.38534 imbalance=1.043 nsplit=0
# Epoch: [79][0/8]	Time  5.076 ( 5.076)	Data  4.055 ( 4.055)	Loss 8.7814e+00 (8.7814e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 80 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.12s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.44466 imbalance=1.124 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.44378 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.43749 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.43439 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.43634 imbalance=1.051 nsplit=0
# Epoch: [80][0/8]	Time  6.467 ( 6.467)	Data  6.136 ( 6.136)	Loss 8.8591e+00 (8.8591e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 81 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.79s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.43771 imbalance=1.113 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.44594 imbalance=1.097 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.44316 imbalance=1.075 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.44009 imbalance=1.084 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.44337 imbalance=1.044 nsplit=0
# Epoch: [81][0/8]	Time  5.959 ( 5.959)	Data  5.577 ( 5.577)	Loss 8.6522e+00 (8.6522e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 82 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.75s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.41237 imbalance=1.108 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.42821 imbalance=1.085 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.42664 imbalance=1.070 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.41267 imbalance=1.098 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.41267 imbalance=1.098 nsplit=0
# Epoch: [82][0/8]	Time  5.301 ( 5.301)	Data  3.717 ( 3.717)	Loss 8.5678e+00 (8.5678e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 83 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.89s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.47869 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.47958 imbalance=1.112 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.47889 imbalance=1.107 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.47828 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.47828 imbalance=1.084 nsplit=0
# Epoch: [83][0/8]	Time  4.663 ( 4.663)	Data  4.275 ( 4.275)	Loss 8.6871e+00 (8.6871e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 84 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.52s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.59888 imbalance=1.073 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.58993 imbalance=1.099 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.59088 imbalance=1.073 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.59888 imbalance=1.073 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.59685 imbalance=1.056 nsplit=0
# Epoch: [84][0/8]	Time  4.566 ( 4.566)	Data  4.168 ( 4.168)	Loss 8.7063e+00 (8.7063e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 85 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.89s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.7884 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.77804 imbalance=1.151 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.78708 imbalance=1.060 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.7884 imbalance=1.056 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.77814 imbalance=1.146 nsplit=0
# Epoch: [85][0/8]	Time  5.115 ( 5.115)	Data  3.246 ( 3.246)	Loss 8.6792e+00 (8.6792e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 86 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.78s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.80172 imbalance=1.081 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.79629 imbalance=1.133 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.79997 imbalance=1.064 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.80172 imbalance=1.081 nsplit=0
# Outer iteration 4 / 5
# ...
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.55955 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.53108 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.55955 imbalance=1.093 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.55929 imbalance=1.090 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.53108 imbalance=1.042 nsplit=0
# Epoch: [284][0/8]	Time  4.498 ( 4.498)	Data  3.749 ( 3.749)	Loss 7.7645e+00 (7.7645e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 285 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.24s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.54608 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.54484 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.54608 imbalance=1.042 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.54608 imbalance=1.042 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.54484 imbalance=1.029 nsplit=0
# Epoch: [285][0/8]	Time  5.804 ( 5.804)	Data  5.476 ( 5.476)	Loss 7.6070e+00 (7.6070e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 286 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.78s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.60087 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.60008 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.60087 imbalance=1.040 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.60087 imbalance=1.040 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.60008 imbalance=1.029 nsplit=0
# Epoch: [286][0/8]	Time  4.737 ( 4.737)	Data  4.410 ( 4.410)	Loss 7.7183e+00 (7.7183e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 287 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.06s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.67962 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.68039 imbalance=1.041 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.67962 imbalance=1.040 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.67962 imbalance=1.040 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.68039 imbalance=1.041 nsplit=0
# Epoch: [287][0/8]	Time  4.699 ( 4.699)	Data  4.325 ( 4.325)	Loss 7.5326e+00 (7.5326e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 288 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.55s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.38747 imbalance=1.041 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.38607 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.38747 imbalance=1.041 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.38747 imbalance=1.041 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.38607 imbalance=1.035 nsplit=0
# Epoch: [288][0/8]	Time  4.593 ( 4.593)	Data  4.234 ( 4.234)	Loss 7.7196e+00 (7.7196e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 289 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.22s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.50103 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.49465 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.50103 imbalance=1.048 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.50103 imbalance=1.048 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.49465 imbalance=1.034 nsplit=0
# Epoch: [289][0/8]	Time  4.923 ( 4.923)	Data  4.285 ( 4.285)	Loss 7.5980e+00 (7.5980e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 290 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.84s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.52265 imbalance=1.050 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.51142 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.52265 imbalance=1.050 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.52265 imbalance=1.050 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.51142 imbalance=1.026 nsplit=0
# Epoch: [290][0/8]	Time  6.932 ( 6.932)	Data  6.433 ( 6.433)	Loss 7.6586e+00 (7.6586e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 291 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.93s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.39156 imbalance=1.059 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.37707 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.39156 imbalance=1.059 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.39156 imbalance=1.059 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.37707 imbalance=1.031 nsplit=0
# Epoch: [291][0/8]	Time  4.685 ( 4.685)	Data  4.001 ( 4.001)	Loss 7.7158e+00 (7.7158e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 292 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.66s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.23865 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.23595 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.23865 imbalance=1.052 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.23865 imbalance=1.052 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.23595 imbalance=1.027 nsplit=0
# Epoch: [292][0/8]	Time  4.675 ( 4.675)	Data  4.339 ( 4.339)	Loss 7.7351e+00 (7.7351e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 293 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.35s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.18212 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.18062 imbalance=1.038 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.18212 imbalance=1.060 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.18212 imbalance=1.060 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.18062 imbalance=1.038 nsplit=0
# Epoch: [293][0/8]	Time  4.812 ( 4.812)	Data  4.099 ( 4.099)	Loss 7.6269e+00 (7.6269e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 294 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.79s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.28257 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.28265 imbalance=1.022 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.28257 imbalance=1.032 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.28257 imbalance=1.032 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.28265 imbalance=1.022 nsplit=0
# Epoch: [294][0/8]	Time  6.333 ( 6.333)	Data  5.971 ( 5.971)	Loss 7.5973e+00 (7.5973e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 295 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.15059 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.1508 imbalance=1.022 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.15059 imbalance=1.026 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.15059 imbalance=1.026 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.1508 imbalance=1.022 nsplit=0
# Epoch: [295][0/8]	Time  4.626 ( 4.626)	Data  4.066 ( 4.066)	Loss 7.6439e+00 (7.6439e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 296 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.44s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.13207 imbalance=1.024 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.13047 imbalance=1.021 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.13207 imbalance=1.024 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.13207 imbalance=1.024 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.13047 imbalance=1.021 nsplit=0
# Epoch: [296][0/8]	Time  4.524 ( 4.524)	Data  4.024 ( 4.024)	Loss 7.7677e+00 (7.7677e+00)	Acc@Inst   9.38 (  9.38)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 297 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.38s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.14347 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.14502 imbalance=1.016 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.14347 imbalance=1.025 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.14347 imbalance=1.025 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.14502 imbalance=1.016 nsplit=0
# Epoch: [297][0/8]	Time  4.862 ( 4.862)	Data  4.530 ( 4.530)	Loss 7.4975e+00 (7.4975e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 298 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.82s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.15312 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.1486 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.15312 imbalance=1.028 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.15312 imbalance=1.028 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.1486 imbalance=1.019 nsplit=0
# Epoch: [298][0/8]	Time  6.171 ( 6.171)	Data  5.831 ( 5.831)	Loss 7.5937e+00 (7.5937e+00)	Acc@Inst  15.62 ( 15.62)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 299 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.78s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.09016 imbalance=1.017 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.08878 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.09016 imbalance=1.017 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.09016 imbalance=1.017 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.08878 imbalance=1.019 nsplit=0
# Epoch: [299][0/8]	Time  6.369 ( 6.369)	Data  5.625 ( 5.625)	Loss 7.7648e+00 (7.7648e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)

# %%
# --- Install dependencies ---
# !pip install faiss-cpu umap-learn scikit-learn matplotlib

import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, silhouette_score
import numpy as np
import umap
import glob
from pcl import builder
import torchvision.models as models

# --- Find latest checkpoint ---
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]  # latest checkpoint
print("Using checkpoint:", checkpoint_path)

# --- Manually set args used in training ---
arch = "resnet34"
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.2
mlp = True

# --- Build MoCo model ---
model = builder.MoCo(
    models.__dict__[arch],
    low_dim,
    pcl_r,
    moco_m,
    temperature,
    mlp
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = ckpt['state_dict']
state_dict = {k: v for k, v in state_dict.items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# --- Dataset & DataLoader ---
data_path = "/content/drive/MyDrive/dataset_cropped"
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(data_path, transform)
loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=4)

# --- Feature extraction ---
all_features = []
all_labels = []

with torch.no_grad():
    for imgs, labels in loader:
        imgs = imgs.cuda(non_blocking=True)
        feats = model.encoder_q(imgs)  # MoCo encoder
        feats = torch.nn.functional.normalize(feats, dim=1)
        all_features.append(feats.cpu())
        all_labels.append(labels)

all_features = torch.cat(all_features, dim=0).numpy()
all_labels = torch.cat(all_labels, dim=0).numpy()

# --- t-SNE Visualization ---
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_embeds = tsne.fit_transform(all_features)

plt.figure(figsize=(8, 8))
scatter = plt.scatter(tsne_embeds[:, 0], tsne_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("t-SNE of MoCo Embeddings")
plt.show()

# --- UMAP Visualization ---
umap_embeds = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(all_features)
plt.figure(figsize=(8, 8))
scatter = plt.scatter(umap_embeds[:, 0], umap_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("UMAP of MoCo Embeddings")
plt.show()

# --- Clustering Metrics ---
nmi = normalized_mutual_info_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
ari = adjusted_rand_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
sil = silhouette_score(all_features, all_labels)

print(f"NMI: {nmi:.4f}")
print(f"ARI: {ari:.4f}")
print(f"Silhouette Score: {sil:.4f}")
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (0.5.9.post2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (1.16.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# NMI: 0.2360
# ARI: 0.0000
# Silhouette Score: 0.0134

# %%
import torch
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import glob
from pcl import builder
import torchvision.models as models

# -------------------------------
# Load latest checkpoint
# -------------------------------
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]
print("Using checkpoint:", checkpoint_path)

# --- MoCo args (ResNet-34 backbone) ---
arch = "resnet34"
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.2
mlp = True

# --- Build MoCo model ---
model = builder.MoCo(
    models.__dict__[arch],
    low_dim,
    pcl_r,
    moco_m,
    temperature,
    mlp
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = ckpt['state_dict']
state_dict = {k: v for k, v in state_dict.items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# -------------------------------
# Dataset & DataLoader
# -------------------------------
train_dir = "/content/drive/My Drive/dataset_cropped/train"
test_dir  = "/content/drive/My Drive/dataset_cropped/test"

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(train_dir, transform=transform)
test_dataset  = datasets.ImageFolder(test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False, num_workers=4)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))

# -------------------------------
# Feature Extraction
# -------------------------------
def extract_features(dataloader):
    features, labels = [], []
    with torch.no_grad():
        for imgs, lbls in dataloader:
            imgs = imgs.cuda(non_blocking=True)
            feats = model.encoder_q(imgs)  # use MoCo encoder_q
            feats = F.normalize(feats, dim=1)  # normalize embeddings
            features.append(feats.cpu())
            labels.append(lbls)
    return torch.cat(features), torch.cat(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels   = extract_features(test_loader)

# -------------------------------
# Centroid-based Classification
# -------------------------------
def compute_centroids(features, labels, num_classes):
    centroids = []
    for c in range(num_classes):
        mask = labels == c
        class_feats = features[mask]
        centroid = class_feats.mean(dim=0)
        centroids.append(centroid)
    return torch.stack(centroids)

num_classes = len(train_dataset.classes)
centroids = compute_centroids(train_features, train_labels, num_classes)
centroids = F.normalize(centroids, dim=1)

def predict_with_centroids(test_feats, centroids):
    sims = test_feats @ centroids.T  # cosine similarity
    preds = torch.argmax(sims, dim=1)
    return preds

pred_labels = predict_with_centroids(test_features, centroids)

# -------------------------------
# Evaluation Metrics
# -------------------------------
y_true = test_labels.numpy()
y_pred = pred_labels.numpy()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average="macro")
recall = recall_score(y_true, y_pred, average="macro")  # Sensitivity
f1 = f1_score(y_true, y_pred, average="macro")

# Specificity per class
cm = confusion_matrix(y_true, y_pred)
specificity = []
for i in range(num_classes):
    tn = cm.sum() - (cm[i,:].sum() + cm[:,i].sum() - cm[i,i])
    fp = cm[:,i].sum() - cm[i,i]
    specificity.append(tn / (tn + fp))
specificity = np.mean(specificity)

# -------------------------------
# Print Results
# -------------------------------
print("Confusion Matrix:\n", cm)
print(f"Accuracy:     {acc:.16f}")
print(f"Precision:    {precision:.16f}")
print(f"Sensitivity:  {recall:.16f}")
print(f"F1 Score:     {f1:.16f}")
print(f"Specificity:  {specificity:.16f}")
# Out:
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# Train size: 279
# Test size: 39
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Confusion Matrix:
#  [[ 8  3  2]
#  [ 0  2 11]
#  [ 0  1 12]]
# Accuracy:     0.5641025641025641
# Precision:    0.6044444444444445
# Sensitivity:  0.5641025641025642
# F1 Score:     0.5346700083542189
# Specificity:  0.7820512820512820
