# %%
# !git clone https://github.com/salesforce/PCL.git
# %cd PCL
# Out:
# Cloning into 'PCL'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 160 (delta 18), reused 12 (delta 12), pack-reused 134 (from 2)
# Receiving objects: 100% (160/160), 196.36 KiB | 5.95 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/PCL

# %%
# !pip install torch torchvision
# !pip install numpy tqdm pyyaml
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.2)

# %%
import torch
print(torch.cuda.is_available())  # True
print(torch.cuda.get_device_name(0))  #GPU name
# Out:
# True
# Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = "/content/drive/My Drive/dataset"

# %%
# %cd /content/PCL
# Out:
# /content/PCL

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 72.1 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
import torch
import torch.nn as nn

# %%
import importlib
import sys
import pcl.builder as builder

# Print where the module is loaded from
print("Reloaded from:", builder.__file__)

# Force reload and confirm
builder = importlib.reload(builder)
print("After reload:", builder.__file__)

# Check if MoCo exists
print("MoCo available?", hasattr(builder, "MoCo"))

# Print id to confirm new module object
print("Module id:", id(builder))
# Out:
# Reloaded from: /content/PCL/pcl/builder.py
# After reload: /content/PCL/pcl/builder.py
# MoCo available? True
# Module id: 136997869833728

# %%
import sys
sys.path.insert(0, "/content/PCL")  # force project path

from pcl import builder
print("Builder path:", builder.__file__)
print("Has MoCo:", hasattr(builder, "MoCo"))
# Out:
# Builder path: /content/PCL/pcl/builder.py
# Has MoCo: True

# %%
import os, sys
sys.path.append('/content/PCL')

from pcl import builder
print("✅ Import worked!")

import sys
sys.path.insert(0, "/content/PCL")
# Out:
# ✅ Import worked!

# %%
# %reset -f

# %%
builder_path = "/content/PCL/pcl/builder.py"

# Read the existing builder.py
with open(builder_path, "r") as f:
    original_code = f.read()

# Only add MoCo if it's not already defined
if "class MoCo" not in original_code:
    moco_code = """
class MoCo(nn.Module):
    \"\"\"Build a MoCo model with: a query encoder, a key encoder, and a queue.\"\"\"
    def __init__(self, base_encoder, dim=128, r=16384, m=0.999, T=0.1, mlp=False):
        super(MoCo, self).__init__()
        self.r = r
        self.m = m
        self.T = T
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.encoder_q = base_encoder(num_classes=dim).to(self.device)
        self.encoder_k = base_encoder(num_classes=dim).to(self.device)

        if mlp:
            dim_mlp = self.encoder_q.fc.weight.shape[1]
            self.encoder_q.fc = nn.Sequential(nn.Linear(dim_mlp, dim_mlp), nn.ReLU(), self.encoder_q.fc)
            self.encoder_k.fc = nn.Sequential(nn.Linear(dim_mlp, dim_mlp), nn.ReLU(), self.encoder_k.fc)

        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data.copy_(param_q.data)
            param_k.requires_grad = False

        self.register_buffer("queue", torch.randn(dim, r))
        self.queue = nn.functional.normalize(self.queue, dim=0)
        self.register_buffer("queue_ptr", torch.zeros(1, dtype=torch.long))

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1. - self.m)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys):
        keys = concat_all_gather(keys)
        batch_size = keys.shape[0]
        ptr = int(self.queue_ptr)
        assert self.r % batch_size == 0
        self.queue[:, ptr:ptr + batch_size] = keys.T
        ptr = (ptr + batch_size) % self.r
        self.queue_ptr[0] = ptr

    @torch.no_grad()
    def _batch_shuffle_ddp(self, x):
        idx_unshuffle = None
        return x, idx_unshuffle

    @torch.no_grad()
    def _batch_unshuffle_ddp(self, x, idx_unshuffle):
        return x

    def forward(self, im_q, im_k=None, is_eval=False, cluster_result=None, index=None):
        im_q = im_q.to(self.device)
        if im_k is not None:
            im_k = im_k.to(self.device)
        if index is not None:
            index = index.to(self.device)

        if is_eval:
            self.encoder_k.eval()
            k = self.encoder_k(im_q)
            k = nn.functional.normalize(k, dim=1)
            return k

        with torch.no_grad():
            self._momentum_update_key_encoder()
            im_k, idx_unshuffle = self._batch_shuffle_ddp(im_k)
            k = self.encoder_k(im_k)
            k = nn.functional.normalize(k, dim=1)
            k = self._batch_unshuffle_ddp(k, idx_unshuffle)

        q = self.encoder_q(im_q)
        q = nn.functional.normalize(q, dim=1)

        l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
        l_neg = torch.einsum('nc,ck->nk', [q, self.queue.clone().detach().to(self.device)])
        logits = torch.cat([l_pos, l_neg], dim=1)
        logits /= self.T
        labels = torch.zeros(logits.shape[0], dtype=torch.long).to(self.device)
        self._dequeue_and_enqueue(k)
        return logits, labels, None, None

@torch.no_grad()
def concat_all_gather(tensor):
    return tensor
"""
    # Append the MoCo definition
    with open(builder_path, "a") as f:
        f.write("\n" + moco_code)

print("MoCo class appended to builder.py")
# Out:
# MoCo class appended to builder.py

# %%
import sys
sys.path.insert(0, "/content/PCL")

from pcl import builder
print("MoCo available?", hasattr(builder, "MoCo"))
# Out:
# MoCo available? True

# %%
# !python3 /content/PCL/main_pcl.py \
  "/content/drive/My Drive/dataset_cropped" \
  --arch resnet34 \
  --epochs 300 \
  --batch-size 16 \
  --lr 0.0005 \
  --temperature 0.2 \
  --num-cluster 3
# Out:
# Streaming output truncated to the last 5000 lines.
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.88839 imbalance=1.080 nsplit=0
# Epoch: [39][ 0/17]	Time  5.162 ( 5.162)	Data  4.595 ( 4.595)	Loss 8.5339e+00 (8.5339e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 40 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.05it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.97709 imbalance=1.124 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.96398 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.97472 imbalance=1.050 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.97148 imbalance=1.034 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.96479 imbalance=1.042 nsplit=0
# Epoch: [40][ 0/17]	Time  6.069 ( 6.069)	Data  5.722 ( 5.722)	Loss 8.5904e+00 (8.5904e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 41 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.23it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.90233 imbalance=1.114 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.94048 imbalance=1.040 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.89647 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.93925 imbalance=1.013 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.86732 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Epoch: [41][ 0/17]	Time  6.415 ( 6.415)	Data  6.111 ( 6.111)	Loss 8.5533e+00 (8.5533e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 42 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.22it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.55661 imbalance=1.149 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.56177 imbalance=1.075 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.55002 imbalance=1.098 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.58022 imbalance=1.019 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.55176 imbalance=1.106 nsplit=0
# Epoch: [42][ 0/17]	Time  6.707 ( 6.707)	Data  5.765 ( 5.765)	Loss 8.4349e+00 (8.4349e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 43 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.15it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.61601 imbalance=1.065 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.60319 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.61245 imbalance=1.067 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.59776 imbalance=1.125 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.59747 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Epoch: [43][ 0/17]	Time  5.785 ( 5.785)	Data  5.429 ( 5.429)	Loss 8.5378e+00 (8.5378e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 44 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.22it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.82338 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.80904 imbalance=1.076 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.80645 imbalance=1.076 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.79671 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.79035 imbalance=1.005 nsplit=0
# Objective improved: keep new clusters
# Epoch: [44][ 0/17]	Time  4.792 ( 4.792)	Data  4.553 ( 4.553)	Loss 8.5327e+00 (8.5327e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 45 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.17it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.81856 imbalance=1.098 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.831 imbalance=1.036 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.81886 imbalance=1.075 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.81845 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.86297 imbalance=1.005 nsplit=0
# Epoch: [45][ 0/17]	Time  7.027 ( 7.027)	Data  6.309 ( 6.309)	Loss 8.3598e+00 (8.3598e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 46 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.12it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.27993 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.27895 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.30417 imbalance=1.021 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.3144 imbalance=1.019 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.31613 imbalance=1.027 nsplit=0
# Epoch: [46][ 0/17]	Time  4.736 ( 4.736)	Data  4.391 ( 4.391)	Loss 8.4697e+00 (8.4697e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 47 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.15s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.29334 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.28726 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.28718 imbalance=1.018 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.29299 imbalance=1.022 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.29589 imbalance=1.003 nsplit=0
# Epoch: [47][ 0/17]	Time  4.777 ( 4.777)	Data  4.177 ( 4.177)	Loss 8.2165e+00 (8.2165e+00)	Acc@Inst  18.75 ( 18.75)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 48 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.09s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.47721 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.5037 imbalance=1.013 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.51285 imbalance=1.039 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.5072 imbalance=1.021 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.47728 imbalance=1.011 nsplit=0
# Epoch: [48][ 0/17]	Time  5.576 ( 5.576)	Data  5.093 ( 5.093)	Loss 8.3549e+00 (8.3549e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 49 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.23it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.26859 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.27039 imbalance=1.007 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.50483 imbalance=1.100 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.27946 imbalance=1.001 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.26876 imbalance=1.015 nsplit=0
# Epoch: [49][ 0/17]	Time  6.433 ( 6.433)	Data  6.140 ( 6.140)	Loss 8.1987e+00 (8.1987e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 50 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.19it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.16575 imbalance=1.036 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.16439 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.27074 imbalance=1.052 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.24096 imbalance=1.043 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.16661 imbalance=1.063 nsplit=0
# Epoch: [50][ 0/17]	Time  6.748 ( 6.748)	Data  5.944 ( 5.944)	Loss 8.3608e+00 (8.3608e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 51 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.21it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.35717 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.35629 imbalance=1.021 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.5558 imbalance=1.088 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.52502 imbalance=1.043 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.36144 imbalance=1.038 nsplit=0
# Epoch: [51][ 0/17]	Time  6.072 ( 6.072)	Data  4.958 ( 4.958)	Loss 8.3546e+00 (8.3546e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 52 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.22it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.38961 imbalance=1.221 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.32654 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.26068 imbalance=1.036 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.36069 imbalance=1.117 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.32846 imbalance=1.002 nsplit=0
# Epoch: [52][ 0/17]	Time  4.865 ( 4.865)	Data  4.510 ( 4.510)	Loss 8.1498e+00 (8.1498e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 53 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.13it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.03891 imbalance=1.128 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.0359 imbalance=1.157 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.03723 imbalance=1.098 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.03107 imbalance=1.038 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.99822 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Epoch: [53][ 0/17]	Time  5.682 ( 5.682)	Data  5.259 ( 5.259)	Loss 8.1406e+00 (8.1406e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 54 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.01s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.98928 imbalance=1.182 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.97476 imbalance=1.179 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.9636 imbalance=1.072 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.949 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.95495 imbalance=1.021 nsplit=0
# Epoch: [54][ 0/17]	Time  4.854 ( 4.854)	Data  4.267 ( 4.267)	Loss 8.1412e+00 (8.1412e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 55 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.81237 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.86774 imbalance=1.103 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.81089 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.81738 imbalance=1.007 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.81497 imbalance=1.056 nsplit=0
# Epoch: [55][ 0/17]	Time  4.915 ( 4.915)	Data  4.062 ( 4.062)	Loss 8.1632e+00 (8.1632e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 56 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.26s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.05138 imbalance=1.021 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.0706 imbalance=1.050 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.04272 imbalance=1.108 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.0706 imbalance=1.050 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.11864 imbalance=1.076 nsplit=0
# Epoch: [56][ 0/17]	Time  5.083 ( 5.083)	Data  4.861 ( 4.861)	Loss 8.2243e+00 (8.2243e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 57 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.17it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.52009 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.53724 imbalance=1.130 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.50729 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.5213 imbalance=1.007 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.50488 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Epoch: [57][ 0/17]	Time  6.251 ( 6.251)	Data  6.000 ( 6.000)	Loss 8.1217e+00 (8.1217e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 58 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.21it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.76579 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.74989 imbalance=1.166 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.75241 imbalance=1.141 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.75145 imbalance=1.144 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.74925 imbalance=1.141 nsplit=0
# Objective improved: keep new clusters
# Epoch: [58][ 0/17]	Time  7.756 ( 7.756)	Data  7.514 ( 7.514)	Loss 7.9773e+00 (7.9773e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 59 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.23it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.95008 imbalance=1.239 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.95583 imbalance=1.151 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.94919 imbalance=1.187 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.9499 imbalance=1.184 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.95523 imbalance=1.151 nsplit=0
# Epoch: [59][ 0/17]	Time  5.210 ( 5.210)	Data  4.235 ( 4.235)	Loss 7.9970e+00 (7.9970e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 60 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.21it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.18658 imbalance=1.176 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.18942 imbalance=1.167 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.18663 imbalance=1.171 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.1875 imbalance=1.179 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.18942 imbalance=1.167 nsplit=0
# Epoch: [60][ 0/17]	Time  4.904 ( 4.904)	Data  4.014 ( 4.014)	Loss 7.9805e+00 (7.9805e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 61 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.02it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.12016 imbalance=1.206 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.11993 imbalance=1.183 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.1197 imbalance=1.182 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.11993 imbalance=1.183 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.11993 imbalance=1.183 nsplit=0
# Epoch: [61][ 0/17]	Time  4.769 ( 4.769)	Data  3.895 ( 3.895)	Loss 7.8560e+00 (7.8560e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 62 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.10s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.01993 imbalance=1.269 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.12457 imbalance=1.025 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.02028 imbalance=1.226 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.01602 imbalance=1.237 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.12427 imbalance=1.025 nsplit=0
# Epoch: [62][ 0/17]	Time  6.488 ( 6.488)	Data  5.990 ( 5.990)	Loss 7.8134e+00 (7.8134e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 63 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.03s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.9558 imbalance=1.122 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.94361 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.94621 imbalance=1.032 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.94229 imbalance=1.021 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.94537 imbalance=1.010 nsplit=0
# Epoch: [63][ 0/17]	Time  5.812 ( 5.812)	Data  4.668 ( 4.668)	Loss 7.8037e+00 (7.8037e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 64 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.12s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.43362 imbalance=1.190 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.43779 imbalance=1.119 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.43115 imbalance=1.143 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.4335 imbalance=1.109 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.43779 imbalance=1.119 nsplit=0
# Epoch: [64][ 0/17]	Time  4.949 ( 4.949)	Data  4.675 ( 4.675)	Loss 7.8194e+00 (7.8194e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 65 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.17s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.43958 imbalance=1.194 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.44006 imbalance=1.171 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.43066 imbalance=1.151 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.43066 imbalance=1.151 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.44006 imbalance=1.171 nsplit=0
# Epoch: [65][ 0/17]	Time  4.888 ( 4.888)	Data  4.162 ( 4.162)	Loss 7.6325e+00 (7.6325e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 66 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.30s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.27969 imbalance=1.210 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.27952 imbalance=1.164 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.27235 imbalance=1.076 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.28213 imbalance=1.130 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.27185 imbalance=1.142 nsplit=0
# Objective improved: keep new clusters
# Epoch: [66][ 0/17]	Time  5.315 ( 5.315)	Data  4.760 ( 4.760)	Loss 7.7029e+00 (7.7029e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 67 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.16it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.1372 imbalance=1.171 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.19577 imbalance=1.158 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.14247 imbalance=1.151 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.20405 imbalance=1.054 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.14365 imbalance=1.098 nsplit=0
# Epoch: [67][ 0/17]	Time  6.106 ( 6.106)	Data  5.178 ( 5.178)	Loss 7.7214e+00 (7.7214e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 68 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.22it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.30361 imbalance=1.169 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.18739 imbalance=1.169 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.26723 imbalance=1.067 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.19554 imbalance=1.056 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.18798 imbalance=1.155 nsplit=0
# Epoch: [68][ 0/17]	Time  7.595 ( 7.595)	Data  6.181 ( 6.181)	Loss 7.5751e+00 (7.5751e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 69 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.19it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.40796 imbalance=1.160 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.27643 imbalance=1.153 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.2811 imbalance=1.122 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.28016 imbalance=1.119 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.27654 imbalance=1.151 nsplit=0
# Epoch: [69][ 0/17]	Time  6.326 ( 6.326)	Data  5.953 ( 5.953)	Loss 7.5819e+00 (7.5819e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 70 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.22it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.98883 imbalance=1.149 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.99357 imbalance=1.181 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.98883 imbalance=1.149 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.98883 imbalance=1.149 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.98894 imbalance=1.146 nsplit=0
# Epoch: [70][ 0/17]	Time  5.335 ( 5.335)	Data  4.346 ( 4.346)	Loss 7.5827e+00 (7.5827e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 71 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.05it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.07205 imbalance=1.104 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.0746 imbalance=1.186 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.07646 imbalance=1.093 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.14264 imbalance=1.117 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.07216 imbalance=1.093 nsplit=0
# Epoch: [71][ 0/17]	Time  4.899 ( 4.899)	Data  4.478 ( 4.478)	Loss 7.4868e+00 (7.4868e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 72 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.12it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.20754 imbalance=1.153 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.20113 imbalance=1.198 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.20812 imbalance=1.174 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.19806 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.19921 imbalance=1.070 nsplit=0
# Epoch: [72][ 0/17]	Time  4.831 ( 4.831)	Data  4.495 ( 4.495)	Loss 7.6145e+00 (7.6145e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 73 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.17s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.16666 imbalance=1.144 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.17101 imbalance=1.136 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.16716 imbalance=1.137 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.16393 imbalance=1.098 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.16516 imbalance=1.089 nsplit=0
# Epoch: [73][ 0/17]	Time  4.855 ( 4.855)	Data  4.167 ( 4.167)	Loss 7.5910e+00 (7.5910e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 74 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.20s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.13438 imbalance=1.153 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.12776 imbalance=1.204 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.13863 imbalance=1.087 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.12326 imbalance=1.151 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.12425 imbalance=1.132 nsplit=0
# Epoch: [74][ 0/17]	Time  5.160 ( 5.160)	Data  4.595 ( 4.595)	Loss 7.5661e+00 (7.5661e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 75 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.02it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.0966 imbalance=1.142 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.09313 imbalance=1.167 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.08266 imbalance=1.073 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.08257 imbalance=1.078 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.07994 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Epoch: [75][ 0/17]	Time  5.673 ( 5.673)	Data  5.192 ( 5.192)	Loss 7.5861e+00 (7.5861e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 76 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.19it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.32437 imbalance=1.132 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.3406 imbalance=1.071 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.32033 imbalance=1.107 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.33892 imbalance=1.067 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.33872 imbalance=1.054 nsplit=0
# Epoch: [76][ 0/17]	Time  6.802 ( 6.802)	Data  6.563 ( 6.563)	Loss 7.4658e+00 (7.4658e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 77 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.23it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.17359 imbalance=1.103 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.19311 imbalance=1.160 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.16721 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.15988 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.16124 imbalance=1.076 nsplit=0
# Epoch: [77][ 0/17]	Time  6.684 ( 6.684)	Data  5.323 ( 5.323)	Loss 7.5559e+00 (7.5559e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 78 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.23it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.55095 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.55453 imbalance=1.114 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.54944 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.55314 imbalance=1.118 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.55314 imbalance=1.118 nsplit=0
# Epoch: [78][ 0/17]	Time  5.374 ( 5.374)	Data  4.103 ( 4.103)	Loss 7.5416e+00 (7.5416e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 79 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.25s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.35347 imbalance=1.089 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.38365 imbalance=1.073 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.35359 imbalance=1.088 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.38433 imbalance=1.083 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.37003 imbalance=1.031 nsplit=0
# Epoch: [79][ 0/17]	Time  5.083 ( 5.083)	Data  4.600 ( 4.600)	Loss 7.5981e+00 (7.5981e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 80 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.22it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.42458 imbalance=1.095 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.45698 imbalance=1.095 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.42296 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.42347 imbalance=1.060 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.42313 imbalance=1.056 nsplit=0
# Epoch: [80][ 0/17]	Time  5.996 ( 5.996)	Data  5.153 ( 5.153)	Loss 7.3540e+00 (7.3540e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 81 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.16it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.00083 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.01367 imbalance=1.119 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.00054 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.01367 imbalance=1.119 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=7.01415 imbalance=1.104 nsplit=0
# Epoch: [81][ 0/17]	Time  4.974 ( 4.974)	Data  4.330 ( 4.330)	Loss 7.5068e+00 (7.5068e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 82 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.09it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.51111 imbalance=1.050 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.52215 imbalance=1.045 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.51198 imbalance=1.035 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.52212 imbalance=1.047 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.51788 imbalance=1.070 nsplit=0
# Epoch: [82][ 0/17]	Time  4.981 ( 4.981)	Data  4.690 ( 4.690)	Loss 7.7323e+00 (7.7323e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 83 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.22s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.60161 imbalance=1.079 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.59433 imbalance=1.065 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.61166 imbalance=1.070 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.59433 imbalance=1.065 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.59433 imbalance=1.065 nsplit=0
# Epoch: [83][ 0/17]	Time  7.823 ( 7.823)	Data  7.603 ( 7.603)	Loss 7.4855e+00 (7.4855e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 84 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.13s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.34489 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.36455 imbalance=1.052 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.34444 imbalance=1.087 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.36455 imbalance=1.052 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.34349 imbalance=1.063 nsplit=0
# Objective improved: keep new clusters
# Epoch: [84][ 0/17]	Time  4.988 ( 4.988)	Data  4.765 ( 4.765)	Loss 7.3843e+00 (7.3843e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 85 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.12it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.99267 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.99421 imbalance=1.127 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.00138 imbalance=1.112 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.99384 imbalance=1.121 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.00138 imbalance=1.112 nsplit=0
# ...
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.12856 imbalance=1.056 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.18209 imbalance=1.031 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.12812 imbalance=1.057 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=2.18193 imbalance=1.028 nsplit=0
# Epoch: [284][ 0/17]	Time  6.235 ( 6.235)	Data  5.722 ( 5.722)	Loss 7.3707e+00 (7.3707e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 285 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.19it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.19706 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.22999 imbalance=1.075 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.22773 imbalance=1.060 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.19621 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.22832 imbalance=1.053 nsplit=0
# Epoch: [285][ 0/17]	Time  7.013 ( 7.013)	Data  6.787 ( 6.787)	Loss 6.8251e+00 (6.8251e+00)	Acc@Inst  25.00 ( 25.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 286 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.18it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.29471 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.29471 imbalance=1.030 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.29471 imbalance=1.030 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.29464 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=2.29464 imbalance=1.031 nsplit=0
# Epoch: [286][ 0/17]	Time  7.367 ( 7.367)	Data  6.873 ( 6.873)	Loss 7.0975e+00 (7.0975e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 287 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.19it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.18638 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.0891 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.0894 imbalance=1.011 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.0891 imbalance=1.028 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.17931 imbalance=1.043 nsplit=0
# Epoch: [287][ 0/17]	Time  4.919 ( 4.919)	Data  3.320 ( 3.320)	Loss 7.1262e+00 (7.1262e+00)	Acc@Inst  31.25 ( 31.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 288 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.92192 imbalance=1.143 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.92201 imbalance=1.067 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.95285 imbalance=1.051 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=1.92204 imbalance=1.064 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=1.95222 imbalance=1.049 nsplit=0
# Epoch: [288][ 0/17]	Time  4.863 ( 4.863)	Data  3.864 ( 3.864)	Loss 6.9098e+00 (6.9098e+00)	Acc@Inst  18.75 ( 18.75)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 289 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.20s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.11871 imbalance=1.115 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.11906 imbalance=1.065 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.11871 imbalance=1.115 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.11906 imbalance=1.065 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.11871 imbalance=1.115 nsplit=0
# Epoch: [289][ 0/17]	Time  4.927 ( 4.927)	Data  4.710 ( 4.710)	Loss 6.8441e+00 (6.8441e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 290 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.03it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.47248 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.47248 imbalance=1.034 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.47248 imbalance=1.034 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.47535 imbalance=1.040 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=2.47535 imbalance=1.040 nsplit=0
# Epoch: [290][ 0/17]	Time  4.841 ( 4.841)	Data  4.130 ( 4.130)	Loss 6.7836e+00 (6.7836e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 291 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.17s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.44756 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.32419 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.32419 imbalance=1.029 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.32511 imbalance=1.034 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=2.40261 imbalance=1.060 nsplit=0
# Epoch: [291][ 0/17]	Time  5.383 ( 5.383)	Data  4.225 ( 4.225)	Loss 6.9026e+00 (6.9026e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 292 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.25s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.33374 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.33374 imbalance=1.032 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.33374 imbalance=1.032 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.33374 imbalance=1.032 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.33374 imbalance=1.032 nsplit=0
# Epoch: [292][ 0/17]	Time  4.835 ( 4.835)	Data  4.081 ( 4.081)	Loss 6.7414e+00 (6.7414e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 293 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.08it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.32585 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.32148 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.32116 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.32183 imbalance=1.030 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.32116 imbalance=1.035 nsplit=0
# Epoch: [293][ 0/17]	Time  5.719 ( 5.719)	Data  5.493 ( 5.493)	Loss 7.0787e+00 (7.0787e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 294 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.08it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.26119 imbalance=1.092 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.16897 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.16856 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.16893 imbalance=1.021 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.22363 imbalance=1.053 nsplit=0
# Epoch: [294][ 0/17]	Time  6.442 ( 6.442)	Data  6.208 ( 6.208)	Loss 6.9403e+00 (6.9403e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 295 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.17it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.02519 imbalance=1.079 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.94258 imbalance=1.022 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.94215 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=1.94215 imbalance=1.019 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=1.99105 imbalance=1.056 nsplit=0
# Epoch: [295][ 0/17]	Time  6.827 ( 6.827)	Data  6.597 ( 6.597)	Loss 6.8012e+00 (6.8012e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 296 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.18it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.10195 imbalance=1.074 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.10196 imbalance=1.072 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.10068 imbalance=1.021 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.1019 imbalance=1.076 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.10174 imbalance=1.075 nsplit=0
# Epoch: [296][ 0/17]	Time  6.877 ( 6.877)	Data  6.264 ( 6.264)	Loss 6.9152e+00 (6.9152e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 297 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.23it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.87503 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.87456 imbalance=1.091 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.87456 imbalance=1.091 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=1.87356 imbalance=1.107 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=1.87456 imbalance=1.091 nsplit=0
# Epoch: [297][ 0/17]	Time  4.835 ( 4.835)	Data  4.272 ( 4.272)	Loss 7.2178e+00 (7.2178e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 298 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:03<00:00,  1.11it/s]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.12956 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.12893 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=2.12956 imbalance=1.040 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.12956 imbalance=1.040 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=2.13028 imbalance=1.046 nsplit=0
# Epoch: [298][ 0/17]	Time  4.892 ( 4.892)	Data  4.448 ( 4.448)	Loss 7.0563e+00 (7.0563e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 299 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.95168 imbalance=1.033 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.95168 imbalance=1.033 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.95168 imbalance=1.033 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=1.95157 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=1.95157 imbalance=1.034 nsplit=0
# Epoch: [299][ 0/17]	Time  4.809 ( 4.809)	Data  3.904 ( 3.904)	Loss 6.8018e+00 (6.8018e+00)	Acc@Inst  37.50 ( 37.50)	Acc@Proto   0.00 (  0.00)

# %%
# --- Install dependencies ---
# !pip install faiss-cpu umap-learn scikit-learn matplotlib

import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, silhouette_score
import numpy as np
import umap
import glob
from pcl import builder
import torchvision.models as models

# --- Find latest checkpoint ---
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]  # latest checkpoint
print("Using checkpoint:", checkpoint_path)

# --- Manually set args used in training ---
arch = "resnet34"
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.2
mlp = True

# --- Build MoCo model ---
model = builder.MoCo(
    models.__dict__[arch],
    low_dim,
    pcl_r,
    moco_m,
    temperature,
    mlp
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = ckpt['state_dict']
state_dict = {k: v for k, v in state_dict.items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# --- Dataset & DataLoader ---
data_path = "/content/drive/MyDrive/dataset_cropped"
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(data_path, transform)
loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=4)

# --- Feature extraction ---
all_features = []
all_labels = []

with torch.no_grad():
    for imgs, labels in loader:
        imgs = imgs.cuda(non_blocking=True)
        feats = model.encoder_q(imgs)  # MoCo encoder
        feats = torch.nn.functional.normalize(feats, dim=1)
        all_features.append(feats.cpu())
        all_labels.append(labels)

all_features = torch.cat(all_features, dim=0).numpy()
all_labels = torch.cat(all_labels, dim=0).numpy()

# --- t-SNE Visualization ---
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_embeds = tsne.fit_transform(all_features)

plt.figure(figsize=(8, 8))
scatter = plt.scatter(tsne_embeds[:, 0], tsne_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("t-SNE of MoCo Embeddings")
plt.show()

# --- UMAP Visualization ---
umap_embeds = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(all_features)
plt.figure(figsize=(8, 8))
scatter = plt.scatter(umap_embeds[:, 0], umap_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("UMAP of MoCo Embeddings")
plt.show()

# --- Clustering Metrics ---
nmi = normalized_mutual_info_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
ari = adjusted_rand_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
sil = silhouette_score(all_features, all_labels)

print(f"NMI: {nmi:.4f}")
print(f"ARI: {ari:.4f}")
print(f"Silhouette Score: {sil:.4f}")
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (0.5.9.post2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (1.16.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# NMI: 0.2360
# ARI: 0.0000
# Silhouette Score: 0.0034

# %%
import torch
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import glob
from pcl import builder
import torchvision.models as models

# -------------------------------
# Load latest checkpoint
# -------------------------------
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]
print("Using checkpoint:", checkpoint_path)

# --- MoCo args (ResNet-34 backbone) ---
arch = "resnet34"
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.2
mlp = True

# --- Build MoCo model ---
model = builder.MoCo(
    models.__dict__[arch],
    low_dim,
    pcl_r,
    moco_m,
    temperature,
    mlp
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = ckpt['state_dict']
state_dict = {k: v for k, v in state_dict.items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# -------------------------------
# Dataset & DataLoader
# -------------------------------
train_dir = "/content/drive/My Drive/dataset_cropped/train"
test_dir  = "/content/drive/My Drive/dataset_cropped/test"

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(train_dir, transform=transform)
test_dataset  = datasets.ImageFolder(test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False, num_workers=4)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))

# -------------------------------
# Feature Extraction
# -------------------------------
def extract_features(dataloader):
    features, labels = [], []
    with torch.no_grad():
        for imgs, lbls in dataloader:
            imgs = imgs.cuda(non_blocking=True)
            feats = model.encoder_q(imgs)  # use MoCo encoder_q
            feats = F.normalize(feats, dim=1)  # normalize embeddings
            features.append(feats.cpu())
            labels.append(lbls)
    return torch.cat(features), torch.cat(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels   = extract_features(test_loader)

# -------------------------------
# Centroid-based Classification
# -------------------------------
def compute_centroids(features, labels, num_classes):
    centroids = []
    for c in range(num_classes):
        mask = labels == c
        class_feats = features[mask]
        centroid = class_feats.mean(dim=0)
        centroids.append(centroid)
    return torch.stack(centroids)

num_classes = len(train_dataset.classes)
centroids = compute_centroids(train_features, train_labels, num_classes)
centroids = F.normalize(centroids, dim=1)

def predict_with_centroids(test_feats, centroids):
    sims = test_feats @ centroids.T  # cosine similarity
    preds = torch.argmax(sims, dim=1)
    return preds

pred_labels = predict_with_centroids(test_features, centroids)

# -------------------------------
# Evaluation Metrics
# -------------------------------
y_true = test_labels.numpy()
y_pred = pred_labels.numpy()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average="macro")
recall = recall_score(y_true, y_pred, average="macro")  # Sensitivity
f1 = f1_score(y_true, y_pred, average="macro")

# Specificity per class
cm = confusion_matrix(y_true, y_pred)
specificity = []
for i in range(num_classes):
    tn = cm.sum() - (cm[i,:].sum() + cm[:,i].sum() - cm[i,i])
    fp = cm[:,i].sum() - cm[i,i]
    specificity.append(tn / (tn + fp))
specificity = np.mean(specificity)

# -------------------------------
# Print Results
# -------------------------------
print("Confusion Matrix:\n", cm)
print(f"Accuracy:     {acc:.16f}")
print(f"Precision:    {precision:.16f}")
print(f"Sensitivity:  {recall:.16f}")
print(f"F1 Score:     {f1:.16f}")
print(f"Specificity:  {specificity:.16f}")
# Out:
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# Train size: 279
# Test size: 39
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Confusion Matrix:
#  [[ 9  3  1]
#  [11  2  0]
#  [ 1  1 11]]
# Accuracy:     0.5641025641025641
# Precision:    0.5595238095238094
# Sensitivity:  0.5641025641025641
# F1 Score:     0.5399793601651187
# Specificity:  0.7820512820512820
