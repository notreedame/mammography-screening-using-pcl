# %%
# !git clone https://github.com/salesforce/PCL.git
# %cd PCL
# Out:
# Cloning into 'PCL'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 160 (delta 18), reused 12 (delta 12), pack-reused 134 (from 2)
# Receiving objects: 100% (160/160), 196.36 KiB | 5.95 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/PCL

# %%
# !pip install torch torchvision
# !pip install numpy tqdm pyyaml
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.2)

# %%
import torch
print(torch.cuda.is_available())  # True
print(torch.cuda.get_device_name(0))  #GPU name
# Out:
# True
# Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = "/content/drive/My Drive/dataset"

# %%
# %cd /content/PCL
# Out:
# /content/PCL

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 72.1 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
import torch
import torch.nn as nn

# %%
import importlib
import sys
import pcl.builder as builder

# Print where the module is loaded from
print("Reloaded from:", builder.__file__)

# Force reload and confirm
builder = importlib.reload(builder)
print("After reload:", builder.__file__)

# Check if MoCo exists
print("MoCo available?", hasattr(builder, "MoCo"))

# Print id to confirm new module object
print("Module id:", id(builder))
# Out:
# Reloaded from: /content/PCL/pcl/builder.py
# After reload: /content/PCL/pcl/builder.py
# MoCo available? True
# Module id: 136997869833728

# %%
import sys
sys.path.insert(0, "/content/PCL")  # force project path

from pcl import builder
print("Builder path:", builder.__file__)
print("Has MoCo:", hasattr(builder, "MoCo"))
# Out:
# Builder path: /content/PCL/pcl/builder.py
# Has MoCo: True

# %%
import os, sys
sys.path.append('/content/PCL')

from pcl import builder
print("✅ Import worked!")

import sys
sys.path.insert(0, "/content/PCL")
# Out:
# ✅ Import worked!

# %%
# %reset -f

# %%
builder_path = "/content/PCL/pcl/builder.py"

# Read the existing builder.py
with open(builder_path, "r") as f:
    original_code = f.read()

# Only add MoCo if it's not already defined
if "class MoCo" not in original_code:
    moco_code = """
class MoCo(nn.Module):
    \"\"\"Build a MoCo model with: a query encoder, a key encoder, and a queue.\"\"\"
    def __init__(self, base_encoder, dim=128, r=16384, m=0.999, T=0.1, mlp=False):
        super(MoCo, self).__init__()
        self.r = r
        self.m = m
        self.T = T
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.encoder_q = base_encoder(num_classes=dim).to(self.device)
        self.encoder_k = base_encoder(num_classes=dim).to(self.device)

        if mlp:
            dim_mlp = self.encoder_q.fc.weight.shape[1]
            self.encoder_q.fc = nn.Sequential(nn.Linear(dim_mlp, dim_mlp), nn.ReLU(), self.encoder_q.fc)
            self.encoder_k.fc = nn.Sequential(nn.Linear(dim_mlp, dim_mlp), nn.ReLU(), self.encoder_k.fc)

        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data.copy_(param_q.data)
            param_k.requires_grad = False

        self.register_buffer("queue", torch.randn(dim, r))
        self.queue = nn.functional.normalize(self.queue, dim=0)
        self.register_buffer("queue_ptr", torch.zeros(1, dtype=torch.long))

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1. - self.m)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys):
        keys = concat_all_gather(keys)
        batch_size = keys.shape[0]
        ptr = int(self.queue_ptr)
        assert self.r % batch_size == 0
        self.queue[:, ptr:ptr + batch_size] = keys.T
        ptr = (ptr + batch_size) % self.r
        self.queue_ptr[0] = ptr

    @torch.no_grad()
    def _batch_shuffle_ddp(self, x):
        idx_unshuffle = None
        return x, idx_unshuffle

    @torch.no_grad()
    def _batch_unshuffle_ddp(self, x, idx_unshuffle):
        return x

    def forward(self, im_q, im_k=None, is_eval=False, cluster_result=None, index=None):
        im_q = im_q.to(self.device)
        if im_k is not None:
            im_k = im_k.to(self.device)
        if index is not None:
            index = index.to(self.device)

        if is_eval:
            self.encoder_k.eval()
            k = self.encoder_k(im_q)
            k = nn.functional.normalize(k, dim=1)
            return k

        with torch.no_grad():
            self._momentum_update_key_encoder()
            im_k, idx_unshuffle = self._batch_shuffle_ddp(im_k)
            k = self.encoder_k(im_k)
            k = nn.functional.normalize(k, dim=1)
            k = self._batch_unshuffle_ddp(k, idx_unshuffle)

        q = self.encoder_q(im_q)
        q = nn.functional.normalize(q, dim=1)

        l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
        l_neg = torch.einsum('nc,ck->nk', [q, self.queue.clone().detach().to(self.device)])
        logits = torch.cat([l_pos, l_neg], dim=1)
        logits /= self.T
        labels = torch.zeros(logits.shape[0], dtype=torch.long).to(self.device)
        self._dequeue_and_enqueue(k)
        return logits, labels, None, None

@torch.no_grad()
def concat_all_gather(tensor):
    return tensor
"""
    # Append the MoCo definition
    with open(builder_path, "a") as f:
        f.write("\n" + moco_code)

print("MoCo class appended to builder.py")
# Out:
# MoCo class appended to builder.py

# %%
import sys
sys.path.insert(0, "/content/PCL")

from pcl import builder
print("MoCo available?", hasattr(builder, "MoCo"))
# Out:
# MoCo available? True

# %%
# !python3 /content/PCL/main_pcl.py \
  "/content/drive/My Drive/dataset_cropped" \
  --arch resnet34 \
  --epochs 300 \
  --batch-size 32 \
  --lr 0.001 \
  --temperature 0.2 \
  --num-cluster 3
# Out:
# Streaming output truncated to the last 5000 lines.
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.54938 imbalance=1.019 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.55035 imbalance=1.015 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.54871 imbalance=1.002 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.54121 imbalance=1.089 nsplit=0
# Objective improved: keep new clusters
# Epoch: [38][0/8]	Time  5.663 ( 5.663)	Data  5.227 ( 5.227)	Loss 9.0091e+00 (9.0091e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 39 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.99s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.54403 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.58392 imbalance=1.015 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.54403 imbalance=1.093 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.57611 imbalance=1.003 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.57403 imbalance=1.004 nsplit=0
# Epoch: [39][0/8]	Time  5.498 ( 5.498)	Data  5.036 ( 5.036)	Loss 8.9369e+00 (8.9369e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 40 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.97s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.53547 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.54362 imbalance=1.058 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.53623 imbalance=1.015 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.53448 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.55774 imbalance=1.088 nsplit=0
# Epoch: [40][0/8]	Time  6.718 ( 6.718)	Data  5.976 ( 5.976)	Loss 8.9188e+00 (8.9188e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 41 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.86s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.50386 imbalance=1.138 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.48029 imbalance=1.041 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.4785 imbalance=1.001 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.47656 imbalance=1.016 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.51474 imbalance=1.163 nsplit=0
# Epoch: [41][0/8]	Time  5.209 ( 5.209)	Data  4.856 ( 4.856)	Loss 8.9189e+00 (8.9189e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 42 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.87s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.46086 imbalance=1.089 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.46498 imbalance=1.056 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.46008 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.44941 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.44868 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Epoch: [42][0/8]	Time  4.780 ( 4.780)	Data  4.379 ( 4.379)	Loss 9.0096e+00 (9.0096e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 43 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.24s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.5051 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.50437 imbalance=1.054 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.5053 imbalance=1.020 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.50527 imbalance=1.016 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.50418 imbalance=1.051 nsplit=0
# Objective improved: keep new clusters
# Epoch: [43][0/8]	Time  5.541 ( 5.541)	Data  5.214 ( 5.214)	Loss 8.9484e+00 (8.9484e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 44 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:06<00:00,  3.39s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.47368 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.48596 imbalance=1.063 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.47529 imbalance=1.039 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.02 s, search 0.01 s): objective=5.4757 imbalance=1.045 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.02 s, search 0.02 s): objective=5.48039 imbalance=1.036 nsplit=0
# Epoch: [44][0/8]	Time  6.142 ( 6.142)	Data  5.743 ( 5.743)	Loss 8.9249e+00 (8.9249e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 45 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.57s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.46791 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.50041 imbalance=1.042 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.46818 imbalance=1.049 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.49052 imbalance=1.017 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.49287 imbalance=1.019 nsplit=0
# Epoch: [45][0/8]	Time  5.258 ( 5.258)	Data  4.736 ( 4.736)	Loss 9.0277e+00 (9.0277e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 46 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.32s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.54325 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.55576 imbalance=1.031 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.54325 imbalance=1.047 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.54958 imbalance=1.017 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.55576 imbalance=1.031 nsplit=0
# Epoch: [46][0/8]	Time  4.614 ( 4.614)	Data  4.129 ( 4.129)	Loss 8.9720e+00 (8.9720e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 47 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.69s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.63265 imbalance=1.066 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.63886 imbalance=1.021 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.63362 imbalance=1.060 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.6338 imbalance=1.026 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.63886 imbalance=1.021 nsplit=0
# Epoch: [47][0/8]	Time  4.671 ( 4.671)	Data  4.213 ( 4.213)	Loss 9.0078e+00 (9.0078e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 48 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.04s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.79253 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.78235 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.79253 imbalance=1.056 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.78235 imbalance=1.035 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.78235 imbalance=1.035 nsplit=0
# Epoch: [48][0/8]	Time  6.424 ( 6.424)	Data  5.901 ( 5.901)	Loss 9.1447e+00 (9.1447e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 49 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.84s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.10872 imbalance=1.016 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.11292 imbalance=1.013 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.11838 imbalance=1.019 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.09986 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.11744 imbalance=1.011 nsplit=0
# Epoch: [49][0/8]	Time  6.307 ( 6.307)	Data  5.658 ( 5.658)	Loss 9.0310e+00 (9.0310e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 50 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:06<00:00,  3.08s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.53463 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.53106 imbalance=1.038 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.53463 imbalance=1.047 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.52689 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.52715 imbalance=1.030 nsplit=0
# Epoch: [50][0/8]	Time  4.724 ( 4.724)	Data  4.347 ( 4.347)	Loss 9.0621e+00 (9.0621e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 51 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.02s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.78725 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.75723 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.78124 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.78014 imbalance=1.012 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.78014 imbalance=1.012 nsplit=0
# Epoch: [51][0/8]	Time  5.595 ( 5.595)	Data  5.141 ( 5.141)	Loss 9.0748e+00 (9.0748e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 52 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.79s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.9114 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.2076 imbalance=1.025 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.9114 imbalance=1.006 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=6.9114 imbalance=1.006 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.20941 imbalance=1.037 nsplit=0
# Epoch: [52][0/8]	Time  6.549 ( 6.549)	Data  6.062 ( 6.062)	Loss 8.9061e+00 (8.9061e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 53 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.82s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.17043 imbalance=1.094 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.22685 imbalance=1.001 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.13608 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.05734 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=7.2478 imbalance=1.035 nsplit=0
# Epoch: [53][0/8]	Time  5.587 ( 5.587)	Data  5.233 ( 5.233)	Loss 8.9358e+00 (8.9358e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 54 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.80s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.1246 imbalance=1.120 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.17414 imbalance=1.196 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.12451 imbalance=1.133 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.15404 imbalance=1.176 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.12486 imbalance=1.118 nsplit=0
# Epoch: [54][0/8]	Time  4.750 ( 4.750)	Data  4.017 ( 4.017)	Loss 9.0138e+00 (9.0138e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 55 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.10s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.05733 imbalance=1.159 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.14267 imbalance=1.156 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.05092 imbalance=1.108 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.05771 imbalance=1.133 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.14298 imbalance=1.155 nsplit=0
# Epoch: [55][0/8]	Time  5.520 ( 5.520)	Data  5.182 ( 5.182)	Loss 8.9392e+00 (8.9392e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 56 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=6.86704 imbalance=1.098 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.89358 imbalance=1.146 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=6.86896 imbalance=1.089 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.02 s, search 0.01 s): objective=6.86835 imbalance=1.103 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.02 s, search 0.01 s): objective=6.89358 imbalance=1.146 nsplit=0
# Epoch: [56][0/8]	Time  6.466 ( 6.466)	Data  6.058 ( 6.058)	Loss 9.0349e+00 (9.0349e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 57 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.06s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.14519 imbalance=1.083 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.19919 imbalance=1.144 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.14955 imbalance=1.104 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.14516 imbalance=1.108 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.19889 imbalance=1.121 nsplit=0
# Epoch: [57][0/8]	Time  4.663 ( 4.663)	Data  4.041 ( 4.041)	Loss 8.9051e+00 (8.9051e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 58 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.95s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.1677 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.20473 imbalance=1.182 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.17026 imbalance=1.140 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.1689 imbalance=1.087 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.16811 imbalance=1.091 nsplit=0
# Epoch: [58][0/8]	Time  4.618 ( 4.618)	Data  4.262 ( 4.262)	Loss 8.9746e+00 (8.9746e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 59 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.49s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.23641 imbalance=1.106 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.27151 imbalance=1.156 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.23627 imbalance=1.117 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.24696 imbalance=1.088 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=7.26507 imbalance=1.102 nsplit=0
# Epoch: [59][0/8]	Time  5.491 ( 5.491)	Data  5.134 ( 5.134)	Loss 9.0120e+00 (9.0120e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 60 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.30s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.37419 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.39348 imbalance=1.058 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.37319 imbalance=1.055 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.37777 imbalance=1.084 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.39462 imbalance=1.056 nsplit=0
# Epoch: [60][0/8]	Time  4.802 ( 4.802)	Data  4.456 ( 4.456)	Loss 8.9470e+00 (8.9470e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 61 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.97s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.46209 imbalance=1.063 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.45877 imbalance=1.108 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.45495 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.45577 imbalance=1.046 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=7.45495 imbalance=1.034 nsplit=0
# Epoch: [61][0/8]	Time  4.663 ( 4.663)	Data  3.807 ( 3.807)	Loss 9.0263e+00 (9.0263e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 62 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.46s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.53099 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.55744 imbalance=1.048 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.5319 imbalance=1.067 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.52981 imbalance=1.067 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.54863 imbalance=1.043 nsplit=0
# Epoch: [62][0/8]	Time  4.678 ( 4.678)	Data  4.151 ( 4.151)	Loss 8.9149e+00 (8.9149e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 63 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.66s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.52429 imbalance=1.107 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.5754 imbalance=1.055 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.52495 imbalance=1.077 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.57823 imbalance=1.059 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.54315 imbalance=1.039 nsplit=0
# Epoch: [63][0/8]	Time  4.625 ( 4.625)	Data  4.184 ( 4.184)	Loss 8.8853e+00 (8.8853e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 64 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.06s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.65425 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.77058 imbalance=1.026 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.6537 imbalance=1.079 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.70332 imbalance=1.052 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=7.66899 imbalance=1.106 nsplit=0
# Epoch: [64][0/8]	Time  5.457 ( 5.457)	Data  5.089 ( 5.089)	Loss 8.8427e+00 (8.8427e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 65 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.21s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.88758 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.88054 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.80758 imbalance=1.094 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.82572 imbalance=1.063 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=7.94322 imbalance=1.058 nsplit=0
# Epoch: [65][0/8]	Time  6.114 ( 6.114)	Data  5.556 ( 5.556)	Loss 8.8546e+00 (8.8546e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 66 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.82s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.59553 imbalance=1.067 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.69764 imbalance=1.017 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.58119 imbalance=1.102 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.59262 imbalance=1.067 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.70224 imbalance=1.014 nsplit=0
# Epoch: [66][0/8]	Time  6.623 ( 6.623)	Data  6.208 ( 6.208)	Loss 8.9444e+00 (8.9444e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 67 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.89s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.84994 imbalance=1.062 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.9797 imbalance=1.011 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=7.83859 imbalance=1.081 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=7.84553 imbalance=1.075 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=7.97078 imbalance=1.005 nsplit=0
# Epoch: [67][0/8]	Time  5.967 ( 5.967)	Data  5.490 ( 5.490)	Loss 8.6830e+00 (8.6830e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 68 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.84s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.03647 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.03884 imbalance=1.049 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.01242 imbalance=1.089 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.02776 imbalance=1.062 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.03619 imbalance=1.052 nsplit=0
# Epoch: [68][0/8]	Time  4.647 ( 4.647)	Data  3.849 ( 3.849)	Loss 8.8183e+00 (8.8183e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 69 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.24s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.02337 imbalance=1.063 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.04259 imbalance=1.013 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.0364 imbalance=1.040 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.01549 imbalance=1.095 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=8.03015 imbalance=1.026 nsplit=0
# Epoch: [69][0/8]	Time  5.039 ( 5.039)	Data  4.582 ( 4.582)	Loss 8.7798e+00 (8.7798e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 70 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.05s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.13126 imbalance=1.085 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.13078 imbalance=1.096 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.16333 imbalance=1.032 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.12272 imbalance=1.102 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.13734 imbalance=1.072 nsplit=0
# Epoch: [70][0/8]	Time  6.821 ( 6.821)	Data  6.318 ( 6.318)	Loss 8.7648e+00 (8.7648e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 71 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.82s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.23843 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.24042 imbalance=1.020 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.24042 imbalance=1.020 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.25542 imbalance=1.112 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.23533 imbalance=1.044 nsplit=0
# Objective improved: keep new clusters
# Epoch: [71][0/8]	Time  5.695 ( 5.695)	Data  5.270 ( 5.270)	Loss 8.8084e+00 (8.8084e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 72 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.82s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.31773 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.35782 imbalance=1.017 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.31906 imbalance=1.032 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.31723 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.31334 imbalance=1.064 nsplit=0
# Objective improved: keep new clusters
# Epoch: [72][0/8]	Time  4.801 ( 4.801)	Data  4.413 ( 4.413)	Loss 8.6962e+00 (8.6962e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 73 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.01s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.47778 imbalance=1.076 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.49635 imbalance=1.036 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.49635 imbalance=1.036 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.48011 imbalance=1.095 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.83157 imbalance=1.118 nsplit=0
# Epoch: [73][0/8]	Time  4.681 ( 4.681)	Data  3.917 ( 3.917)	Loss 8.5720e+00 (8.5720e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 74 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.54s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.53646 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.53491 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.53491 imbalance=1.025 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.5214 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.52534 imbalance=1.069 nsplit=0
# Epoch: [74][0/8]	Time  4.739 ( 4.739)	Data  4.379 ( 4.379)	Loss 8.6852e+00 (8.6852e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 75 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.01s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.5516 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.59045 imbalance=1.013 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.55063 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.5477 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.5516 imbalance=1.030 nsplit=0
# Epoch: [75][0/8]	Time  7.137 ( 7.137)	Data  6.654 ( 6.654)	Loss 8.5993e+00 (8.5993e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 76 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.82s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.78411 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.79579 imbalance=1.050 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=8.7726 imbalance=1.057 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=8.77356 imbalance=1.060 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.105 imbalance=1.105 nsplit=0
# Epoch: [76][0/8]	Time  4.723 ( 4.723)	Data  4.333 ( 4.333)	Loss 8.6805e+00 (8.6805e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 77 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.65s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.25788 imbalance=1.137 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.44895 imbalance=1.049 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=9.26381 imbalance=1.100 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=9.28249 imbalance=1.160 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.02 s, search 0.01 s): objective=9.44327 imbalance=1.093 nsplit=0
# Epoch: [77][0/8]	Time  6.177 ( 6.177)	Data  5.588 ( 5.588)	Loss 8.5673e+00 (8.5673e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 78 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.11s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.25053 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.28008 imbalance=1.034 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.25108 imbalance=1.043 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.26073 imbalance=1.067 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.59243 imbalance=1.015 nsplit=0
# Epoch: [78][0/8]	Time  4.724 ( 4.724)	Data  4.396 ( 4.396)	Loss 8.7006e+00 (8.7006e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 79 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.84s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.19423 imbalance=1.051 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.22086 imbalance=1.015 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.19086 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.19108 imbalance=1.050 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.23085 imbalance=1.017 nsplit=0
# Epoch: [79][0/8]	Time  4.751 ( 4.751)	Data  4.254 ( 4.254)	Loss 8.5773e+00 (8.5773e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 80 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.39s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.3397 imbalance=1.038 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.3501 imbalance=1.003 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=9.33497 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=9.33527 imbalance=1.002 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.02 s, search 0.01 s): objective=9.69019 imbalance=1.063 nsplit=0
# Epoch: [80][0/8]	Time  5.702 ( 5.702)	Data  5.119 ( 5.119)	Loss 8.4434e+00 (8.4434e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 81 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.35s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.61348 imbalance=1.063 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.62691 imbalance=1.032 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.62627 imbalance=1.026 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.62501 imbalance=1.034 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.63861 imbalance=1.033 nsplit=0
# Epoch: [81][0/8]	Time  5.446 ( 5.446)	Data  4.950 ( 4.950)	Loss 8.5439e+00 (8.5439e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 82 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.45s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.70855 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.71481 imbalance=1.011 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.70582 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.71481 imbalance=1.011 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.70785 imbalance=1.029 nsplit=0
# Epoch: [82][0/8]	Time  4.651 ( 4.651)	Data  4.166 ( 4.166)	Loss 8.6240e+00 (8.6240e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 83 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.62s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.81711 imbalance=1.064 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.83223 imbalance=1.022 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=9.82269 imbalance=1.046 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.81539 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=9.88088 imbalance=1.037 nsplit=0
# Epoch: [83][0/8]	Time  4.804 ( 4.804)	Data  4.445 ( 4.445)	Loss 8.7165e+00 (8.7165e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 84 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.09s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=10.1492 imbalance=1.117 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=10.3118 imbalance=1.126 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=10.1448 imbalance=1.050 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=10.1227 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=10.3115 imbalance=1.126 nsplit=0
# Epoch: [84][0/8]	Time  6.819 ( 6.819)	Data  6.472 ( 6.472)	Loss 8.3749e+00 (8.3749e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 85 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.14s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# ...
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.7429 imbalance=1.004 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.7308 imbalance=1.013 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.7429 imbalance=1.004 nsplit=0
# Epoch: [284][0/8]	Time  4.781 ( 4.781)	Data  4.413 ( 4.413)	Loss 7.5131e+00 (7.5131e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 285 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.99s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.67927 imbalance=1.017 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.67927 imbalance=1.017 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.67927 imbalance=1.017 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.67927 imbalance=1.017 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.67927 imbalance=1.017 nsplit=0
# Epoch: [285][0/8]	Time  5.624 ( 5.624)	Data  5.291 ( 5.291)	Loss 7.6060e+00 (7.6060e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 286 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.07s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.43821 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.43389 imbalance=1.017 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.43821 imbalance=1.006 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.43434 imbalance=1.012 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=5.43821 imbalance=1.006 nsplit=0
# Epoch: [286][0/8]	Time  4.769 ( 4.769)	Data  4.380 ( 4.380)	Loss 7.5745e+00 (7.5745e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 287 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.44s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.37745 imbalance=1.004 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.36812 imbalance=1.021 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.37745 imbalance=1.004 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.36894 imbalance=1.015 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.37745 imbalance=1.004 nsplit=0
# Epoch: [287][0/8]	Time  4.654 ( 4.654)	Data  4.277 ( 4.277)	Loss 7.5060e+00 (7.5060e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 288 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:06<00:00,  3.00s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.7689 imbalance=1.003 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.77348 imbalance=1.023 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.7689 imbalance=1.003 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.02 s, search 0.01 s): objective=4.7689 imbalance=1.003 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.02 s, search 0.01 s): objective=4.76864 imbalance=1.004 nsplit=0
# Objective improved: keep new clusters
# Epoch: [288][0/8]	Time  5.002 ( 5.002)	Data  4.469 ( 4.469)	Loss 7.5656e+00 (7.5656e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 289 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.88s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.8871 imbalance=1.004 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.88809 imbalance=1.017 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.88775 imbalance=1.005 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.88771 imbalance=1.013 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.8871 imbalance=1.004 nsplit=0
# Epoch: [289][0/8]	Time  7.075 ( 7.075)	Data  6.628 ( 6.628)	Loss 7.9409e+00 (7.9409e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 290 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.94s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.01844 imbalance=1.004 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.01761 imbalance=1.015 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=5.01844 imbalance=1.004 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.0163 imbalance=1.011 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=5.01856 imbalance=1.005 nsplit=0
# Epoch: [290][0/8]	Time  7.331 ( 7.331)	Data  6.902 ( 6.902)	Loss 7.4742e+00 (7.4742e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 291 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.88s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.64577 imbalance=1.005 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.64886 imbalance=1.019 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.64577 imbalance=1.005 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.64673 imbalance=1.010 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.64577 imbalance=1.005 nsplit=0
# Epoch: [291][0/8]	Time  5.677 ( 5.677)	Data  4.860 ( 4.860)	Loss 7.4507e+00 (7.4507e+00)	Acc@Inst   9.38 (  9.38)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 292 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.88s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.67986 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.67998 imbalance=1.015 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.67748 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.67775 imbalance=1.007 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.68117 imbalance=1.010 nsplit=0
# Epoch: [292][0/8]	Time  4.785 ( 4.785)	Data  4.432 ( 4.432)	Loss 7.4935e+00 (7.4935e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 293 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.27s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.51569 imbalance=1.012 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.51532 imbalance=1.015 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.51472 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.51668 imbalance=1.011 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.51709 imbalance=1.010 nsplit=0
# Epoch: [293][0/8]	Time  4.910 ( 4.910)	Data  4.501 ( 4.501)	Loss 7.7267e+00 (7.7267e+00)	Acc@Inst   9.38 (  9.38)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 294 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.39s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.71379 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.71422 imbalance=1.021 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.71214 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.71014 imbalance=1.012 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.71415 imbalance=1.010 nsplit=0
# Epoch: [294][0/8]	Time  4.597 ( 4.597)	Data  3.910 ( 3.910)	Loss 7.5851e+00 (7.5851e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 295 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.10s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.54739 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.54938 imbalance=1.026 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.54421 imbalance=1.014 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.54568 imbalance=1.023 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.54442 imbalance=1.015 nsplit=0
# Epoch: [295][0/8]	Time  6.135 ( 6.135)	Data  5.193 ( 5.193)	Loss 7.6761e+00 (7.6761e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 296 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.90s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.46541 imbalance=1.014 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.46627 imbalance=1.032 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.46569 imbalance=1.015 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.46589 imbalance=1.025 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.46569 imbalance=1.015 nsplit=0
# Epoch: [296][0/8]	Time  4.862 ( 4.862)	Data  4.437 ( 4.437)	Loss 7.6524e+00 (7.6524e+00)	Acc@Inst   9.38 (  9.38)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 297 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.06s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.62426 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.62426 imbalance=1.029 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.62337 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.6214 imbalance=1.015 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.62188 imbalance=1.011 nsplit=0
# Epoch: [297][0/8]	Time  4.804 ( 4.804)	Data  4.472 ( 4.472)	Loss 7.4013e+00 (7.4013e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 298 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.46s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.6591 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.65961 imbalance=1.032 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.66154 imbalance=1.007 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.6591 imbalance=1.026 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=4.66154 imbalance=1.007 nsplit=0
# Epoch: [298][0/8]	Time  4.673 ( 4.673)	Data  3.997 ( 3.997)	Loss 7.6561e+00 (7.6561e+00)	Acc@Inst   9.38 (  9.38)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 299 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:05<00:00,  2.71s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.30099 imbalance=1.024 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.30062 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=4.29967 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.29889 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=4.29889 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Epoch: [299][0/8]	Time  6.831 ( 6.831)	Data  6.509 ( 6.509)	Loss 7.7859e+00 (7.7859e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)

# %%
# --- Install dependencies ---
# !pip install faiss-cpu umap-learn scikit-learn matplotlib

import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, silhouette_score
import numpy as np
import umap
import glob
from pcl import builder
import torchvision.models as models

# --- Find latest checkpoint ---
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]  # latest checkpoint
print("Using checkpoint:", checkpoint_path)

# --- Manually set args used in training ---
arch = "resnet34"
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.2
mlp = True

# --- Build MoCo model ---
model = builder.MoCo(
    models.__dict__[arch],
    low_dim,
    pcl_r,
    moco_m,
    temperature,
    mlp
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = ckpt['state_dict']
state_dict = {k: v for k, v in state_dict.items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# --- Dataset & DataLoader ---
data_path = "/content/drive/MyDrive/dataset_cropped"
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(data_path, transform)
loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=4)

# --- Feature extraction ---
all_features = []
all_labels = []

with torch.no_grad():
    for imgs, labels in loader:
        imgs = imgs.cuda(non_blocking=True)
        feats = model.encoder_q(imgs)  # MoCo encoder
        feats = torch.nn.functional.normalize(feats, dim=1)
        all_features.append(feats.cpu())
        all_labels.append(labels)

all_features = torch.cat(all_features, dim=0).numpy()
all_labels = torch.cat(all_labels, dim=0).numpy()

# --- t-SNE Visualization ---
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_embeds = tsne.fit_transform(all_features)

plt.figure(figsize=(8, 8))
scatter = plt.scatter(tsne_embeds[:, 0], tsne_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("t-SNE of MoCo Embeddings")
plt.show()

# --- UMAP Visualization ---
umap_embeds = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(all_features)
plt.figure(figsize=(8, 8))
scatter = plt.scatter(umap_embeds[:, 0], umap_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("UMAP of MoCo Embeddings")
plt.show()

# --- Clustering Metrics ---
nmi = normalized_mutual_info_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
ari = adjusted_rand_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
sil = silhouette_score(all_features, all_labels)

print(f"NMI: {nmi:.4f}")
print(f"ARI: {ari:.4f}")
print(f"Silhouette Score: {sil:.4f}")
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (0.5.9.post2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (1.16.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# NMI: 0.2360
# ARI: 0.0000
# Silhouette Score: 0.0013

# %%
import torch
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import glob
from pcl import builder
import torchvision.models as models

# -------------------------------
# Load latest checkpoint
# -------------------------------
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]
print("Using checkpoint:", checkpoint_path)

# --- MoCo args (ResNet-34 backbone) ---
arch = "resnet34"
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.2
mlp = True

# --- Build MoCo model ---
model = builder.MoCo(
    models.__dict__[arch],
    low_dim,
    pcl_r,
    moco_m,
    temperature,
    mlp
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = ckpt['state_dict']
state_dict = {k: v for k, v in state_dict.items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# -------------------------------
# Dataset & DataLoader
# -------------------------------
train_dir = "/content/drive/My Drive/dataset_cropped/train"
test_dir  = "/content/drive/My Drive/dataset_cropped/test"

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(train_dir, transform=transform)
test_dataset  = datasets.ImageFolder(test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False, num_workers=4)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))

# -------------------------------
# Feature Extraction
# -------------------------------
def extract_features(dataloader):
    features, labels = [], []
    with torch.no_grad():
        for imgs, lbls in dataloader:
            imgs = imgs.cuda(non_blocking=True)
            feats = model.encoder_q(imgs)  # use MoCo encoder_q
            feats = F.normalize(feats, dim=1)  # normalize embeddings
            features.append(feats.cpu())
            labels.append(lbls)
    return torch.cat(features), torch.cat(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels   = extract_features(test_loader)

# -------------------------------
# Centroid-based Classification
# -------------------------------
def compute_centroids(features, labels, num_classes):
    centroids = []
    for c in range(num_classes):
        mask = labels == c
        class_feats = features[mask]
        centroid = class_feats.mean(dim=0)
        centroids.append(centroid)
    return torch.stack(centroids)

num_classes = len(train_dataset.classes)
centroids = compute_centroids(train_features, train_labels, num_classes)
centroids = F.normalize(centroids, dim=1)

def predict_with_centroids(test_feats, centroids):
    sims = test_feats @ centroids.T  # cosine similarity
    preds = torch.argmax(sims, dim=1)
    return preds

pred_labels = predict_with_centroids(test_features, centroids)

# -------------------------------
# Evaluation Metrics
# -------------------------------
y_true = test_labels.numpy()
y_pred = pred_labels.numpy()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average="macro")
recall = recall_score(y_true, y_pred, average="macro")  # Sensitivity
f1 = f1_score(y_true, y_pred, average="macro")

# Specificity per class
cm = confusion_matrix(y_true, y_pred)
specificity = []
for i in range(num_classes):
    tn = cm.sum() - (cm[i,:].sum() + cm[:,i].sum() - cm[i,i])
    fp = cm[:,i].sum() - cm[i,i]
    specificity.append(tn / (tn + fp))
specificity = np.mean(specificity)

# -------------------------------
# Print Results
# -------------------------------
print("Confusion Matrix:\n", cm)
print(f"Accuracy:     {acc:.16f}")
print(f"Precision:    {precision:.16f}")
print(f"Sensitivity:  {recall:.16f}")
print(f"F1 Score:     {f1:.16f}")
print(f"Specificity:  {specificity:.16f}")
# Out:
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# Train size: 279
# Test size: 39
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Confusion Matrix:
#  [[ 9  3  1]
#  [12  1  0]
#  [ 1  1 11]]
# Accuracy:     0.5384615384615384
# Precision:    0.5085858585858586
# Sensitivity:  0.5384615384615384
# F1 Score:     0.5017989417989418
# Specificity:  0.7692307692307693
