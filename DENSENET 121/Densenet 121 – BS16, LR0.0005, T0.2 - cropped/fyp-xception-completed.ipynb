# %%
# !git clone https://github.com/salesforce/PCL.git
# %cd PCL
# Out:
# Cloning into 'PCL'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 160 (delta 18), reused 12 (delta 12), pack-reused 134 (from 2)
# Receiving objects: 100% (160/160), 196.36 KiB | 7.01 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/PCL

# %%
# !pip install torch torchvision
# !pip install numpy tqdm pyyaml
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.2)

# %%
#install xception
# !pip install timm
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (1.0.19)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from timm) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm) (0.23.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm) (0.34.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.1.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->timm) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2025.8.3)

# %%
import torch
print(torch.cuda.is_available())  # True
print(torch.cuda.get_device_name(0))  #GPU name
# Out:
# True
# Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = "/content/drive/My Drive/dataset"

# %%
# %cd /content/PCL
# Out:
# /content/PCL

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 73.8 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
import torch
import torch.nn as nn

# %%
import importlib
import sys
import pcl.builder as builder

# Print where the module is loaded from
print("Reloaded from:", builder.__file__)

# Force reload and confirm
builder = importlib.reload(builder)
print("After reload:", builder.__file__)

# Check if MoCo exists
print("MoCo available?", hasattr(builder, "MoCo"))

# Print id to confirm new module object
print("Module id:", id(builder))
# Out:
# Reloaded from: /content/PCL/pcl/builder.py
# After reload: /content/PCL/pcl/builder.py
# MoCo available? True
# Module id: 131947705056240

# %%
import sys
sys.path.insert(0, "/content/PCL")  # force project path

from pcl import builder
print("Builder path:", builder.__file__)
print("Has MoCo:", hasattr(builder, "MoCo"))
# Out:
# Builder path: /content/PCL/pcl/builder.py
# Has MoCo: True

# %%
import os, sys
sys.path.append('/content/PCL')

from pcl import builder
print("✅ Import worked!")

import sys
sys.path.insert(0, "/content/PCL")
# Out:
# ✅ Import worked!

# %%
# %reset -f

# %%
builder_path = "/content/PCL/pcl/builder.py"

# Read builder.py
with open(builder_path, "r") as f:
    original_code = f.read()

# Ensure imports exist
imports_to_add = []
if "import timm" not in original_code:
    imports_to_add.append("import timm")
if "import torch" not in original_code:
    imports_to_add.append("import torch")
if "import torch.nn as nn" not in original_code:
    imports_to_add.append("import torch.nn as nn")

# Only add MoCo if it's not already defined
if "class MoCo" not in original_code:
    moco_code = """
class MoCo(nn.Module):
    \"\"\"MoCo with legacy_xception.tf_in1k backbone.\"\"\"
    def __init__(self, base_encoder=None, dim=128, r=16384, m=0.999, T=0.1, mlp=False):
        super(MoCo, self).__init__()
        self.r = r
        self.T = T
        self.m = m

        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # Query & key encoders (Xception backbone from timm)
        self.encoder_q = timm.create_model("legacy_xception", pretrained=True, num_classes=dim).to(self.device)
        self.encoder_k = timm.create_model("legacy_xception", pretrained=True, num_classes=dim).to(self.device)

        # Optionally replace classifier with MLP head
        if mlp:
            dim_mlp = self.encoder_q.classifier.in_features
            self.encoder_q.classifier = nn.Sequential(
                nn.Linear(dim_mlp, dim_mlp), nn.ReLU(), nn.Linear(dim_mlp, dim)
            )
            self.encoder_k.classifier = nn.Sequential(
                nn.Linear(dim_mlp, dim_mlp), nn.ReLU(), nn.Linear(dim_mlp, dim)
            )

        # initialize key encoder to be the same as query encoder, and freeze it
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data.copy_(param_q.data)
            param_k.requires_grad = False

        # queue for negative samples
        self.register_buffer("queue", torch.randn(dim, r))
        self.queue = nn.functional.normalize(self.queue, dim=0)
        self.register_buffer("queue_ptr", torch.zeros(1, dtype=torch.long))

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1. - self.m)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys):
        keys = concat_all_gather(keys)
        batch_size = keys.shape[0]
        ptr = int(self.queue_ptr)
        assert self.r % batch_size == 0, "Queue size must be divisible by batch size"
        self.queue[:, ptr:ptr + batch_size] = keys.T
        ptr = (ptr + batch_size) % self.r
        self.queue_ptr[0] = ptr

    @torch.no_grad()
    def _batch_shuffle_ddp(self, x):
        idx_unshuffle = None
        return x, idx_unshuffle

    @torch.no_grad()
    def _batch_unshuffle_ddp(self, x, idx_unshuffle):
        return x

    def forward(self, im_q, im_k=None, is_eval=False, cluster_result=None, index=None):
        im_q = im_q.to(self.device)
        if im_k is not None:
            im_k = im_k.to(self.device)
        if index is not None:
            index = index.to(self.device)

        if is_eval:
            self.encoder_k.eval()
            k = self.encoder_k(im_q)
            k = nn.functional.normalize(k, dim=1)
            return k

        with torch.no_grad():
            self._momentum_update_key_encoder()
            im_k, idx_unshuffle = self._batch_shuffle_ddp(im_k)
            k = self.encoder_k(im_k)
            k = nn.functional.normalize(k, dim=1)
            k = self._batch_unshuffle_ddp(k, idx_unshuffle)

        q = self.encoder_q(im_q)
        q = nn.functional.normalize(q, dim=1)

        l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
        l_neg = torch.einsum('nc,ck->nk', [q, self.queue.clone().detach().to(self.device)])
        logits = torch.cat([l_pos, l_neg], dim=1)
        logits /= self.T
        labels = torch.zeros(logits.shape[0], dtype=torch.long).to(self.device)

        self._dequeue_and_enqueue(k)
        return logits, labels, None, None


@torch.no_grad()
def concat_all_gather(tensor):
    return tensor
"""

    # Add missing imports + MoCo
    with open(builder_path, "a") as f:
        if imports_to_add:
            f.write("\n" + "\n".join(imports_to_add) + "\n")
        f.write("\n" + moco_code)

print("MoCo class with Xception backbone appended to builder.py")
# Out:
# MoCo class with Xception backbone appended to builder.py

# %%
import sys
sys.path.insert(0, "/content/PCL")

from pcl import builder
print("MoCo available?", hasattr(builder, "MoCo"))
# Out:
# MoCo available? True

# %%
import timm
print("Does 'xception' exist?", 'xception' in timm.list_models())
model = timm.create_model("legacy_xception.tf_in1k", pretrained=True)
# Out:
# Does 'xception' exist? False

# %%
# !python3 /content/PCL/main_pcl.py \
  "/content/drive/My Drive/dataset_cropped" \
  --arch legacy_xception.tf_in1k \
  --epochs 300 \
  --batch-size 16 \
  --lr 0.0005 \
  --temperature 0.2 \
  --num-cluster 3
# Out:
# Streaming output truncated to the last 5000 lines.
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=121.102 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=121.12 imbalance=1.081 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=121.053 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=121.228 imbalance=1.110 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=128.383 imbalance=1.005 nsplit=0
# Epoch: [12][ 0/17]	Time  6.239 ( 6.239)	Data  5.822 ( 5.822)	Loss 7.7469e+00 (7.7469e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 13 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.56s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=97.6583 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=97.8025 imbalance=1.100 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=97.987 imbalance=1.102 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=97.651 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=97.9083 imbalance=1.102 nsplit=0
# Epoch: [13][ 0/17]	Time  6.119 ( 6.119)	Data  5.110 ( 5.110)	Loss 7.9584e+00 (7.9584e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 14 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.33s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=94.8325 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=97.6004 imbalance=1.299 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=94.7739 imbalance=1.046 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=94.897 imbalance=1.052 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=94.8122 imbalance=1.039 nsplit=0
# Epoch: [14][ 0/17]	Time  7.736 ( 7.736)	Data  6.491 ( 6.491)	Loss 7.9528e+00 (7.9528e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 15 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.45s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=105.559 imbalance=1.157 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=105.45 imbalance=1.165 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=104.927 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=104.854 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=104.854 imbalance=1.061 nsplit=0
# Epoch: [15][ 0/17]	Time  7.004 ( 7.004)	Data  6.106 ( 6.106)	Loss 8.0172e+00 (8.0172e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 16 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.63s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=116.92 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=116.92 imbalance=1.068 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=116.896 imbalance=1.067 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=116.607 imbalance=1.038 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=116.607 imbalance=1.038 nsplit=0
# Epoch: [16][ 0/17]	Time  5.941 ( 5.941)	Data  5.236 ( 5.236)	Loss 7.9533e+00 (7.9533e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 17 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.41s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=114.837 imbalance=1.085 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=114.837 imbalance=1.085 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=115.41 imbalance=1.204 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=114.69 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=114.738 imbalance=1.036 nsplit=0
# Epoch: [17][ 0/17]	Time  8.054 ( 8.054)	Data  7.575 ( 7.575)	Loss 8.1190e+00 (8.1190e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 18 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.45s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.9792 imbalance=1.054 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.9502 imbalance=1.058 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=87.2665 imbalance=1.043 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=87.1497 imbalance=1.016 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=87.1108 imbalance=1.011 nsplit=0
# Epoch: [18][ 0/17]	Time  6.744 ( 6.744)	Data  5.798 ( 5.798)	Loss 8.3779e+00 (8.3779e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 19 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.56s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=106.197 imbalance=1.051 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=106.219 imbalance=1.048 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=106.202 imbalance=1.074 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=106.191 imbalance=1.051 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=106.197 imbalance=1.064 nsplit=0
# Epoch: [19][ 0/17]	Time  5.954 ( 5.954)	Data  5.432 ( 5.432)	Loss 8.4306e+00 (8.4306e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 20 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.43s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=103.007 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=102.608 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=102.917 imbalance=1.074 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=102.479 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=102.437 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Epoch: [20][ 0/17]	Time  8.143 ( 8.143)	Data  7.635 ( 7.635)	Loss 8.4340e+00 (8.4340e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 21 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.73s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.173 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=99.9174 imbalance=1.044 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.164 imbalance=1.040 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=99.5589 imbalance=1.057 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=100.198 imbalance=1.021 nsplit=0
# Epoch: [21][ 0/17]	Time  5.828 ( 5.828)	Data  5.281 ( 5.281)	Loss 8.1945e+00 (8.1945e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 22 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.57s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=125.239 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=125.041 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=125.058 imbalance=1.017 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=125.063 imbalance=1.026 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=125.043 imbalance=1.022 nsplit=0
# Epoch: [22][ 0/17]	Time  5.921 ( 5.921)	Data  4.979 ( 4.979)	Loss 8.2958e+00 (8.2958e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 23 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.30s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=157.782 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=155.629 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=154.599 imbalance=1.081 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=158.696 imbalance=1.081 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=158.696 imbalance=1.081 nsplit=0
# Epoch: [23][ 0/17]	Time  7.957 ( 7.957)	Data  7.181 ( 7.181)	Loss 8.4003e+00 (8.4003e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 24 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.37s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=110.261 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=110.133 imbalance=1.036 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=110.199 imbalance=1.019 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=110.101 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=110.181 imbalance=1.019 nsplit=0
# Epoch: [24][ 0/17]	Time  7.160 ( 7.160)	Data  6.757 ( 6.757)	Loss 8.4529e+00 (8.4529e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 25 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.65s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=113.545 imbalance=1.091 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=113.545 imbalance=1.091 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=114.281 imbalance=1.057 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=115.739 imbalance=1.051 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=113.512 imbalance=1.044 nsplit=0
# Objective improved: keep new clusters
# Epoch: [25][ 0/17]	Time  5.939 ( 5.939)	Data  5.293 ( 5.293)	Loss 8.2411e+00 (8.2411e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 26 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.35s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=81.5875 imbalance=1.059 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=81.5875 imbalance=1.059 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=81.6554 imbalance=1.050 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=81.6338 imbalance=1.049 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=81.6725 imbalance=1.055 nsplit=0
# Epoch: [26][ 0/17]	Time  7.881 ( 7.881)	Data  7.273 ( 7.273)	Loss 8.4505e+00 (8.4505e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 27 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.42s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=124.287 imbalance=1.018 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=124.298 imbalance=1.017 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=124.298 imbalance=1.015 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=124.262 imbalance=1.000 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=124.15 imbalance=1.009 nsplit=0
# Objective improved: keep new clusters
# Epoch: [27][ 0/17]	Time  6.725 ( 6.725)	Data  6.307 ( 6.307)	Loss 8.5174e+00 (8.5174e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 28 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.59s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=145.775 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=144.791 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=144.791 imbalance=1.075 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=145.026 imbalance=1.059 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=144.767 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Epoch: [28][ 0/17]	Time  6.524 ( 6.524)	Data  5.861 ( 5.861)	Loss 8.4288e+00 (8.4288e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 29 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.6919 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.6919 imbalance=1.045 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.6934 imbalance=1.048 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=86.7372 imbalance=1.051 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=86.6919 imbalance=1.045 nsplit=0
# Epoch: [29][ 0/17]	Time  7.942 ( 7.942)	Data  7.142 ( 7.142)	Loss 8.2324e+00 (8.2324e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 30 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:07<00:00,  1.96s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=78.5367 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=78.5367 imbalance=1.060 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=78.4097 imbalance=1.005 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=78.4019 imbalance=1.007 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=78.4096 imbalance=1.010 nsplit=0
# Epoch: [30][ 0/17]	Time  6.044 ( 6.044)	Data  5.428 ( 5.428)	Loss 8.4393e+00 (8.4393e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 31 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.32s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=85.3945 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=85.4196 imbalance=1.075 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=84.9539 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=85.5405 imbalance=1.022 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=84.8774 imbalance=1.002 nsplit=0
# Objective improved: keep new clusters
# Epoch: [31][ 0/17]	Time  7.163 ( 7.163)	Data  6.286 ( 6.286)	Loss 8.2992e+00 (8.2992e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 32 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=109.037 imbalance=1.064 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=108.63 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=108.63 imbalance=1.047 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=108.632 imbalance=1.046 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=108.63 imbalance=1.047 nsplit=0
# Epoch: [32][ 0/17]	Time  7.313 ( 7.313)	Data  6.701 ( 6.701)	Loss 8.3385e+00 (8.3385e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 33 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:07<00:00,  1.81s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.8284 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.8284 imbalance=1.088 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.8303 imbalance=1.083 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=86.8303 imbalance=1.083 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=87.1574 imbalance=1.070 nsplit=0
# Epoch: [33][ 0/17]	Time  6.897 ( 6.897)	Data  6.413 ( 6.413)	Loss 8.3904e+00 (8.3904e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 34 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=95.8075 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=96.2874 imbalance=1.140 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=96.4504 imbalance=1.117 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=95.8049 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=95.8117 imbalance=1.060 nsplit=0
# Epoch: [34][ 0/17]	Time  7.842 ( 7.842)	Data  7.315 ( 7.315)	Loss 8.5267e+00 (8.5267e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 35 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.67s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.2006 imbalance=1.193 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.1986 imbalance=1.201 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=88.0635 imbalance=1.092 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=87.3676 imbalance=1.090 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=87.3555 imbalance=1.068 nsplit=0
# Objective improved: keep new clusters
# Epoch: [35][ 0/17]	Time  6.363 ( 6.363)	Data  5.925 ( 5.925)	Loss 8.5864e+00 (8.5864e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 36 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.54s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=81.5236 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=81.5236 imbalance=1.093 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=81.3313 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=81.3142 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=81.3201 imbalance=1.022 nsplit=0
# Epoch: [36][ 0/17]	Time  5.966 ( 5.966)	Data  4.948 ( 4.948)	Loss 8.4393e+00 (8.4393e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 37 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.446 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.4628 imbalance=1.040 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=86.8793 imbalance=1.005 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=86.5598 imbalance=1.028 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=86.446 imbalance=1.032 nsplit=0
# Epoch: [37][ 0/17]	Time  7.843 ( 7.843)	Data  7.260 ( 7.260)	Loss 8.4226e+00 (8.4226e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 38 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.41s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=92.3365 imbalance=1.053 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=92.3964 imbalance=1.060 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=92.5377 imbalance=1.016 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=92.5698 imbalance=1.019 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=92.2666 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Epoch: [38][ 0/17]	Time  7.285 ( 7.285)	Data  6.731 ( 6.731)	Loss 8.6038e+00 (8.6038e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 39 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.47s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.8431 imbalance=1.063 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.6539 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.5097 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=88.5051 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=88.5068 imbalance=1.012 nsplit=0
# Epoch: [39][ 0/17]	Time  5.810 ( 5.810)	Data  5.329 ( 5.329)	Loss 8.2106e+00 (8.2106e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 40 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=87.8175 imbalance=1.024 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=87.9718 imbalance=1.018 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=87.8284 imbalance=1.024 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=87.8175 imbalance=1.024 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=87.8178 imbalance=1.023 nsplit=0
# Epoch: [40][ 0/17]	Time  8.077 ( 8.077)	Data  7.549 ( 7.549)	Loss 8.0423e+00 (8.0423e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 41 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.57s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=61.1716 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=61.1716 imbalance=1.048 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=61.2084 imbalance=1.053 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=61.1494 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=61.2278 imbalance=1.041 nsplit=0
# Epoch: [41][ 0/17]	Time  6.270 ( 6.270)	Data  5.822 ( 5.822)	Loss 8.2703e+00 (8.2703e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 42 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.59s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=81.1856 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=82.0274 imbalance=1.182 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=81.2489 imbalance=1.076 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=82.2247 imbalance=1.155 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=82.1059 imbalance=1.134 nsplit=0
# Epoch: [42][ 0/17]	Time  5.985 ( 5.985)	Data  5.571 ( 5.571)	Loss 8.4518e+00 (8.4518e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 43 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.30s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=90.5419 imbalance=1.204 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.9555 imbalance=1.044 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=89.0613 imbalance=1.054 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=90.5366 imbalance=1.201 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=93.443 imbalance=1.025 nsplit=0
# Epoch: [43][ 0/17]	Time  7.983 ( 7.983)	Data  6.470 ( 6.470)	Loss 8.5385e+00 (8.5385e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 44 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=87.7267 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=87.691 imbalance=1.073 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=87.575 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=87.9371 imbalance=1.076 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=87.7279 imbalance=1.060 nsplit=0
# Epoch: [44][ 0/17]	Time  7.355 ( 7.355)	Data  6.814 ( 6.814)	Loss 8.3254e+00 (8.3254e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 45 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:07<00:00,  1.78s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=84.6884 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=84.6183 imbalance=1.063 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=84.8988 imbalance=1.059 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=84.6147 imbalance=1.065 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=85.05 imbalance=1.010 nsplit=0
# Epoch: [45][ 0/17]	Time  5.890 ( 5.890)	Data  5.048 ( 5.048)	Loss 8.4749e+00 (8.4749e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 46 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.32s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=78.7319 imbalance=1.053 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=79.754 imbalance=1.185 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=79.9989 imbalance=1.095 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=81.1844 imbalance=1.013 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=78.7319 imbalance=1.053 nsplit=0
# Epoch: [46][ 0/17]	Time  7.689 ( 7.689)	Data  7.039 ( 7.039)	Loss 8.2501e+00 (8.2501e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 47 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.42s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=72.7334 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=72.7871 imbalance=1.080 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.1351 imbalance=1.100 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=72.6743 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=72.6713 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Epoch: [47][ 0/17]	Time  6.764 ( 6.764)	Data  6.343 ( 6.343)	Loss 8.4034e+00 (8.4034e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 48 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.69s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=51.1869 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=51.179 imbalance=1.044 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=51.041 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=51.041 imbalance=1.037 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=51.0626 imbalance=1.029 nsplit=0
# Epoch: [48][ 0/17]	Time  6.560 ( 6.560)	Data  5.911 ( 5.911)	Loss 8.3366e+00 (8.3366e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 49 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=54.2722 imbalance=1.022 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=54.2451 imbalance=1.022 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=54.2793 imbalance=1.012 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=54.2341 imbalance=1.020 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=54.2793 imbalance=1.012 nsplit=0
# Epoch: [49][ 0/17]	Time  7.792 ( 7.792)	Data  6.333 ( 6.333)	Loss 8.9338e+00 (8.9338e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 50 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:07<00:00,  1.89s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.0811 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.0737 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.0795 imbalance=1.032 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=47.0975 imbalance=1.039 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=47.0811 imbalance=1.029 nsplit=0
# Epoch: [50][ 0/17]	Time  6.061 ( 6.061)	Data  5.580 ( 5.580)	Loss 7.9866e+00 (7.9866e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 51 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.44s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=52.8942 imbalance=1.053 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=52.8942 imbalance=1.053 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=52.7388 imbalance=1.039 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=52.8894 imbalance=1.055 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=52.7626 imbalance=1.045 nsplit=0
# Epoch: [51][ 0/17]	Time  6.006 ( 6.006)	Data  4.738 ( 4.738)	Loss 8.3429e+00 (8.3429e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 52 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.981 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.9809 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.9489 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=47.9555 imbalance=1.022 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=47.955 imbalance=1.021 nsplit=0
# Epoch: [52][ 0/17]	Time  7.832 ( 7.832)	Data  7.378 ( 7.378)	Loss 8.3604e+00 (8.3604e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 53 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.41s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=48.8401 imbalance=1.133 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=48.8401 imbalance=1.133 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=48.594 imbalance=1.033 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=48.6144 imbalance=1.048 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=48.6144 imbalance=1.048 nsplit=0
# Epoch: [53][ 0/17]	Time  7.047 ( 7.047)	Data  6.468 ( 6.468)	Loss 8.2515e+00 (8.2515e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 54 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.50s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=52.4806 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=52.3463 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=52.8302 imbalance=1.100 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=52.3245 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=52.5461 imbalance=1.013 nsplit=0
# Epoch: [54][ 0/17]	Time  5.936 ( 5.936)	Data  5.527 ( 5.527)	Loss 7.9644e+00 (7.9644e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 55 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.33s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=57.309 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=57.324 imbalance=1.039 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=58.2175 imbalance=1.086 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=57.3098 imbalance=1.049 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=57.913 imbalance=1.042 nsplit=0
# Epoch: [55][ 0/17]	Time  8.064 ( 8.064)	Data  7.434 ( 7.434)	Loss 8.0083e+00 (8.0083e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 56 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.59s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=63.7918 imbalance=1.065 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=63.7202 imbalance=1.044 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=63.3626 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=63.6556 imbalance=1.012 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=63.3616 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Epoch: [56][ 0/17]	Time  6.131 ( 6.131)	Data  5.548 ( 5.548)	Loss 7.9211e+00 (7.9211e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 57 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.63s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.0686 imbalance=1.221 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=61.9946 imbalance=1.125 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=62.6606 imbalance=1.029 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=62.1462 imbalance=1.055 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=63.1236 imbalance=1.025 nsplit=0
# Epoch: [57][ 0/17]	Time  5.995 ( 5.995)	Data  5.275 ( 5.275)	Loss 7.9787e+00 (7.9787e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 58 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.36s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
# ...
#   Iteration 19 (0.00 s, search 0.00 s): objective=126.45 imbalance=1.000 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=128.702 imbalance=1.072 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=126.341 imbalance=1.007 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=126.387 imbalance=1.007 nsplit=0
# Epoch: [257][ 0/17]	Time  8.769 ( 8.769)	Data  8.303 ( 8.303)	Loss 6.8372e+00 (6.8372e+00)	Acc@Inst  25.00 ( 25.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 258 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:07<00:00,  1.84s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=137.74 imbalance=1.064 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=139.251 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=137.8 imbalance=1.040 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=139.251 imbalance=1.008 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=139.251 imbalance=1.008 nsplit=0
# Epoch: [258][ 0/17]	Time  6.131 ( 6.131)	Data  5.669 ( 5.669)	Loss 6.7622e+00 (6.7622e+00)	Acc@Inst  18.75 ( 18.75)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 259 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.49s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=135.554 imbalance=1.128 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=136.353 imbalance=1.004 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=136.992 imbalance=1.090 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=135.986 imbalance=1.013 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=135.986 imbalance=1.013 nsplit=0
# Epoch: [259][ 0/17]	Time  7.619 ( 7.619)	Data  5.994 ( 5.994)	Loss 6.5210e+00 (6.5210e+00)	Acc@Inst  25.00 ( 25.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 260 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.52s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=141.94 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=142.095 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=141.781 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=142.006 imbalance=1.010 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=142.006 imbalance=1.010 nsplit=0
# Epoch: [260][ 0/17]	Time  6.549 ( 6.549)	Data  6.117 ( 6.117)	Loss 6.6067e+00 (6.6067e+00)	Acc@Inst  18.75 ( 18.75)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 261 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.56s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=133.391 imbalance=1.163 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=132.951 imbalance=1.007 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=132.453 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=132.566 imbalance=1.002 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=132.566 imbalance=1.002 nsplit=0
# Epoch: [261][ 0/17]	Time  5.840 ( 5.840)	Data  5.044 ( 5.044)	Loss 6.5296e+00 (6.5296e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 262 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.39s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=128.627 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=129.124 imbalance=1.002 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=128.588 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=128.834 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=128.834 imbalance=1.009 nsplit=0
# Epoch: [262][ 0/17]	Time  8.842 ( 8.842)	Data  7.769 ( 7.769)	Loss 6.8226e+00 (6.8226e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 263 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.53s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=135.571 imbalance=1.162 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=135.896 imbalance=1.007 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=137.374 imbalance=1.067 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=135.601 imbalance=1.012 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=139.26 imbalance=1.024 nsplit=0
# Epoch: [263][ 0/17]	Time  7.786 ( 7.786)	Data  7.348 ( 7.348)	Loss 6.4501e+00 (6.4501e+00)	Acc@Inst  31.25 ( 31.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 264 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:07<00:00,  1.85s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=130.575 imbalance=1.152 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=131.387 imbalance=1.005 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=130.263 imbalance=1.036 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=131.403 imbalance=1.013 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=131.462 imbalance=1.017 nsplit=0
# Epoch: [264][ 0/17]	Time  5.950 ( 5.950)	Data  4.809 ( 4.809)	Loss 6.3761e+00 (6.3761e+00)	Acc@Inst  50.00 ( 50.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 265 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.39s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=124.791 imbalance=1.169 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=124.614 imbalance=1.000 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=125.857 imbalance=1.080 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=124.505 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=124.538 imbalance=1.010 nsplit=0
# Epoch: [265][ 0/17]	Time  7.769 ( 7.769)	Data  7.235 ( 7.235)	Loss 6.4335e+00 (6.4335e+00)	Acc@Inst  25.00 ( 25.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 266 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.74s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=129.421 imbalance=1.099 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=129.354 imbalance=1.001 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=131.53 imbalance=1.070 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=129.715 imbalance=1.002 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=129.759 imbalance=1.005 nsplit=0
# Epoch: [266][ 0/17]	Time  6.029 ( 6.029)	Data  5.136 ( 5.136)	Loss 6.5452e+00 (6.5452e+00)	Acc@Inst  50.00 ( 50.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 267 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.41s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=119.84 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=120.888 imbalance=1.005 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=122.587 imbalance=1.070 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=120.331 imbalance=1.043 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=120.729 imbalance=1.010 nsplit=0
# Epoch: [267][ 0/17]	Time  7.995 ( 7.995)	Data  6.901 ( 6.901)	Loss 6.5136e+00 (6.5136e+00)	Acc@Inst  31.25 ( 31.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 268 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.48s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=115.582 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=116.963 imbalance=1.143 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=116.639 imbalance=1.100 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=115.567 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=115.613 imbalance=1.018 nsplit=0
# Epoch: [268][ 0/17]	Time  6.906 ( 6.906)	Data  6.470 ( 6.470)	Loss 6.5426e+00 (6.5426e+00)	Acc@Inst  37.50 ( 37.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 269 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:07<00:00,  1.81s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=121.193 imbalance=1.062 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=120.854 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=124.177 imbalance=1.067 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=120.86 imbalance=1.017 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=120.86 imbalance=1.017 nsplit=0
# Epoch: [269][ 0/17]	Time  6.017 ( 6.017)	Data  5.476 ( 5.476)	Loss 6.3140e+00 (6.3140e+00)	Acc@Inst  25.00 ( 25.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 270 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.35s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=120.76 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=120.802 imbalance=1.015 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=123.229 imbalance=1.065 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=120.687 imbalance=1.030 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=121.069 imbalance=1.015 nsplit=0
# Epoch: [270][ 0/17]	Time  8.404 ( 8.404)	Data  7.873 ( 7.873)	Loss 6.3675e+00 (6.3675e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7985fd920180>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1664, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1609, in _shutdown_workers
#     self._worker_result_queue.put((None, None))
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 94, in put
#     self._start_thread()
#   File "/usr/lib/python3.12/multiprocessing/queues.py", line 192, in _start_thread
#     self._thread.start()
#   File "/usr/lib/python3.12/threading.py", line 999, in start
#     self._started.wait()
#   File "/usr/lib/python3.12/threading.py", line 655, in wait
#     signaled = self._cond.wait(timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/threading.py", line 355, in wait
#     waiter.acquire()
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/content/PCL/main_pcl.py", line 585, in <module>
#     main()
#   File "/content/PCL/main_pcl.py", line 172, in main
#     main_worker(args.gpu, torch.cuda.device_count(), args)
#   File "/content/PCL/main_pcl.py", line 331, in main_worker
#     train(train_loader, model, criterion, optimizer, epoch, args, cluster_result)
#   File "/content/PCL/main_pcl.py", line 405, in train
#     optimizer.step()
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py", line 516, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py", line 81, in _use_grad
#     ret = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/sgd.py", line 127, in step
#     sgd(
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/sgd.py", line 304, in sgd
#     func(
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/sgd.py", line 424, in _multi_tensor_sgd
#     device_grads = torch._foreach_add(  # type: ignore[assignment]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# --- Install dependencies ---
# !pip install timm faiss-cpu umap-learn scikit-learn matplotlib

import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, silhouette_score
import numpy as np
import umap
import glob
import timm
from pcl import builder   # your MoCo builder


# --- Find latest checkpoint ---
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]  # latest checkpoint
print("Using checkpoint:", checkpoint_path)

# --- Manually set args used in training ---
arch = "legacy_xception.tf_in1k"  # timm model
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.2
mlp = True

# --- Build MoCo model with timm backbone ---
base_encoder = timm.create_model(arch, pretrained=True, num_classes=0)  # no classifier head

model = builder.MoCo(
    base_encoder,
    low_dim,
    pcl_r,
    moco_m,
    temperature,
    mlp
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = {k: v for k, v in ckpt['state_dict'].items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# --- Dataset & DataLoader ---
data_path = "/content/drive/MyDrive/dataset_cropped"
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(data_path, transform)
loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=4)

# --- Feature extraction ---
all_features = []
all_labels = []

with torch.no_grad():
    for imgs, labels in loader:
        imgs = imgs.cuda(non_blocking=True)
        feats = model.encoder_q(imgs)   # forward through MoCo encoder
        if isinstance(feats, (tuple, list)):  # timm models sometimes return (feats, aux)
            feats = feats[0]
        feats = torch.nn.functional.normalize(feats, dim=1)
        all_features.append(feats.cpu())
        all_labels.append(labels)

all_features = torch.cat(all_features, dim=0).numpy()
all_labels = torch.cat(all_labels, dim=0).numpy()

# --- t-SNE Visualization ---
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_embeds = tsne.fit_transform(all_features)

plt.figure(figsize=(8, 8))
scatter = plt.scatter(tsne_embeds[:, 0], tsne_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("t-SNE of MoCo Embeddings (Xception)")
plt.show()

# --- UMAP Visualization ---
umap_embeds = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(all_features)
plt.figure(figsize=(8, 8))
scatter = plt.scatter(umap_embeds[:, 0], umap_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("UMAP of MoCo Embeddings (Xception)")
plt.show()

# --- Clustering Metrics ---
# Simple nearest-neighbor pseudo clustering
sim_matrix = all_features @ all_features.T
nearest_idx = np.argmax(sim_matrix, axis=1)

nmi = normalized_mutual_info_score(all_labels, nearest_idx)
ari = adjusted_rand_score(all_labels, nearest_idx)
sil = silhouette_score(all_features, all_labels)

print(f"NMI: {nmi:.4f}")
print(f"ARI: {ari:.4f}")
print(f"Silhouette Score: {sil:.4f}")
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (1.0.19)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (0.5.9.post2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from timm) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm) (0.23.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm) (0.34.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm) (0.6.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (1.16.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2025.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.1.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->timm) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2025.8.3)
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# NMI: 0.0981
# ARI: -0.0551
# Silhouette Score: -0.0158

# %%
# -------------------------------
# Install timm for Xception
# -------------------------------
# !pip install timm

import torch
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import glob
import timm
from pcl import builder   # your MoCo builder

# -------------------------------
# Load latest checkpoint
# -------------------------------
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]
print("Using checkpoint:", checkpoint_path)

# --- MoCo args (xception backbone) ---
arch = "legacy_xception.tf_in1k"   # timm model
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.1
mlp = True

# --- Build MoCo model ---
base_encoder = timm.create_model(arch, pretrained=True, num_classes=0)  # no FC head

model = builder.MoCo(
    base_encoder,
    low_dim,
    pcl_r,
    moco_m,
    temperature,
    mlp
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = {k: v for k, v in ckpt['state_dict'].items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# -------------------------------
# Dataset & DataLoader
# -------------------------------
train_dir = "/content/drive/My Drive/dataset/train"
test_dir  = "/content/drive/My Drive/dataset/test"

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(train_dir, transform=transform)
test_dataset  = datasets.ImageFolder(test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False, num_workers=4)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))

# -------------------------------
# Feature Extraction
# -------------------------------
def extract_features(dataloader):
    features, labels = [], []
    with torch.no_grad():
        for imgs, lbls in dataloader:
            imgs = imgs.cuda(non_blocking=True)
            feats = model.encoder_q(imgs)
            if isinstance(feats, (tuple, list)):  # timm sometimes returns tuple
                feats = feats[0]
            feats = F.normalize(feats, dim=1)
            features.append(feats.cpu())
            labels.append(lbls)
    return torch.cat(features), torch.cat(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels   = extract_features(test_loader)

# -------------------------------
# Centroid-based Classification
# -------------------------------
def compute_centroids(features, labels, num_classes):
    centroids = []
    for c in range(num_classes):
        mask = labels == c
        class_feats = features[mask]
        centroid = class_feats.mean(dim=0)
        centroids.append(centroid)
    return torch.stack(centroids)

num_classes = len(train_dataset.classes)
centroids = compute_centroids(train_features, train_labels, num_classes)
centroids = F.normalize(centroids, dim=1)

def predict_with_centroids(test_feats, centroids):
    sims = test_feats @ centroids.T
    preds = torch.argmax(sims, dim=1)
    return preds

pred_labels = predict_with_centroids(test_features, centroids)

# -------------------------------
# Evaluation Metrics
# -------------------------------
y_true = test_labels.numpy()
y_pred = pred_labels.numpy()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average="macro")
recall = recall_score(y_true, y_pred, average="macro")  # Sensitivity
f1 = f1_score(y_true, y_pred, average="macro")

# Specificity per class
cm = confusion_matrix(y_true, y_pred)
specificity = []
for i in range(num_classes):
    tn = cm.sum() - (cm[i,:].sum() + cm[:,i].sum() - cm[i,i])
    fp = cm[:,i].sum() - cm[i,i]
    specificity.append(tn / (tn + fp))
specificity = np.mean(specificity)

# -------------------------------
# Print Results
# -------------------------------
print("Confusion Matrix:\n", cm)
print(f"Accuracy:     {acc:.16f}")
print(f"Precision:    {precision:.16f}")
print(f"Sensitivity:  {recall:.16f}")
print(f"F1 Score:     {f1:.16f}")
print(f"Specificity:  {specificity:.16f}")
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (1.0.19)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from timm) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm) (0.23.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm) (0.34.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.1.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->timm) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->timm) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->timm) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->timm) (2025.8.3)
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Train size: 279
# Test size: 39
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Confusion Matrix:
#  [[13  0  0]
#  [13  0  0]
#  [13  0  0]]
# Accuracy:     0.3333333333333333
# Precision:    0.1111111111111111
# Sensitivity:  0.3333333333333333
# F1 Score:     0.1666666666666667
# Specificity:  0.6666666666666666
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
