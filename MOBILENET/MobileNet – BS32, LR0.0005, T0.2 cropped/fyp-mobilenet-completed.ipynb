# %%
# !git clone https://github.com/salesforce/PCL.git
# %cd PCL
# Out:
# Cloning into 'PCL'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 160 (delta 18), reused 12 (delta 12), pack-reused 134 (from 2)
# Receiving objects: 100% (160/160), 196.36 KiB | 14.03 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/PCL

# %%
# !pip install torch torchvision
# !pip install numpy tqdm pyyaml
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (6.0.2)

# %%
import torch
print(torch.cuda.is_available())  # True
print(torch.cuda.get_device_name(0))  #GPU name
# Out:
# True
# Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = "/content/drive/My Drive/dataset_cropped"

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 69.3 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
import sys
sys.path.insert(0, "/content/PCL")  # force project path

from pcl import builder
print("Builder path:", builder.__file__)
print("Has MoCo:", hasattr(builder, "MoCo"))
# Out:
# Builder path: /content/PCL/pcl/builder.py
# Has MoCo: True

# %%
import os, sys
sys.path.append('/content/PCL')

from pcl import builder
print(" Import worked!")

import sys
sys.path.insert(0, "/content/PCL")
# Out:
#  Import worked!

# %%
# %reset -f

# %%
import importlib
import pcl.builder as builder

importlib.reload(builder)  # Force reload builder.py
# Out:
# <module 'pcl.builder' from '/content/PCL/pcl/builder.py'>

# %%
import torch
import torch.nn as nn
from torchvision import models

# --- MoCo class for MobileNetV2 only ---
class MoCo(nn.Module):
    def __init__(self, base_encoder, dim=128, r=16384, m=0.999, T=0.1, mlp=False):
        super().__init__()
        self.r = r
        self.m = m
        self.T = T
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # Encoders
        self.encoder_q = base_encoder(num_classes=dim).to(self.device)
        self.encoder_k = base_encoder(num_classes=dim).to(self.device)

        # Replace MobileNet classifier head
        if isinstance(self.encoder_q.classifier, nn.Sequential):
            in_features = self.encoder_q.classifier[-1].in_features
            if mlp:
                self.encoder_q.classifier = nn.Sequential(
                    nn.Linear(in_features, in_features), nn.ReLU(), nn.Linear(in_features, dim)
                )
                self.encoder_k.classifier = nn.Sequential(
                    nn.Linear(in_features, in_features), nn.ReLU(), nn.Linear(in_features, dim)
                )
            else:
                self.encoder_q.classifier[-1] = nn.Linear(in_features, dim)
                self.encoder_k.classifier[-1] = nn.Linear(in_features, dim)

        # Copy weights from query to key
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data.copy_(param_q.data)
            param_k.requires_grad = False

        self.register_buffer("queue", torch.randn(dim, r))
        self.queue = nn.functional.normalize(self.queue, dim=0)
        self.register_buffer("queue_ptr", torch.zeros(1, dtype=torch.long))

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1. - self.m)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys):
        batch_size = keys.shape[0]
        ptr = int(self.queue_ptr)
        self.queue[:, ptr:ptr + batch_size] = keys.T
        ptr = (ptr + batch_size) % self.r
        self.queue_ptr[0] = ptr

    def forward(self, im_q, im_k=None, is_eval=False):
        im_q = im_q.to(self.device)
        if im_k is not None:
            im_k = im_k.to(self.device)

        q = nn.functional.normalize(self.encoder_q(im_q), dim=1)

        if is_eval:
            return nn.functional.normalize(self.encoder_k(im_q), dim=1)

        with torch.no_grad():
            self._momentum_update_key_encoder()
            k = nn.functional.normalize(self.encoder_k(im_k), dim=1)
            self._dequeue_and_enqueue(k)

        l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
        l_neg = torch.einsum('nc,ck->nk', [q, self.queue.clone().detach().to(self.device)])
        logits = torch.cat([l_pos, l_neg], dim=1)
        logits /= self.T
        labels = torch.zeros(logits.shape[0], dtype=torch.long).to(self.device)

        return logits, labels, None, None

# --- Instantiate MoCo with MobileNetV2 ---
mobilenet = models.mobilenet_v2
model = MoCo(mobilenet, dim=128, mlp=False)
print("MoCo model with MobileNetV2 created successfully!")
# Out:
# MoCo model with MobileNetV2 created successfully!

# %%
import sys
sys.path.append("/content/PCL")  # ensure pcl module is found
import pcl.builder as builder
print(hasattr(builder, "MoCo"))  # should print True
# Out:
# True

# %%
from torchvision import models
mobilenet = models.mobilenet_v2
model = builder.MoCo(mobilenet, dim=128, mlp=False)

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import pcl.builder  # your builder.py containing MoCo

# Define architecture
arch = "mobilenet_v2"

# Create the MoCo model
model = pcl.builder.MoCo(
    base_encoder=models.__dict__[arch],
    dim=128,
    r=16384,
    m=0.999,
    T=0.2,
    mlp=False
)

print(model)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# MoCo(
#   (encoder_q): MobileNetV2(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (16): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (17): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (18): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (classifier): Sequential(
#       (0): Dropout(p=0.2, inplace=False)
#       (1): Linear(in_features=1280, out_features=128, bias=True)
#     )
#   )
#   (encoder_k): MobileNetV2(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (16): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (17): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (18): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (classifier): Sequential(
#       (0): Dropout(p=0.2, inplace=False)
#       (1): Linear(in_features=1280, out_features=128, bias=True)
#     )
#   )
# )

# %%
import importlib
import pcl.builder as builder

importlib.reload(builder)  # forces Python to re-read builder.py

# now MoCo should be available
model = builder.MoCo(
    base_encoder=models.mobilenet_v2,
    dim=128,
    r=16384,
    m=0.999,
    T=0.2,
    mlp=False
)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
from pcl.builder import MoCo
print("MoCo loaded:", MoCo)
# Out:
# MoCo loaded: <class 'pcl.builder.MoCo'>

# %%
import sys, importlib

# Make sure PCL is first in the Python path
sys.path.insert(0, "/content/PCL")

# Force reload of builder.py
import pcl.builder
importlib.reload(pcl.builder)

# Now test
print("MoCo available?", hasattr(pcl.builder, "MoCo"))

# Try importing directly
from pcl.builder import MoCo
print("MoCo loaded successfully:", MoCo)
# Out:
# MoCo available? True
# MoCo loaded successfully: <class 'pcl.builder.MoCo'>

# %%
import sys
sys.path.insert(0, "/content/PCL")

from pcl import builder
print("MoCo available?", hasattr(builder, "MoCo"))
# Out:
# MoCo available? True

# %%
import pcl.builder as builder
print("Loaded from:", builder.__file__)
print("Has MoCo:", hasattr(builder, "MoCo"))
# Out:
# Loaded from: /content/PCL/pcl/builder.py
# Has MoCo: True

# %%
# !python3 /content/PCL/main_pcl.py \
  "/content/drive/My Drive/dataset_cropped" \
  --arch mobilenet_v2 \
  --epochs 300 \
  --batch-size 32 \
  --lr 0.0005 \
  --temperature 0.2 \
  --num-cluster 3
# Out:
# Streaming output truncated to the last 5000 lines.
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.6563 imbalance=1.007 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.6652 imbalance=1.073 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.6623 imbalance=1.006 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=35.6855 imbalance=1.049 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=35.6544 imbalance=1.072 nsplit=0
# Objective improved: keep new clusters
# Epoch: [35][0/8]	Time  5.249 ( 5.249)	Data  4.913 ( 4.913)	Loss 8.9354e+00 (8.9354e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 36 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.52s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.0878 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.0792 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.0986 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=35.082 imbalance=1.023 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=35.0821 imbalance=1.023 nsplit=0
# Epoch: [36][0/8]	Time  4.314 ( 4.314)	Data  4.018 ( 4.018)	Loss 8.9797e+00 (8.9797e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 37 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.27s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.3894 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.3703 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.3687 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=36.3914 imbalance=1.065 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=36.5612 imbalance=1.068 nsplit=0
# Epoch: [37][0/8]	Time  4.188 ( 4.188)	Data  3.907 ( 3.907)	Loss 8.9769e+00 (8.9769e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 38 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.66s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.4347 imbalance=1.012 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.4153 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.4086 imbalance=1.039 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=36.4492 imbalance=1.007 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=37.0786 imbalance=1.072 nsplit=0
# Epoch: [38][0/8]	Time  5.859 ( 5.859)	Data  5.520 ( 5.520)	Loss 9.0448e+00 (9.0448e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 39 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.53s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.9475 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.9505 imbalance=1.012 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.9386 imbalance=1.015 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=35.9546 imbalance=1.006 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=36.0665 imbalance=1.005 nsplit=0
# Epoch: [39][0/8]	Time  4.236 ( 4.236)	Data  3.918 ( 3.918)	Loss 9.0316e+00 (9.0316e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 40 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.67s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.795 imbalance=1.042 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.8727 imbalance=1.009 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=35.8029 imbalance=1.046 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=35.7969 imbalance=1.043 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=35.8346 imbalance=1.006 nsplit=0
# Epoch: [40][0/8]	Time  4.315 ( 4.315)	Data  4.023 ( 4.023)	Loss 9.0363e+00 (9.0363e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 41 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.22s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=34.7499 imbalance=1.053 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=34.6011 imbalance=1.005 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=34.6952 imbalance=1.033 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=34.6288 imbalance=1.038 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=34.7509 imbalance=1.010 nsplit=0
# Epoch: [41][0/8]	Time  4.910 ( 4.910)	Data  4.629 ( 4.629)	Loss 8.9990e+00 (8.9990e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 42 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.52s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=32.685 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=32.6258 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=32.6517 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=32.6349 imbalance=1.019 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=32.6324 imbalance=1.016 nsplit=0
# Epoch: [42][0/8]	Time  5.584 ( 5.584)	Data  5.096 ( 5.096)	Loss 9.0894e+00 (9.0894e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 43 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.55s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=33.5024 imbalance=1.039 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=33.5207 imbalance=1.008 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=33.4934 imbalance=1.015 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=33.4943 imbalance=1.039 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=33.516 imbalance=1.019 nsplit=0
# Epoch: [43][0/8]	Time  4.286 ( 4.286)	Data  4.025 ( 4.025)	Loss 9.0482e+00 (9.0482e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 44 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.43s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.4893 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.4494 imbalance=1.050 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.4512 imbalance=1.049 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.449 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.4477 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Epoch: [44][0/8]	Time  4.252 ( 4.252)	Data  3.851 ( 3.851)	Loss 9.1501e+00 (9.1501e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 45 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.68s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.8284 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.8305 imbalance=1.049 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.8305 imbalance=1.045 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=39.8305 imbalance=1.049 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=39.8334 imbalance=1.012 nsplit=0
# Epoch: [45][0/8]	Time  5.392 ( 5.392)	Data  5.104 ( 5.104)	Loss 9.1472e+00 (9.1472e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 46 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.50s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=41.3217 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=41.3209 imbalance=1.079 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=41.3217 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=41.3217 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=41.3229 imbalance=1.052 nsplit=0
# Epoch: [46][0/8]	Time  5.045 ( 5.045)	Data  4.211 ( 4.211)	Loss 9.0205e+00 (9.0205e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 47 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.56s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.5233 imbalance=1.058 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=39.5211 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=39.5211 imbalance=1.061 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=39.5211 imbalance=1.061 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=39.5233 imbalance=1.058 nsplit=0
# Epoch: [47][0/8]	Time  4.230 ( 4.230)	Data  3.917 ( 3.917)	Loss 9.1054e+00 (9.1054e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 48 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.19s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.1067 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.144 imbalance=1.029 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.1055 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.1232 imbalance=1.031 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=40.094 imbalance=1.013 nsplit=0
# Objective improved: keep new clusters
# Epoch: [48][0/8]	Time  4.553 ( 4.553)	Data  4.206 ( 4.206)	Loss 9.0239e+00 (9.0239e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 49 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.53s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.1689 imbalance=1.024 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.1708 imbalance=1.028 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.171 imbalance=1.022 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=39.3201 imbalance=1.060 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=39.1669 imbalance=1.024 nsplit=0
# Objective improved: keep new clusters
# Epoch: [49][0/8]	Time  6.054 ( 6.054)	Data  5.349 ( 5.349)	Loss 9.0250e+00 (9.0250e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 50 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.70s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.1466 imbalance=1.091 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.1291 imbalance=1.052 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.1038 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.2867 imbalance=1.130 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=38.102 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Epoch: [50][0/8]	Time  4.250 ( 4.250)	Data  3.542 ( 3.542)	Loss 9.0899e+00 (9.0899e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 51 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.87s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.428 imbalance=1.098 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.4398 imbalance=1.024 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.3826 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.5438 imbalance=1.001 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=37.441 imbalance=1.095 nsplit=0
# Epoch: [51][0/8]	Time  4.742 ( 4.742)	Data  4.400 ( 4.400)	Loss 9.1128e+00 (9.1128e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 52 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.01s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.5013 imbalance=1.021 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.5006 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.6122 imbalance=1.009 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.5561 imbalance=1.029 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=38.4957 imbalance=1.022 nsplit=0
# Objective improved: keep new clusters
# Epoch: [52][0/8]	Time  4.791 ( 4.791)	Data  4.248 ( 4.248)	Loss 9.1152e+00 (9.1152e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 53 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.76s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.8478 imbalance=1.037 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.8343 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.8692 imbalance=1.070 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.8416 imbalance=1.017 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=38.7247 imbalance=1.018 nsplit=0
# Epoch: [53][0/8]	Time  6.247 ( 6.247)	Data  5.136 ( 5.136)	Loss 9.1135e+00 (9.1135e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 54 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.58s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.74 imbalance=1.062 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.5215 imbalance=1.156 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.5565 imbalance=1.099 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.7566 imbalance=1.017 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.7394 imbalance=1.024 nsplit=0
# Epoch: [54][0/8]	Time  4.291 ( 4.291)	Data  4.005 ( 4.005)	Loss 9.0632e+00 (9.0632e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 55 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.95s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.572 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.7621 imbalance=1.123 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.7709 imbalance=1.189 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.3419 imbalance=1.006 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=37.0438 imbalance=1.043 nsplit=0
# Epoch: [55][0/8]	Time  4.373 ( 4.373)	Data  3.674 ( 3.674)	Loss 8.9754e+00 (8.9754e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 56 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.14s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.7028 imbalance=1.095 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.7009 imbalance=1.057 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.6867 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=37.5463 imbalance=1.007 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=36.6954 imbalance=1.053 nsplit=0
# Epoch: [56][0/8]	Time  5.051 ( 5.051)	Data  4.758 ( 4.758)	Loss 8.9549e+00 (8.9549e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 57 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.58s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.6099 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.5797 imbalance=1.129 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.4978 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.337 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=37.4879 imbalance=1.023 nsplit=0
# Epoch: [57][0/8]	Time  5.858 ( 5.858)	Data  5.370 ( 5.370)	Loss 9.0336e+00 (9.0336e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 58 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.55s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.197 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.1567 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.1763 imbalance=1.010 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.1719 imbalance=1.021 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.1608 imbalance=1.033 nsplit=0
# Epoch: [58][0/8]	Time  4.279 ( 4.279)	Data  4.012 ( 4.012)	Loss 8.9936e+00 (8.9936e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 59 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.37s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.0566 imbalance=1.017 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.756 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.5903 imbalance=1.117 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.8053 imbalance=1.032 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=37.5299 imbalance=1.140 nsplit=0
# Objective improved: keep new clusters
# Epoch: [59][0/8]	Time  4.259 ( 4.259)	Data  3.962 ( 3.962)	Loss 8.9405e+00 (8.9405e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 60 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.83s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=34.7504 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=34.8297 imbalance=1.057 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=34.8292 imbalance=1.072 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=34.7349 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=34.7373 imbalance=1.128 nsplit=0
# Epoch: [60][0/8]	Time  4.858 ( 4.858)	Data  4.527 ( 4.527)	Loss 8.9308e+00 (8.9308e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 61 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.52s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=34.9261 imbalance=1.011 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=34.8098 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=34.8169 imbalance=1.010 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=34.8193 imbalance=1.010 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=34.813 imbalance=1.021 nsplit=0
# Epoch: [61][0/8]	Time  5.479 ( 5.479)	Data  5.141 ( 5.141)	Loss 9.0043e+00 (9.0043e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 62 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.59s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.5041 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.4507 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.4564 imbalance=1.024 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=36.4543 imbalance=1.102 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=36.4504 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Epoch: [62][0/8]	Time  4.275 ( 4.275)	Data  3.767 ( 3.767)	Loss 8.9520e+00 (8.9520e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 63 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.16s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.9232 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.8761 imbalance=1.026 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.9126 imbalance=1.042 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.8785 imbalance=1.007 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=39.1195 imbalance=1.020 nsplit=0
# Epoch: [63][0/8]	Time  4.111 ( 4.111)	Data  3.489 ( 3.489)	Loss 8.9309e+00 (8.9309e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 64 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.63s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.3966 imbalance=1.067 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.3491 imbalance=1.017 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.3966 imbalance=1.067 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.3408 imbalance=1.043 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=38.3538 imbalance=1.015 nsplit=0
# Epoch: [64][0/8]	Time  5.624 ( 5.624)	Data  5.112 ( 5.112)	Loss 8.8408e+00 (8.8408e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 65 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.63s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.4833 imbalance=1.047 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.4236 imbalance=1.034 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.6649 imbalance=1.031 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.4209 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=37.4398 imbalance=1.045 nsplit=0
# Epoch: [65][0/8]	Time  5.119 ( 5.119)	Data  4.793 ( 4.793)	Loss 8.8256e+00 (8.8256e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 66 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.57s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.6103 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.3071 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.6072 imbalance=1.091 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.5802 imbalance=1.021 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.3699 imbalance=1.189 nsplit=0
# Epoch: [66][0/8]	Time  4.220 ( 4.220)	Data  3.931 ( 3.931)	Loss 8.8541e+00 (8.8541e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 67 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.35s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.5065 imbalance=1.225 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.505 imbalance=1.211 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.5009 imbalance=1.217 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=36.5561 imbalance=1.209 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=36.2974 imbalance=1.371 nsplit=0
# Objective improved: keep new clusters
# Epoch: [67][0/8]	Time  4.283 ( 4.283)	Data  3.996 ( 3.996)	Loss 8.7874e+00 (8.7874e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 68 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.58s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.9345 imbalance=1.301 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.5868 imbalance=1.328 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.4769 imbalance=1.447 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.7487 imbalance=1.311 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=40.5005 imbalance=1.372 nsplit=0
# Epoch: [68][0/8]	Time  6.258 ( 6.258)	Data  5.590 ( 5.590)	Loss 8.6840e+00 (8.6840e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 69 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.55s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.0418 imbalance=1.603 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.0049 imbalance=1.572 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.0049 imbalance=1.572 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=36.007 imbalance=1.572 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=36.0102 imbalance=1.580 nsplit=0
# Epoch: [69][0/8]	Time  4.195 ( 4.195)	Data  3.705 ( 3.705)	Loss 8.5964e+00 (8.5964e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 70 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.90s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.9973 imbalance=1.468 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.9973 imbalance=1.468 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.9973 imbalance=1.468 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.9973 imbalance=1.468 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=37.9973 imbalance=1.468 nsplit=0
# Epoch: [70][0/8]	Time  4.418 ( 4.418)	Data  4.108 ( 4.108)	Loss 8.7210e+00 (8.7210e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 71 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.17s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=43.6467 imbalance=1.519 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=43.6467 imbalance=1.519 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=43.6467 imbalance=1.519 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=43.8815 imbalance=1.506 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=43.6467 imbalance=1.519 nsplit=0
# Epoch: [71][0/8]	Time  4.861 ( 4.861)	Data  4.519 ( 4.519)	Loss 8.7128e+00 (8.7128e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 72 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.57s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=42.9996 imbalance=1.340 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=42.9996 imbalance=1.340 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=42.9617 imbalance=1.362 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=43.3954 imbalance=1.225 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=43.3287 imbalance=1.244 nsplit=0
# Epoch: [72][0/8]	Time  5.937 ( 5.937)	Data  5.623 ( 5.623)	Loss 8.5603e+00 (8.5603e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 73 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.58s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.5843 imbalance=1.340 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.5122 imbalance=1.428 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.58 imbalance=1.317 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=41.4357 imbalance=1.041 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.8184 imbalance=1.217 nsplit=0
# Epoch: [73][0/8]	Time  4.420 ( 4.420)	Data  3.888 ( 3.888)	Loss 8.6054e+00 (8.6054e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 74 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.33s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.9238 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.981 imbalance=1.030 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.9299 imbalance=1.076 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=37.9697 imbalance=1.054 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=38.2217 imbalance=1.322 nsplit=0
# Epoch: [74][0/8]	Time  4.282 ( 4.282)	Data  3.961 ( 3.961)	Loss 8.5681e+00 (8.5681e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 75 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.13s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.9833 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.5658 imbalance=1.065 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=39.0043 imbalance=1.012 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.9865 imbalance=1.001 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.9905 imbalance=1.019 nsplit=0
# Epoch: [75][0/8]	Time  4.658 ( 4.658)	Data  4.147 ( 4.147)	Loss 8.4536e+00 (8.4536e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 76 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.59s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.8476 imbalance=1.202 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.7556 imbalance=1.174 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.1986 imbalance=1.191 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.2501 imbalance=1.112 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=39.7601 imbalance=1.185 nsplit=0
# Epoch: [76][0/8]	Time  6.148 ( 6.148)	Data  5.837 ( 5.837)	Loss 8.4253e+00 (8.4253e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 77 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.80s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.5613 imbalance=1.111 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.1768 imbalance=1.253 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=37.1723 imbalance=1.008 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=36.1689 imbalance=1.178 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=36.5609 imbalance=1.104 nsplit=0
# Epoch: [77][0/8]	Time  4.508 ( 4.508)	Data  4.235 ( 4.235)	Loss 8.4201e+00 (8.4201e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 78 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.79s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.5323 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.5521 imbalance=1.018 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=36.6425 imbalance=1.024 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=36.5007 imbalance=1.040 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=36.2139 imbalance=1.136 nsplit=0
# Objective improved: keep new clusters
# Epoch: [78][0/8]	Time  4.350 ( 4.350)	Data  4.075 ( 4.075)	Loss 8.4435e+00 (8.4435e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 79 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.11s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.6467 imbalance=1.102 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.5061 imbalance=1.166 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.516 imbalance=1.152 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.5975 imbalance=1.109 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=38.6552 imbalance=1.067 nsplit=0
# Epoch: [79][0/8]	Time  4.476 ( 4.476)	Data  3.758 ( 3.758)	Loss 8.3972e+00 (8.3972e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 80 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.75s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.187 imbalance=1.140 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.1929 imbalance=1.154 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.1852 imbalance=1.175 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.7432 imbalance=1.375 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.1929 imbalance=1.154 nsplit=0
# Epoch: [80][0/8]	Time  6.289 ( 6.289)	Data  5.620 ( 5.620)	Loss 8.3852e+00 (8.3852e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 81 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.59s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=42.1468 imbalance=1.317 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=43.3323 imbalance=1.115 nsplit=0
# Outer iteration 2 / 5
# ...
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=57.4196 imbalance=1.239 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=64.1294 imbalance=1.223 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=57.3955 imbalance=1.189 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=57.3616 imbalance=1.196 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=57.4196 imbalance=1.239 nsplit=0
# Epoch: [284][0/8]	Time  4.859 ( 4.859)	Data  4.385 ( 4.385)	Loss 7.8804e+00 (7.8804e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 285 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.75s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=71.6937 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=70.0669 imbalance=1.116 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=70.0669 imbalance=1.116 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=70.0669 imbalance=1.116 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=70.0669 imbalance=1.116 nsplit=0
# Epoch: [285][0/8]	Time  4.355 ( 4.355)	Data  4.064 ( 4.064)	Loss 7.7196e+00 (7.7196e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 286 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.25s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=64.6423 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=64.4954 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=64.5134 imbalance=1.033 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=64.6362 imbalance=1.117 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=64.5446 imbalance=1.037 nsplit=0
# Epoch: [286][0/8]	Time  4.508 ( 4.508)	Data  4.190 ( 4.190)	Loss 8.0049e+00 (8.0049e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 287 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.57s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=50.2471 imbalance=1.097 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=49.9103 imbalance=1.083 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=49.9117 imbalance=1.081 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=50.2471 imbalance=1.097 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=49.9065 imbalance=1.087 nsplit=0
# Objective improved: keep new clusters
# Epoch: [287][0/8]	Time  5.927 ( 5.927)	Data  5.570 ( 5.570)	Loss 7.7913e+00 (7.7913e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 288 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.67s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.0625 imbalance=1.129 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.0551 imbalance=1.122 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.0723 imbalance=1.133 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=47.0551 imbalance=1.122 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=47.0625 imbalance=1.129 nsplit=0
# Epoch: [288][0/8]	Time  4.215 ( 4.215)	Data  3.925 ( 3.925)	Loss 7.8276e+00 (7.8276e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 289 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.03s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=56.4071 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=56.4071 imbalance=1.100 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=53.8858 imbalance=1.407 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=56.3231 imbalance=1.091 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=56.1785 imbalance=1.204 nsplit=0
# Epoch: [289][0/8]	Time  4.297 ( 4.297)	Data  4.017 ( 4.017)	Loss 7.7936e+00 (7.7936e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 290 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.82s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.8723 imbalance=1.452 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=65.6907 imbalance=1.251 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=64.1527 imbalance=1.406 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=62.8857 imbalance=1.452 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=65.6907 imbalance=1.251 nsplit=0
# Epoch: [290][0/8]	Time  5.040 ( 5.040)	Data  4.448 ( 4.448)	Loss 7.7969e+00 (7.7969e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 291 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.58s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=59.1563 imbalance=1.545 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=59.8299 imbalance=1.748 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.1405 imbalance=1.443 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=61.5451 imbalance=1.639 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=60.5181 imbalance=1.720 nsplit=0
# Epoch: [291][0/8]	Time  5.570 ( 5.570)	Data  5.209 ( 5.209)	Loss 7.9579e+00 (7.9579e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 292 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.59s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=63.1456 imbalance=1.430 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=64.0259 imbalance=1.061 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=64.0251 imbalance=1.070 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=64.0226 imbalance=1.053 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=64.0403 imbalance=1.075 nsplit=0
# Epoch: [292][0/8]	Time  5.724 ( 5.724)	Data  5.433 ( 5.433)	Loss 7.9774e+00 (7.9774e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 293 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.80s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=51.1317 imbalance=1.266 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=51.1884 imbalance=1.239 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=51.9484 imbalance=1.219 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=51.1317 imbalance=1.266 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=51.9518 imbalance=1.213 nsplit=0
# Epoch: [293][0/8]	Time  4.327 ( 4.327)	Data  4.035 ( 4.035)	Loss 7.8287e+00 (7.8287e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 294 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.26s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.1974 imbalance=1.117 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.1941 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.1941 imbalance=1.121 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=62.1978 imbalance=1.115 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=61.1334 imbalance=1.389 nsplit=0
# Objective improved: keep new clusters
# Epoch: [294][0/8]	Time  6.201 ( 6.201)	Data  5.903 ( 5.903)	Loss 7.7180e+00 (7.7180e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 295 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.5873 imbalance=1.296 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.645 imbalance=1.178 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.6386 imbalance=1.175 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=68.6668 imbalance=1.268 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=71.4687 imbalance=1.129 nsplit=0
# Epoch: [295][0/8]	Time  5.156 ( 5.156)	Data  4.751 ( 4.751)	Loss 7.8286e+00 (7.8286e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 296 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.55s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=70.6031 imbalance=1.121 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=70.5437 imbalance=1.107 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=70.5437 imbalance=1.107 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=70.5465 imbalance=1.111 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=70.5437 imbalance=1.107 nsplit=0
# Epoch: [296][0/8]	Time  5.253 ( 5.253)	Data  4.897 ( 4.897)	Loss 7.7643e+00 (7.7643e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 297 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.57s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.1558 imbalance=1.166 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.2048 imbalance=1.158 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=88.2048 imbalance=1.158 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=88.2048 imbalance=1.158 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=88.2048 imbalance=1.158 nsplit=0
# Epoch: [297][0/8]	Time  4.278 ( 4.278)	Data  3.998 ( 3.998)	Loss 7.8746e+00 (7.8746e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 298 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:04<00:00,  2.33s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=120.775 imbalance=1.278 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=120.53 imbalance=1.179 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=120.53 imbalance=1.179 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=120.53 imbalance=1.179 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=120.53 imbalance=1.179 nsplit=0
# Epoch: [298][0/8]	Time  4.245 ( 4.245)	Data  3.915 ( 3.915)	Loss 7.7580e+00 (7.7580e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 299 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 2/2 [00:03<00:00,  1.67s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=100.955 imbalance=1.301 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=101.313 imbalance=1.248 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=100.955 imbalance=1.301 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=101.313 imbalance=1.248 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=101.313 imbalance=1.248 nsplit=0
# Epoch: [299][0/8]	Time  5.999 ( 5.999)	Data  5.718 ( 5.718)	Loss 7.8682e+00 (7.8682e+00)	Acc@Inst   3.12 (  3.12)	Acc@Proto   0.00 (  0.00)

# %%
# --- Install dependencies ---
# !pip install faiss-cpu umap-learn scikit-learn matplotlib
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.11/dist-packages (1.12.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.9.post2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.16.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, silhouette_score
import numpy as np
import umap
import glob
from pcl import builder
import torchvision.models as models

# --- Find latest checkpoint ---
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]  # latest checkpoint
print("Using checkpoint:", checkpoint_path)

# --- Manually set args used in training ---
arch = "mobilenet_v2"
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.2
mlp = True

arch = "mobilenet_v2"
model = builder.MoCo(
    models.__dict__[arch],
    dim=128,
    r=4,
    m=0.999,
    T=0.2,
    mlp=True
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = ckpt['state_dict']
state_dict = {k: v for k, v in state_dict.items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# --- Dataset & DataLoader ---
data_path = "/content/drive/MyDrive/dataset_cropped"
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(data_path, transform)
loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=4)

# --- Feature extraction ---
all_features = []
all_labels = []

with torch.no_grad():
    for imgs, labels in loader:
        imgs = imgs.cuda(non_blocking=True)
        feats = model.encoder_q(imgs)  # MoCo encoder
        feats = torch.nn.functional.normalize(feats, dim=1)
        all_features.append(feats.cpu())
        all_labels.append(labels)

all_features = torch.cat(all_features, dim=0).numpy()
all_labels = torch.cat(all_labels, dim=0).numpy()

# --- t-SNE Visualization ---
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_embeds = tsne.fit_transform(all_features)

plt.figure(figsize=(8, 8))
scatter = plt.scatter(tsne_embeds[:, 0], tsne_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("t-SNE of MoCo Embeddings")
plt.show()

# --- UMAP Visualization ---
umap_embeds = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(all_features)
plt.figure(figsize=(8, 8))
scatter = plt.scatter(umap_embeds[:, 0], umap_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("UMAP of MoCo Embeddings")
plt.show()

# --- Clustering Metrics ---
nmi = normalized_mutual_info_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
ari = adjusted_rand_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
sil = silhouette_score(all_features, all_labels)

print(f"NMI: {nmi:.4f}")
print(f"ARI: {ari:.4f}")
print(f"Silhouette Score: {sil:.4f}")
# Out:
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# NMI: 0.2360
# ARI: 0.0000
# Silhouette Score: -0.0185

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import numpy as np
from collections import Counter

# --- Paths ---
train_dir = "/content/drive/My Drive/dataset_cropped/train"
test_dir  = "/content/drive/My Drive/dataset_cropped/test"

# --- Data transforms (same as training eval augmentation) ---
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# --- Load datasets ---
train_dataset = datasets.ImageFolder(train_dir, transform=transform)
test_dataset  = datasets.ImageFolder(test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False, num_workers=4)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

# --- Feature extraction ---
def extract_features(dataloader):
    features = []
    labels = []
    with torch.no_grad():
        for imgs, lbls in dataloader:
            imgs = imgs.cuda(non_blocking=True)
            feats = model.encoder_q(imgs)  # MoCo encoder
            feats = F.normalize(feats, dim=1)
            features.append(feats.cpu())
            labels.append(lbls)
    return torch.cat(features), torch.cat(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels = extract_features(test_loader)

print(f"Train features: {train_features.shape}")
print(f"Test features: {test_features.shape}")

# --- Cosine kNN classification ---
def knn_cosine(train_feats, train_lbls, test_feats, k=5):
    # Cosine similarity: normalize again just in case
    train_feats = F.normalize(train_feats, dim=1)
    test_feats  = F.normalize(test_feats, dim=1)

    sims = test_feats @ train_feats.T  # (num_test, num_train)
    topk = torch.topk(sims, k=k, dim=1).indices  # top-k indices

    preds = []
    for idxs in topk:
        neighbor_labels = train_lbls[idxs]
        pred = Counter(neighbor_labels.tolist()).most_common(1)[0][0]
        preds.append(pred)
    return torch.tensor(preds)

pred_labels = knn_cosine(train_features, train_labels, test_features, k=5)
accuracy = (pred_labels == test_labels).float().mean().item()

print(f"k-NN (k=5, cosine) Accuracy: {accuracy * 100:.2f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Train features: torch.Size([279, 128])
# Test features: torch.Size([39, 128])
# k-NN (k=5, cosine) Accuracy: 71.79%
