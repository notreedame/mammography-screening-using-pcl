# %%
# !git clone https://github.com/salesforce/PCL.git
# %cd PCL
# Out:
# Cloning into 'PCL'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 160 (delta 18), reused 12 (delta 12), pack-reused 134 (from 2)
# Receiving objects: 100% (160/160), 196.36 KiB | 1.05 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# /content/PCL

# %%
# !pip install torch torchvision
# !pip install numpy tqdm pyyaml
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 103.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (6.0.2)

# %%
import torch
print(torch.cuda.is_available())  # True
print(torch.cuda.get_device_name(0))  #GPU name
# Out:
# True
# Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = "/content/drive/My Drive/dataset"

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 69.8 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0

# %%
import sys
sys.path.insert(0, "/content/PCL")  # force project path

from pcl import builder
print("Builder path:", builder.__file__)
print("Has MoCo:", hasattr(builder, "MoCo"))
# Out:
# Builder path: /content/PCL/pcl/builder.py
# Has MoCo: True

# %%
import os, sys
sys.path.append('/content/PCL')

from pcl import builder
print(" Import worked!")

import sys
sys.path.insert(0, "/content/PCL")
# Out:
#  Import worked!

# %%
# %reset -f

# %%
import importlib
import pcl.builder as builder

importlib.reload(builder)  # Force reload builder.py
# Out:
# <module 'pcl.builder' from '/content/PCL/pcl/builder.py'>

# %%
import torch
import torch.nn as nn
from torchvision import models

# --- MoCo class for MobileNetV2 only ---
class MoCo(nn.Module):
    def __init__(self, base_encoder, dim=128, r=16384, m=0.999, T=0.1, mlp=False):
        super().__init__()
        self.r = r
        self.m = m
        self.T = T
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        # Encoders
        self.encoder_q = base_encoder(num_classes=dim).to(self.device)
        self.encoder_k = base_encoder(num_classes=dim).to(self.device)

        # Replace MobileNet classifier head
        if isinstance(self.encoder_q.classifier, nn.Sequential):
            in_features = self.encoder_q.classifier[-1].in_features
            if mlp:
                self.encoder_q.classifier = nn.Sequential(
                    nn.Linear(in_features, in_features), nn.ReLU(), nn.Linear(in_features, dim)
                )
                self.encoder_k.classifier = nn.Sequential(
                    nn.Linear(in_features, in_features), nn.ReLU(), nn.Linear(in_features, dim)
                )
            else:
                self.encoder_q.classifier[-1] = nn.Linear(in_features, dim)
                self.encoder_k.classifier[-1] = nn.Linear(in_features, dim)

        # Copy weights from query to key
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data.copy_(param_q.data)
            param_k.requires_grad = False

        self.register_buffer("queue", torch.randn(dim, r))
        self.queue = nn.functional.normalize(self.queue, dim=0)
        self.register_buffer("queue_ptr", torch.zeros(1, dtype=torch.long))

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data = param_k.data * self.m + param_q.data * (1. - self.m)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys):
        batch_size = keys.shape[0]
        ptr = int(self.queue_ptr)
        self.queue[:, ptr:ptr + batch_size] = keys.T
        ptr = (ptr + batch_size) % self.r
        self.queue_ptr[0] = ptr

    def forward(self, im_q, im_k=None, is_eval=False):
        im_q = im_q.to(self.device)
        if im_k is not None:
            im_k = im_k.to(self.device)

        q = nn.functional.normalize(self.encoder_q(im_q), dim=1)

        if is_eval:
            return nn.functional.normalize(self.encoder_k(im_q), dim=1)

        with torch.no_grad():
            self._momentum_update_key_encoder()
            k = nn.functional.normalize(self.encoder_k(im_k), dim=1)
            self._dequeue_and_enqueue(k)

        l_pos = torch.einsum('nc,nc->n', [q, k]).unsqueeze(-1)
        l_neg = torch.einsum('nc,ck->nk', [q, self.queue.clone().detach().to(self.device)])
        logits = torch.cat([l_pos, l_neg], dim=1)
        logits /= self.T
        labels = torch.zeros(logits.shape[0], dtype=torch.long).to(self.device)

        return logits, labels, None, None

# --- Instantiate MoCo with MobileNetV2 ---
mobilenet = models.mobilenet_v2
model = MoCo(mobilenet, dim=128, mlp=False)
print("MoCo model with MobileNetV2 created successfully!")
# Out:
# MoCo model with MobileNetV2 created successfully!

# %%
import sys
sys.path.append("/content/PCL")  # ensure pcl module is found
import pcl.builder as builder
print(hasattr(builder, "MoCo"))  # should print True
# Out:
# True

# %%
from torchvision import models
mobilenet = models.mobilenet_v2
model = builder.MoCo(mobilenet, dim=128, mlp=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import pcl.builder  # your builder.py containing MoCo

# Define architecture
arch = "mobilenet_v2"

# Create the MoCo model
model = pcl.builder.MoCo(
    base_encoder=models.__dict__[arch],
    dim=128,
    r=16384,
    m=0.999,
    T=0.2,
    mlp=False
)

print(model)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# MoCo(
#   (encoder_q): MobileNetV2(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (16): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (17): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (18): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (classifier): Sequential(
#       (0): Dropout(p=0.2, inplace=False)
#       (1): Linear(in_features=1280, out_features=128, bias=True)
#     )
#   )
#   (encoder_k): MobileNetV2(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (16): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (17): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (18): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#     (classifier): Sequential(
#       (0): Dropout(p=0.2, inplace=False)
#       (1): Linear(in_features=1280, out_features=128, bias=True)
#     )
#   )
# )

# %%
import importlib
import pcl.builder as builder

importlib.reload(builder)  # forces Python to re-read builder.py

# now MoCo should be available
model = builder.MoCo(
    base_encoder=models.mobilenet_v2,
    dim=128,
    r=16384,
    m=0.999,
    T=0.2,
    mlp=False
)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
from pcl.builder import MoCo
print("MoCo loaded:", MoCo)
# Out:
# MoCo loaded: <class 'pcl.builder.MoCo'>

# %%
import sys, importlib

# Make sure PCL is first in the Python path
sys.path.insert(0, "/content/PCL")

# Force reload of builder.py
import pcl.builder
importlib.reload(pcl.builder)

# Now test
print("MoCo available?", hasattr(pcl.builder, "MoCo"))

# Try importing directly
from pcl.builder import MoCo
print("MoCo loaded successfully:", MoCo)
# Out:
# MoCo available? True
# MoCo loaded successfully: <class 'pcl.builder.MoCo'>

# %%
import sys
sys.path.insert(0, "/content/PCL")

from pcl import builder
print("MoCo available?", hasattr(builder, "MoCo"))
# Out:
# MoCo available? True

# %%
import pcl.builder as builder
print("Loaded from:", builder.__file__)
print("Has MoCo:", hasattr(builder, "MoCo"))
# Out:
# Loaded from: /content/PCL/pcl/builder.py
# Has MoCo: True

# %%
# !python3 /content/PCL/main_pcl.py \
  "/content/drive/My Drive/dataset" \
  --arch mobilenet_v2 \
  --epochs 300 \
  --batch-size 16 \
  --lr 0.0005 \
  --temperature 0.2 \
  --num-cluster 3
# Out:
# Streaming output truncated to the last 5000 lines.
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=41.2532 imbalance=1.089 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=41.2596 imbalance=1.237 nsplit=0
# Epoch: [32][ 0/17]	Time  5.779 ( 5.779)	Data  5.570 ( 5.570)	Loss 8.6110e+00 (8.6110e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 33 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.28s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.4702 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.4675 imbalance=1.043 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.4882 imbalance=1.044 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.6724 imbalance=1.007 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=40.4828 imbalance=1.052 nsplit=0
# Epoch: [33][ 0/17]	Time  5.589 ( 5.589)	Data  4.573 ( 4.573)	Loss 8.6272e+00 (8.6272e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 34 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.30s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.7676 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.7839 imbalance=1.146 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=41.2952 imbalance=1.133 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.7734 imbalance=1.009 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=40.8139 imbalance=1.038 nsplit=0
# Epoch: [34][ 0/17]	Time  5.760 ( 5.760)	Data  5.482 ( 5.482)	Loss 8.5940e+00 (8.5940e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 35 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.47s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.5207 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.4243 imbalance=1.025 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.3242 imbalance=1.127 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=39.4112 imbalance=1.024 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=39.5403 imbalance=1.097 nsplit=0
# Epoch: [35][ 0/17]	Time  5.781 ( 5.781)	Data  5.567 ( 5.567)	Loss 8.5525e+00 (8.5525e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 36 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.25s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.6861 imbalance=1.033 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=40.1956 imbalance=1.029 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.729 imbalance=1.005 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=39.6832 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=40.2232 imbalance=1.037 nsplit=0
# Epoch: [36][ 0/17]	Time  5.657 ( 5.657)	Data  4.583 ( 4.583)	Loss 8.5746e+00 (8.5746e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 37 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.27s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.3201 imbalance=1.036 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.2081 imbalance=1.140 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=38.2053 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=38.2039 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=38.204 imbalance=1.113 nsplit=0
# Epoch: [37][ 0/17]	Time  6.336 ( 6.336)	Data  5.610 ( 5.610)	Loss 8.4764e+00 (8.4764e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 38 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.0147 imbalance=1.004 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.0972 imbalance=1.011 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=39.0418 imbalance=1.000 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=39.0515 imbalance=1.007 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=39.049 imbalance=1.001 nsplit=0
# Epoch: [38][ 0/17]	Time  5.848 ( 5.848)	Data  5.636 ( 5.636)	Loss 8.5618e+00 (8.5618e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 39 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.15s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.0852 imbalance=1.050 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.071 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=47.0334 imbalance=1.125 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=47.097 imbalance=1.018 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=47.107 imbalance=1.013 nsplit=0
# Epoch: [39][ 0/17]	Time  5.643 ( 5.643)	Data  5.288 ( 5.288)	Loss 8.4172e+00 (8.4172e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 40 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.24s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=48.9667 imbalance=1.032 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=48.5806 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=48.7289 imbalance=1.092 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=49.0168 imbalance=1.017 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=48.8882 imbalance=1.010 nsplit=0
# Epoch: [40][ 0/17]	Time  5.602 ( 5.602)	Data  5.344 ( 5.344)	Loss 8.5035e+00 (8.5035e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 41 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.23s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.6789 imbalance=1.174 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.7173 imbalance=1.174 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.6883 imbalance=1.196 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=62.6918 imbalance=1.178 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=63.0149 imbalance=1.160 nsplit=0
# Epoch: [41][ 0/17]	Time  5.570 ( 5.570)	Data  5.376 ( 5.376)	Loss 8.3656e+00 (8.3656e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 42 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:06<00:00,  1.52s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=87.6848 imbalance=1.133 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=87.69 imbalance=1.133 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=87.8242 imbalance=1.080 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=87.8242 imbalance=1.080 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=87.6848 imbalance=1.133 nsplit=0
# Epoch: [42][ 0/17]	Time  5.689 ( 5.689)	Data  5.434 ( 5.434)	Loss 8.3279e+00 (8.3279e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 43 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.34s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=67.6423 imbalance=1.166 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.1524 imbalance=1.269 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=67.7947 imbalance=1.067 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=70.6829 imbalance=1.050 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=67.6423 imbalance=1.166 nsplit=0
# Epoch: [43][ 0/17]	Time  5.907 ( 5.907)	Data  5.505 ( 5.505)	Loss 8.3192e+00 (8.3192e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 44 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.23s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=55.5013 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=56.086 imbalance=1.019 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=55.5248 imbalance=1.036 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=56.0756 imbalance=1.019 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=55.5108 imbalance=1.004 nsplit=0
# Epoch: [44][ 0/17]	Time  6.424 ( 6.424)	Data  5.619 ( 5.619)	Loss 8.2890e+00 (8.2890e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 45 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.16s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.441 imbalance=1.078 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.6758 imbalance=1.217 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=62.4214 imbalance=1.085 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=62.4674 imbalance=1.057 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=62.6758 imbalance=1.217 nsplit=0
# Epoch: [45][ 0/17]	Time  5.915 ( 5.915)	Data  5.696 ( 5.696)	Loss 8.2459e+00 (8.2459e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 46 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.17s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.2215 imbalance=1.089 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.2379 imbalance=1.090 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.2379 imbalance=1.090 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=74.2379 imbalance=1.090 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=74.2379 imbalance=1.090 nsplit=0
# Epoch: [46][ 0/17]	Time  6.746 ( 6.746)	Data  6.296 ( 6.296)	Loss 8.1525e+00 (8.1525e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 47 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.14s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=105.94 imbalance=1.106 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=106.027 imbalance=1.062 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=106.027 imbalance=1.062 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=105.947 imbalance=1.095 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=106.101 imbalance=1.053 nsplit=0
# Epoch: [47][ 0/17]	Time  5.753 ( 5.753)	Data  5.270 ( 5.270)	Loss 8.1863e+00 (8.1863e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 48 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.16s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=133.512 imbalance=1.114 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=136.603 imbalance=1.043 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=133.512 imbalance=1.114 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=136.603 imbalance=1.043 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=136.603 imbalance=1.043 nsplit=0
# Epoch: [48][ 0/17]	Time  5.749 ( 5.749)	Data  5.550 ( 5.550)	Loss 8.0937e+00 (8.0937e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 49 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.25s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.26 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.254 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.292 imbalance=1.088 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=100.254 imbalance=1.049 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=100.254 imbalance=1.049 nsplit=0
# Epoch: [49][ 0/17]	Time  5.739 ( 5.739)	Data  5.119 ( 5.119)	Loss 8.1197e+00 (8.1197e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 50 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.386 imbalance=1.168 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.429 imbalance=1.095 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.386 imbalance=1.168 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=100.386 imbalance=1.168 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=100.386 imbalance=1.168 nsplit=0
# Epoch: [50][ 0/17]	Time  5.746 ( 5.746)	Data  5.425 ( 5.425)	Loss 8.0798e+00 (8.0798e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 51 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.27s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.5745 imbalance=1.104 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.412 imbalance=1.008 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.4516 imbalance=1.003 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=74.1457 imbalance=1.020 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=74.4032 imbalance=1.011 nsplit=0
# Epoch: [51][ 0/17]	Time  5.969 ( 5.969)	Data  5.613 ( 5.613)	Loss 8.0173e+00 (8.0173e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 52 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.12s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=73.8535 imbalance=1.050 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=73.4828 imbalance=1.045 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=73.4795 imbalance=1.122 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=73.4247 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=73.8988 imbalance=1.269 nsplit=0
# Epoch: [52][ 0/17]	Time  5.605 ( 5.605)	Data  5.320 ( 5.320)	Loss 8.0146e+00 (8.0146e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 53 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=73.4167 imbalance=1.029 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=73.4507 imbalance=1.004 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.7064 imbalance=1.017 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=73.4565 imbalance=1.001 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=73.4372 imbalance=1.015 nsplit=0
# Epoch: [53][ 0/17]	Time  6.568 ( 6.568)	Data  6.158 ( 6.158)	Loss 7.9926e+00 (7.9926e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 54 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.16s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=76.9466 imbalance=1.074 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=77.0144 imbalance=1.056 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=77.0084 imbalance=1.050 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=76.9782 imbalance=1.032 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=77.0144 imbalance=1.056 nsplit=0
# Epoch: [54][ 0/17]	Time  5.893 ( 5.893)	Data  5.524 ( 5.524)	Loss 7.9427e+00 (7.9427e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 55 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.14s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.8563 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.8563 imbalance=1.075 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=74.8563 imbalance=1.075 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=74.8499 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=74.844 imbalance=1.060 nsplit=0
# Objective improved: keep new clusters
# Epoch: [55][ 0/17]	Time  5.700 ( 5.700)	Data  5.021 ( 5.021)	Loss 7.9563e+00 (7.9563e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 56 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.22s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=65.8842 imbalance=1.027 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=65.8842 imbalance=1.027 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=65.9035 imbalance=1.046 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=65.8687 imbalance=1.028 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=65.9083 imbalance=1.044 nsplit=0
# Epoch: [56][ 0/17]	Time  5.731 ( 5.731)	Data  5.392 ( 5.392)	Loss 7.9343e+00 (7.9343e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 57 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.26s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=67.9839 imbalance=1.043 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.0226 imbalance=1.084 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.0182 imbalance=1.073 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=67.985 imbalance=1.045 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=67.9839 imbalance=1.043 nsplit=0
# Epoch: [57][ 0/17]	Time  5.778 ( 5.778)	Data  5.567 ( 5.567)	Loss 7.8707e+00 (7.8707e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 58 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.43s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=69.0412 imbalance=1.063 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=69.0412 imbalance=1.076 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=69.0412 imbalance=1.076 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=69.0412 imbalance=1.076 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=69.0412 imbalance=1.076 nsplit=0
# Epoch: [58][ 0/17]	Time  5.744 ( 5.744)	Data  5.355 ( 5.355)	Loss 7.8674e+00 (7.8674e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 59 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.14s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=60.0801 imbalance=1.098 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=60.1535 imbalance=1.078 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=60.1575 imbalance=1.083 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=60.069 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=60.0523 imbalance=1.072 nsplit=0
# Objective improved: keep new clusters
# Epoch: [59][ 0/17]	Time  5.700 ( 5.700)	Data  5.226 ( 5.226)	Loss 7.7771e+00 (7.7771e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 60 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.18s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=71.0174 imbalance=1.054 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=70.0065 imbalance=1.095 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=71.1858 imbalance=1.079 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=71.1858 imbalance=1.079 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=70.0065 imbalance=1.095 nsplit=0
# Epoch: [60][ 0/17]	Time  6.469 ( 6.469)	Data  5.905 ( 5.905)	Loss 7.7836e+00 (7.7836e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 61 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.12s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=79.9369 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=78.9986 imbalance=1.198 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=79.0659 imbalance=1.280 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=80.0472 imbalance=1.010 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=80.0938 imbalance=1.010 nsplit=0
# Epoch: [61][ 0/17]	Time  5.676 ( 5.676)	Data  5.290 ( 5.290)	Loss 7.7295e+00 (7.7295e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 62 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.19s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.513 imbalance=1.138 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.513 imbalance=1.138 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.5069 imbalance=1.146 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=68.513 imbalance=1.138 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=68.513 imbalance=1.138 nsplit=0
# Epoch: [62][ 0/17]	Time  5.895 ( 5.895)	Data  5.656 ( 5.656)	Loss 7.6966e+00 (7.6966e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 63 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.25s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=82.6445 imbalance=1.149 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=82.599 imbalance=1.050 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=82.5877 imbalance=1.124 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=84.9782 imbalance=1.010 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=82.8843 imbalance=1.011 nsplit=0
# Epoch: [63][ 0/17]	Time  5.635 ( 5.635)	Data  5.362 ( 5.362)	Loss 7.6832e+00 (7.6832e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 64 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.29s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=104.825 imbalance=1.038 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=104.84 imbalance=1.036 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=104.789 imbalance=1.069 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=104.85 imbalance=1.037 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=104.85 imbalance=1.037 nsplit=0
# Epoch: [64][ 0/17]	Time  5.743 ( 5.743)	Data  4.914 ( 4.914)	Loss 7.6507e+00 (7.6507e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 65 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.43s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=104.033 imbalance=1.147 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=103.989 imbalance=1.080 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=104.483 imbalance=1.117 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=103.987 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=103.982 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Epoch: [65][ 0/17]	Time  5.751 ( 5.751)	Data  5.123 ( 5.123)	Loss 7.6404e+00 (7.6404e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 66 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.14s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=103.046 imbalance=1.004 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.306 imbalance=1.061 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=100.343 imbalance=1.115 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=100.368 imbalance=1.066 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=100.277 imbalance=1.081 nsplit=0
# Objective improved: keep new clusters
# Epoch: [66][ 0/17]	Time  5.681 ( 5.681)	Data  4.975 ( 4.975)	Loss 7.6150e+00 (7.6150e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 67 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.17s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=101.995 imbalance=1.107 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=101.97 imbalance=1.090 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=101.995 imbalance=1.107 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=101.97 imbalance=1.090 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=101.97 imbalance=1.090 nsplit=0
# Epoch: [67][ 0/17]	Time  6.499 ( 6.499)	Data  6.220 ( 6.220)	Loss 7.5838e+00 (7.5838e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 68 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.13s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=77.2053 imbalance=1.238 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=77.5221 imbalance=1.047 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=77.3441 imbalance=1.154 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=77.5221 imbalance=1.047 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=77.5221 imbalance=1.047 nsplit=0
# Epoch: [68][ 0/17]	Time  5.609 ( 5.609)	Data  5.046 ( 5.046)	Loss 7.6263e+00 (7.6263e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 69 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.15s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=69.487 imbalance=1.019 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=69.3299 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=69.5197 imbalance=1.030 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=69.3299 imbalance=1.049 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=69.3299 imbalance=1.049 nsplit=0
# Epoch: [69][ 0/17]	Time  5.843 ( 5.843)	Data  5.408 ( 5.408)	Loss 7.5943e+00 (7.5943e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 70 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.28s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.0558 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.25 imbalance=1.050 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=68.0558 imbalance=1.048 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=68.1899 imbalance=1.034 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=68.25 imbalance=1.050 nsplit=0
# Epoch: [70][ 0/17]	Time  5.864 ( 5.864)	Data  5.595 ( 5.595)	Loss 7.5982e+00 (7.5982e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 71 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.20s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=75.8215 imbalance=1.046 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=75.8215 imbalance=1.046 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=75.8257 imbalance=1.044 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=75.8257 imbalance=1.044 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=75.8215 imbalance=1.046 nsplit=0
# Epoch: [71][ 0/17]	Time  5.797 ( 5.797)	Data  5.578 ( 5.578)	Loss 7.5805e+00 (7.5805e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 72 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.42s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=76.6016 imbalance=1.021 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=76.6028 imbalance=1.007 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=76.6094 imbalance=1.018 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=76.4891 imbalance=1.070 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=76.5478 imbalance=1.025 nsplit=0
# Epoch: [72][ 0/17]	Time  5.863 ( 5.863)	Data  5.643 ( 5.643)	Loss 7.5992e+00 (7.5992e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 73 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.12s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=59.9924 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=59.9924 imbalance=1.006 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=63.2792 imbalance=1.118 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=59.9882 imbalance=1.007 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=60.0453 imbalance=1.009 nsplit=0
# Epoch: [73][ 0/17]	Time  5.541 ( 5.541)	Data  4.807 ( 4.807)	Loss 7.5210e+00 (7.5210e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 74 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.19s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=55.7445 imbalance=1.023 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=55.7215 imbalance=1.033 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=55.7187 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=55.7471 imbalance=1.033 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=56.9221 imbalance=1.000 nsplit=0
# Epoch: [74][ 0/17]	Time  6.500 ( 6.500)	Data  6.252 ( 6.252)	Loss 7.5034e+00 (7.5034e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 75 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.12s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=56.3513 imbalance=1.048 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=57.2983 imbalance=1.084 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=57.2557 imbalance=1.011 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=56.2689 imbalance=1.001 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=56.2648 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Epoch: [75][ 0/17]	Time  5.631 ( 5.631)	Data  5.346 ( 5.346)	Loss 7.4714e+00 (7.4714e+00)	Acc@Inst  12.50 ( 12.50)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 76 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.15s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=55.6435 imbalance=1.015 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=55.5961 imbalance=1.010 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=56.0235 imbalance=1.021 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=55.5544 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=55.5515 imbalance=1.006 nsplit=0
# Objective improved: keep new clusters
# Epoch: [76][ 0/17]	Time  5.784 ( 5.784)	Data  5.476 ( 5.476)	Loss 7.4907e+00 (7.4907e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 77 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.32s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=56.3302 imbalance=1.022 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=56.5305 imbalance=1.026 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=56.3889 imbalance=1.049 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=56.441 imbalance=1.052 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=56.3302 imbalance=1.022 nsplit=0
# Epoch: [77][ 0/17]	Time  5.656 ( 5.656)	Data  5.197 ( 5.197)	Loss 7.5290e+00 (7.5290e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 78 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.26s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=58.504 imbalance=1.098 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=58.5962 imbalance=1.102 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=58.5672 imbalance=1.106 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=58.5483 imbalance=1.081 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=58.6287 imbalance=1.115 nsplit=0
# Epoch: [78][ 0/17]	Time  5.583 ( 5.583)	Data  5.329 ( 5.329)	Loss 7.4694e+00 (7.4694e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 79 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.44s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=63.6926 imbalance=1.118 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=63.7771 imbalance=1.096 nsplit=0
# Outer iteration 2 / 5
# ...
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=116.024 imbalance=1.155 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=116.024 imbalance=1.155 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=116.024 imbalance=1.155 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=116.024 imbalance=1.155 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=116.024 imbalance=1.155 nsplit=0
# Epoch: [284][ 0/17]	Time  5.774 ( 5.774)	Data  5.452 ( 5.452)	Loss 7.4984e+00 (7.4984e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 285 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.37s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=148.889 imbalance=1.100 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=148.889 imbalance=1.100 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=148.889 imbalance=1.100 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=148.889 imbalance=1.100 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=148.889 imbalance=1.100 nsplit=0
# Epoch: [285][ 0/17]	Time  6.182 ( 6.182)	Data  5.679 ( 5.679)	Loss 7.4244e+00 (7.4244e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 286 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.13s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=287.001 imbalance=1.071 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=287.001 imbalance=1.071 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=287.001 imbalance=1.071 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=287.001 imbalance=1.071 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=287.001 imbalance=1.071 nsplit=0
# Epoch: [286][ 0/17]	Time  5.822 ( 5.822)	Data  5.600 ( 5.600)	Loss 7.5658e+00 (7.5658e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 287 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.20s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=330.625 imbalance=1.088 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=330.625 imbalance=1.088 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=330.573 imbalance=1.160 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=330.625 imbalance=1.088 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=330.625 imbalance=1.088 nsplit=0
# Epoch: [287][ 0/17]	Time  5.921 ( 5.921)	Data  5.532 ( 5.532)	Loss 7.3637e+00 (7.3637e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 288 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.12s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=292.658 imbalance=1.075 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=292.658 imbalance=1.075 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=292.362 imbalance=1.090 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=292.658 imbalance=1.075 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=292.362 imbalance=1.090 nsplit=0
# Epoch: [288][ 0/17]	Time  5.757 ( 5.757)	Data  5.386 ( 5.386)	Loss 7.4662e+00 (7.4662e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 289 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.17s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=196.122 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=196.867 imbalance=1.067 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=196.122 imbalance=1.031 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=196.122 imbalance=1.031 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=196.869 imbalance=1.067 nsplit=0
# Epoch: [289][ 0/17]	Time  6.638 ( 6.638)	Data  6.024 ( 6.024)	Loss 7.5457e+00 (7.5457e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 290 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.16s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=239.866 imbalance=1.084 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=239.866 imbalance=1.084 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=239.866 imbalance=1.084 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=239.866 imbalance=1.084 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=239.536 imbalance=1.112 nsplit=0
# Objective improved: keep new clusters
# Epoch: [290][ 0/17]	Time  5.751 ( 5.751)	Data  5.539 ( 5.539)	Loss 7.5959e+00 (7.5959e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 291 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.16s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=229.957 imbalance=1.067 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=230.041 imbalance=1.074 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=230.041 imbalance=1.074 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=229.957 imbalance=1.067 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=230.041 imbalance=1.074 nsplit=0
# Epoch: [291][ 0/17]	Time  5.916 ( 5.916)	Data  5.603 ( 5.603)	Loss 7.4367e+00 (7.4367e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 292 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.22s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=289.385 imbalance=1.056 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=289.003 imbalance=1.104 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=289.385 imbalance=1.056 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=289.385 imbalance=1.056 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=289.003 imbalance=1.104 nsplit=0
# Epoch: [292][ 0/17]	Time  5.908 ( 5.908)	Data  5.723 ( 5.723)	Loss 7.6485e+00 (7.6485e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 293 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.17s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=254.425 imbalance=1.138 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=254.425 imbalance=1.138 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=254.425 imbalance=1.138 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=254.425 imbalance=1.138 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=254.425 imbalance=1.138 nsplit=0
# Epoch: [293][ 0/17]	Time  5.851 ( 5.851)	Data  5.024 ( 5.024)	Loss 7.4447e+00 (7.4447e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 294 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:05<00:00,  1.35s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=109.09 imbalance=1.183 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=108.005 imbalance=1.095 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=107.291 imbalance=1.049 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=107.695 imbalance=1.068 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=107.399 imbalance=1.071 nsplit=0
# Epoch: [294][ 0/17]	Time  6.006 ( 6.006)	Data  5.498 ( 5.498)	Loss 7.4535e+00 (7.4535e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 295 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.19s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=252.067 imbalance=1.093 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=252.046 imbalance=1.092 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=252.376 imbalance=1.104 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=253.001 imbalance=1.086 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=252.376 imbalance=1.104 nsplit=0
# Epoch: [295][ 0/17]	Time  5.964 ( 5.964)	Data  5.548 ( 5.548)	Loss 7.3994e+00 (7.3994e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 296 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.19s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=145.791 imbalance=1.149 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=145.916 imbalance=1.136 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=145.791 imbalance=1.149 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=145.817 imbalance=1.149 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=145.916 imbalance=1.136 nsplit=0
# Epoch: [296][ 0/17]	Time  6.996 ( 6.996)	Data  5.971 ( 5.971)	Loss 7.6009e+00 (7.6009e+00)	Acc@Inst   0.00 (  0.00)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 297 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.09s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=130.316 imbalance=1.035 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=130.292 imbalance=1.031 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=130.292 imbalance=1.031 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=130.316 imbalance=1.035 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=133.49 imbalance=1.023 nsplit=0
# Epoch: [297][ 0/17]	Time  5.992 ( 5.992)	Data  5.678 ( 5.678)	Loss 7.4336e+00 (7.4336e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 298 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.16s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=171.464 imbalance=1.159 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=171.464 imbalance=1.159 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=171.464 imbalance=1.159 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=171.464 imbalance=1.159 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.01 s): objective=171.464 imbalance=1.159 nsplit=0
# Epoch: [298][ 0/17]	Time  7.088 ( 7.088)	Data  6.797 ( 6.797)	Loss 7.4680e+00 (7.4680e+00)	Acc@Inst  18.75 ( 18.75)	Acc@Proto   0.00 (  0.00)
# [DEBUG] Epoch 299 | warmup_epoch = 0 | Clustering will run: True
# Computing features...
# 100% 4/4 [00:04<00:00,  1.11s/it]
# performing kmeans clustering
# Clustering 279 points in 128D to 3 clusters, redo 5 times, 20 iterations
#   Preprocessing in 0.00 s
# Outer iteration 0 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=141.825 imbalance=1.178 nsplit=0
# Objective improved: keep new clusters
# Outer iteration 1 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=141.825 imbalance=1.178 nsplit=0
# Outer iteration 2 / 5
#   Iteration 19 (0.00 s, search 0.00 s): objective=141.825 imbalance=1.178 nsplit=0
# Outer iteration 3 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=141.825 imbalance=1.178 nsplit=0
# Outer iteration 4 / 5
#   Iteration 19 (0.01 s, search 0.00 s): objective=141.825 imbalance=1.178 nsplit=0
# Epoch: [299][ 0/17]	Time  5.936 ( 5.936)	Data  5.430 ( 5.430)	Loss 7.5479e+00 (7.5479e+00)	Acc@Inst   6.25 (  6.25)	Acc@Proto   0.00 (  0.00)

# %%
# --- Install dependencies ---
# !pip install faiss-cpu umap-learn scikit-learn matplotlib
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.11/dist-packages (1.12.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.9.post2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.16.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.metrics import normalized_mutual_info_score, adjusted_rand_score, silhouette_score
import numpy as np
import umap
import glob
from pcl import builder
import torchvision.models as models

# --- latest checkpoint ---
checkpoints = sorted(glob.glob("/content/PCL/experiment_pcl/checkpoint_*.pth.tar"))
checkpoint_path = checkpoints[-1]  # latest checkpoint
print("Using checkpoint:", checkpoint_path)

# --- Manually set args used in training ---
arch = "mobilenet_v2"
low_dim = 128
pcl_r = 4
moco_m = 0.999
temperature = 0.2
mlp = True

arch = "mobilenet_v2"
model = builder.MoCo(
    models.__dict__[arch],
    dim=128,
    r=4,
    m=0.999,
    T=0.2,
    mlp=True
)

# --- Load checkpoint but remove queue ---
ckpt = torch.load(checkpoint_path, map_location="cpu")
state_dict = ckpt['state_dict']
state_dict = {k: v for k, v in state_dict.items() if not k.startswith('queue')}
model.load_state_dict(state_dict, strict=False)
model.eval().cuda()

# --- Dataset & DataLoader ---
data_path = "/content/drive/MyDrive/dataset"
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(data_path, transform)
loader = DataLoader(dataset, batch_size=64, shuffle=False, num_workers=4)

# --- Feature extraction ---
all_features = []
all_labels = []

with torch.no_grad():
    for imgs, labels in loader:
        imgs = imgs.cuda(non_blocking=True)
        feats = model.encoder_q(imgs)  # MoCo encoder
        feats = torch.nn.functional.normalize(feats, dim=1)
        all_features.append(feats.cpu())
        all_labels.append(labels)

all_features = torch.cat(all_features, dim=0).numpy()
all_labels = torch.cat(all_labels, dim=0).numpy()

# --- t-SNE Visualization ---
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_embeds = tsne.fit_transform(all_features)

plt.figure(figsize=(8, 8))
scatter = plt.scatter(tsne_embeds[:, 0], tsne_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("t-SNE of MoCo Embeddings")
plt.show()

# --- UMAP Visualization ---
umap_embeds = umap.UMAP(n_neighbors=15, min_dist=0.1, random_state=42).fit_transform(all_features)
plt.figure(figsize=(8, 8))
scatter = plt.scatter(umap_embeds[:, 0], umap_embeds[:, 1], c=all_labels, cmap="tab20", s=5)
plt.legend(*scatter.legend_elements(), title="Classes", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("UMAP of MoCo Embeddings")
plt.show()

# --- Clustering Metrics ---
nmi = normalized_mutual_info_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
ari = adjusted_rand_score(all_labels, np.argmax(all_features @ all_features.T, axis=1))
sil = silhouette_score(all_features, all_labels)

print(f"NMI: {nmi:.4f}")
print(f"ARI: {ari:.4f}")
print(f"Silhouette Score: {sil:.4f}")
# Out:
# Using checkpoint: /content/PCL/experiment_pcl/checkpoint_0299.pth.tar
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# NMI: 0.2360
# ARI: 0.0000
# Silhouette Score: -0.0318

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# --- Paths ---
train_dir = "/content/drive/My Drive/dataset/train"
test_dir  = "/content/drive/My Drive/dataset/test"

# --- Data transforms ---
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# --- Load datasets ---
train_dataset = datasets.ImageFolder(train_dir, transform=transform)
test_dataset  = datasets.ImageFolder(test_dir, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=False, num_workers=4)
test_loader  = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=4)

print("Train size:", len(train_dataset))
print("Test size:", len(test_dataset))
# Out:
# Train size: 279
# Test size: 39
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# --- Feature extraction ---
import torch.nn.functional as F

def extract_features(dataloader):
    features = []
    labels = []
    with torch.no_grad():
        for imgs, lbls in dataloader:
            imgs = imgs.cuda(non_blocking=True)
            feats = model.encoder_q(imgs)  # MoCo encoder
            feats = F.normalize(feats, dim=1)
            features.append(feats.cpu())
            labels.append(lbls)
    return torch.cat(features), torch.cat(labels)

train_features, train_labels = extract_features(train_loader)
test_features, test_labels   = extract_features(test_loader)

# %%
import torch
import torch.nn.functional as F
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# --- Compute class centroids from training features ---
def compute_centroids(features, labels, num_classes):
    centroids = []
    for c in range(num_classes):
        mask = labels == c
        class_feats = features[mask]
        centroid = class_feats.mean(dim=0)
        centroids.append(centroid)
    return torch.stack(centroids)

num_classes = len(train_dataset.classes)
centroids = compute_centroids(train_features, train_labels, num_classes)
centroids = F.normalize(centroids, dim=1)  # normalize like features

# --- Predict test labels using nearest centroid ---
def predict_with_centroids(test_feats, centroids):
    sims = test_feats @ centroids.T  # cosine similarity
    preds = torch.argmax(sims, dim=1)
    return preds

pred_labels = predict_with_centroids(test_features, centroids)

# --- Metrics ---
y_true = test_labels.numpy()
y_pred = pred_labels.numpy()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average="macro")
recall = recall_score(y_true, y_pred, average="macro")
f1 = f1_score(y_true, y_pred, average="macro")

# specificity per class
cm = confusion_matrix(y_true, y_pred)
specificity = []
for i in range(num_classes):
    tn = cm.sum() - (cm[i,:].sum() + cm[:,i].sum() - cm[i,i])
    fp = cm[:,i].sum() - cm[i,i]
    specificity.append(tn / (tn + fp))

specificity = np.mean(specificity)

print("Accuracy:", acc)
print("Precision:", precision)
print("Recall (Sensitivity):", recall)
print("F1 Score:", f1)
print("Specificity:", specificity)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy: 0.48717948717948717
# Precision: 0.4666666666666666
# Recall (Sensitivity): 0.4871794871794872
# F1 Score: 0.4518518518518519
# Specificity: 0.7435897435897436
# Confusion Matrix:
#  [[ 2  7  4]
#  [ 3  7  3]
#  [ 0  3 10]]
